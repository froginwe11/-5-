# %% [markdown]
# # Day174

# %% [markdown]
# # essentially
#
# 英\[ɪˈsenʃəli\] 美\[ɪˈsenʃəli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/essentially)**
#
# adv. 本质上，根本上; 本来; “essential“的派生
#
# **例句**：
#
# Thinking in categories enables us to categorise phenomena are essentially ambiguous.
# 分类思考能够使我们可以将一些本质上含糊的现象进行分类.
#
# It is essentially necessary that I should have an answer to this question.
# 我对这个问题要一个答复,这是非常必要的.

# %% [markdown]
# # toggle
#
# 英\[ˈtɒgl\] 美\[ˈtɑgl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/toggle)**
#
# n. 棒形纽扣; 套索扣; 转换键; 切换键
#
# v. 切换
#
# **例句**：
#
# Screen should not show any indication, turn the left toggle switch towards you.
# 屏幕上应该没有任何显示, 这时将最左上角的那个三位开关掰到离你最近的位置.
#
# The computational result showed that the five point - double toggle clamping system is the best one.
# 计算结果表明,五铰链双曲肘机构为最佳类型.

# %% [markdown]
# # least
#
# 英\[liːst\] 美\[liːst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/least)**
#
# pron. 最小的; 最少的; 程度最轻的
#
# adv. 最少，最小
#
# **例句**：
#
# There is not the least element of truth in his account of what happened.
# 他对所发生的事情的叙述没有一点真实性.
#
# He's the best teacher even though he has the least experience.
# 尽管他经验最少,但教得最好.

# %% [markdown]
# # department
#
# 英\[dɪˈpɑːtmənt\] 美\[dɪˈpɑːrtmənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/department)**
#
# n. 部门，部; 系，学部; 知识范围; 车间
#
# **例句**：
#
# He volunteered to serve as the manager of our department store.
# 他自荐当我们商场的经理.
#
# The department deferred the decision for six months.
# 这个部门推迟了六个月才作决定.

# %% [markdown]
# # register
#
# 英\[ˈredʒɪstə(r)\] 美\[ˈredʒɪstər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/register)**
#
# n. 登记，注册; 记录; 登记簿; 自动记录器
#
# vt. 登记，注册; （仪表等）指示; 表示，表达; （感情）流露
#
# vi. 登记，注册; 留下印象; 完全符合; [印刷]对齐
#
# **例句**：
#
# The name simply didn't register with me.
# 我对这个名字简直没有印象.
#
# The holes for the bolts register perfectly.
# 螺栓的孔眼完全合适.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. essentially
# 2. toggle
# 3. least
# 4. department
# 5. register
