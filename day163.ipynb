# %% [markdown]
# # Day163

# %% [markdown]
# # capture
#
# 英\[ˈkæptʃə(r)\] 美\[ˈkæptʃər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/capture)**
#
# vt. 俘获; 夺取; 夺得; 引起（注意、想像、兴趣）
#
# n. 捕获; 占领; 捕获物; [计算机]捕捉
#
# **例句**：
#
# Learn from whole and master this system, must understand core, stress a focal point, capture essence.
# 从整体上学习和掌握这个体系, 必须理解核心, 突出重点, 抓住本质.
#
# That would repeat a mistaken desire for one number to capture all that matters.
# 否则又会重复那种奢望一个指标能涵盖所有变量的错误.

# %% [markdown]
# # choice
#
# 英\[tʃɔɪs\] 美\[tʃɔɪs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/choice)**
#
# n. 选择; 选择权; 精选品; 入选者
#
# adj. 上等的，精选的
#
# **例句**：
#
# His intimacy with Japan makes him the likely choice as ambassador to that country.
# 他是日本通,很可能被委派为驻日大使.
#
# John helped his father by choice.
# 约翰自愿帮他父亲.

# %% [markdown]
# # step
#
# 英\[step\] 美\[step\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/step)**
#
# n. 步，脚步; 步骤，手段; 步调; 级别
#
# vt.& vi. 举步，行走; 踩，踏上; 跨入; 轻快地走
#
# vi. 踏，踩; 走
#
# vt. 迈步; 使成阶梯状
#
# **例句**：
#
# A foreign language cannot be learned rapidly, it must be learned step by step.
# 外语并非在短时间内就能学会, 学外语是一个循序渐进的过程.
#
# We are likely to fall into step with them.
# 我们可能接受他们的意见.

# %% [markdown]
# # angle
#
# 英\[ˈæŋɡl\] 美\[ˈæŋɡl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/angle)**
#
# n. 角; [比喻]（考虑、问题的）角度; 观点; 轮廓鲜明的突出体
#
# vt. 使形成（或弯成）角度; 把…放置成一角度; 调整（或对准）…的角度; 使（新闻、报道等）带有倾向性
#
# vi. 垂钓; 斜移; 弯曲成一角度; 从（某角度）报道
#
# **例句**：
#
# Moreover, looking from the stock angle, but must inspect behind the net assets the true value.
# 另外, 从个股角度看, 还要考察净资产背后的真实价值.
#
# From another angle, they look like the swaying hoop skirts of dancing mushrooms in animated movie.
# 从另一个角度看, 它们像动画电影中跳舞蘑菇摇摆的圈环裙.

# %% [markdown]
# # content
#
# 英\[ˈkɒntent\] 美\[ ˈkɑːntent\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/content)**
#
# n. 内容; 目录; 主题; 容量
#
# adj. 满足的，满意的; 愿意的; 心甘情愿的
#
# v. 使满足，使满意
#
# **例句**：
#
# Today I really swam to my heart's content . I did 3,000 metres at a stretch.
# 今天我一口气游了三千米,真过瘾.
#
# The labels on food products give a lot of information about their nutritional content.
# 食品上的标签提供很多关于营养成分的信息.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. capture
# 2. choice
# 3. step
# 4. angle
# 5. content
