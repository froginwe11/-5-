# %% [markdown]
# # Day324

# %% [markdown]
# # supply
#
# 英\[səˈplaɪ\] 美\[səˈplaɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/supply)**
#
# vt. 供给; 补充; 弥补（缺陷、损失等）; 向…提供（物资等）
#
# n. 供给物; 储备物质; 粮食
#
# vi. 暂代他人职务
#
# **例句**：
#
# The supply is inadequate to meet the demand.
# 供不应求.
#
# We pasted the enemy's greatest source of supply.
# 我们对敌人的最大补给来源予以重击.

# %% [markdown]
# # fill
#
# 英\[fɪl\] 美\[fɪl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/fill)**
#
# vt.& vi. （使）充满，（使）装满
#
# vt. 满足; 配药; （按订单）供应; 使充满（感情）
#
# n. 填满…的量; 充分; 装填物; 路堤
#
# **例句**：
#
# The manuscript might be usable if the author could fill it out a little.
# 如果作者稍加充实,原稿就可用.
#
# Fill the tank with water.
# 把水槽灌满水.

# %% [markdown]
# # conform
#
# 英\[kənˈfɔːm\] 美\[kənˈfɔːrm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/conform)**
#
# vi. 符合; 遵照; 适应环境
#
# vt. 使遵守; 使一致; 使顺从
#
# **例句**：
#
# They conform exactly to the written descriptions, of porcelain ware used in the imperial palace.
# 这些青瓷盘与史记记载的宫廷用瓷器完全一致.
#
# Then refactor the code, renaming classes, methods, and modules to conform to the new model.
# 然后按照新的模型重新进行编码, 并对类 、 方法和模块进行重命名.

# %% [markdown]
# # plain
#
# 英\[pleɪn\] 美\[pleɪn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/plain)**
#
# n. 平原; 平地; [纺织业]平针; 朴实无华的东西
#
# adj. 平的; 朴素的; 清晰的; 相貌平平的; 简单的
#
# adv. 清楚地，明白地; 平易地; [用以加强语气]显然; 完全地
#
# **例句**：
#
# He set us an example of plain living.
# 他为我们树立了简朴生活的榜样.
#
# I'll tell you everything in plain words.
# 我将坦白地把一切事情告诉你.

# %% [markdown]
# # basis
#
# 英\[ˈbeɪsɪs\] 美\[ˈbeɪsɪs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/basis)**
#
# n. 基础; 主要成分; 基准，基本原则
#
# **例句**：
#
# On the basis of evidence we deduced that he was guilty.
# 根据这些证据我们推断他是有罪的.
#
# Everything is satisfactorily arranged on a sound basis.
# 妥贴稳当.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. supply
# 2. fill
# 3. conform
# 4. plain
# 5. basis
