# %% [markdown]
# # Day272

# %% [markdown]
# # ampersand
#
# 英\[ˈæmpəsænd\] 美\[ˈæmpərsænd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/ampersand)**
#
# n. &的记号名称
#
# **例句**：

# %% [markdown]
# # mixture
#
# 英\[ˈmɪkstʃə(r)\] 美\[ˈmɪkstʃər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/mixture)**
#
# n. 混合，混杂; 混杂的事物[人群]; 混合（状态）
#
# **例句**：
#
# Stir the mixture until smooth.
# 搅拌这种混合物直到调匀为止.
#
# The mixture is fed into the cylinder from the carburettor.
# 混合体由汽化器注入汽缸.

# %% [markdown]
# # but
#
# 英\[bət , bʌt\] 美\[bət , bʌt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/but)**
#
# conj. 但是; 而是; 除了; 只因为
#
# prep. 除…以外
#
# adv. 只; 不过; 只是; 另一方面
#
# n. 借口; 推辞; 但是; 反对
#
# **例句**：
#
# I'm certainly going, but I'll be a little bit late.
# 我去是去, 可是得晚一点儿.
#
# The matter in your essay is excellent but the style is deplorable.
# 你的文章内容不错,但是文体很糟.

# %% [markdown]
# # unable
#
# 英\[ʌnˈeɪbl\] 美\[ʌnˈeɪbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unable)**
#
# adj. 不能的，不会的; 无能力的，不熟练的; 不能胜任的; 〈罕，诗〉弱，无力的
#
# **例句**：
#
# The ice blocks up the river, making the upstream water unable to flow.
# 冰把河道堵住了, 上游的水流不下来.
#
# I was unable to resist laughing.
# 我忍不住笑了.

# %% [markdown]
# # auto
#
# 英\[ˈɔːtəʊ\] 美\[ˈɔːtoʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/auto)**
#
# n. <美>汽车; 自动
#
# **例句**：
#
# Auto focusing technology is widely used in all kinds of optical apparatus.
# 自动调焦技术已经广泛应用于各种光学仪器中.
#
# After visiting the auto dock.
# 参观了汽车码头后.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. ampersand
# 2. mixture
# 3. but
# 4. unable
# 5. auto
