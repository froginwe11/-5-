# %% [markdown]
# # Day286

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=287>

# %% [markdown]
# # scattered
#
# 英\[ˈskætəd\] 美\[ˈskætərd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/scattered)**
#
# adj. 分散的; 零散的; 疏落的; 到处都是…的
#
# **例句**：
#
# The thundershower had temporarily scattered the swimmers.
# 雷阵雨暂时驱散了游泳的人.
#
# The police scattered the disorderly crowd.
# 警察驱散了骚乱的人群.

# %% [markdown]
# # reinstate
#
# 英\[ˌri:ɪnˈsteɪt\] 美\[ˌriɪnˈstet\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reinstate)**
#
# vt. 使复原; 使恢复; 使恢复健康; 使复任
#
# **例句**：
#
# The governor is said to have agreed to reinstate five senior workers who were dismissed.
# 据说州长已同意给5名被解雇的高级雇员复职。
#
# Install rebuilding kits according to procedures and reinstate equipment into production environment.
# 根据流程安装改装件并恢复生产.

# %% [markdown]
# # edit
#
# 英\[ˈedɪt\] 美\[ˈedɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/edit)**
#
# vt. 剪辑（影片，录音）; 编辑; 校订; 主编
#
# **例句**：
#
# Because a combo box contains an edit field, some combo box qualify as entry controls, too.
# 因为组合框包含一个编辑字段, 所以一些组合框的变体也能作为输入控件.
#
# On the Edit menu, select Copy.
# 在“编辑”菜单上选择“复制”.

# %% [markdown]
# # both
#
# 英\[bəʊθ\] 美\[boʊθ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/both)**
#
# pron. 二者
#
# **例句**：
#
# When we use " he " , we generalize for both sex.
# 当我们用 he 时, 我们泛指男女.
#
# The captain cares the safety of both the crew and the passengers.
# 船长为船员和旅客们的安全操心.

# %% [markdown]
# # come
#
# 英\[kʌm\] 美\[kʌm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/come)**
#
# vi. 来; 开始; 出现; 发生
#
# vt. 做; 装扮…的样子; 将满（…岁）
#
# int. 嗨！
#
# n. 精液；精子
#
# **例句**：
#
# New students will come to our school sometime next week.
# 新学员将于下周某时来校.
#
# My mother makes a fuss of me every time I come home.
# 我每次回家,母亲总对我体贴备至.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. scattered
# 2. reinstate
# 3. edit
# 4. both
# 5. come
