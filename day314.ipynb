# %% [markdown]
# # Day314

# %% [markdown]
# # if
#
# 英\[ɪf\] 美\[ɪf\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/if)**
#
# conj. 如果，倘若; 即使; 〈口〉是否; 假设
#
# n. 条件，设想
#
# **例句**：
#
# They were ready to die , if necessary, for their country.
# 必要时, 他们愿为国捐躯.
#
# I will run you in if the bus isn't going into the town because of the snow today.
# 如果今天公共汽车因为下雪不送你进城的话,我会开车送你去的.

# %% [markdown]
# # safety
#
# 英\[ˈseɪfti\] 美\[ˈseɪfti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/safety)**
#
# n. 安全; 安全性; 安全处所; 中卫
#
# **例句**：
#
# The captain cares the safety of both the crew and the passengers.
# 船长为船员和旅客们的安全操心.
#
# Ships were registered abroad to circumvent employment and safety regulation.
# 船只在外国注册以逃避有关雇佣和安全的规定.

# %% [markdown]
# # kernel
#
# 英\[ˈkɜ:nl\] 美\[ˈkɜrnl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/kernel)**
#
# n. 核心; 要点; 谷粒; 核
#
# **例句**：
#
# Exam Watch Red Hat Enterprise Linux was released with Linux Kernel version 2.4.21.
# 考试表红帽企业Linux与Linux核仁2.4.21版一起释放.
#
# Harvest losses increased 1 % per day of harvest delay after kernel moisture reached 10 %.
# 豆粒湿度达到10%后,收割每推延一天,损失就增1%.

# %% [markdown]
# # hang
#
# 英\[hæŋ\] 美\[hæŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hang)**
#
# vt. 悬挂; （被）绞死; 贴，装饰; 使悬而未决
#
# vi. 悬垂; 被吊死; 附属，依靠; 悬而未决
#
# n. 悬挂的样子; （动作的）暂停; 〈口〉大意，要点; 〈口〉做法，诀窍
#
# **例句**：
#
# Many of the town's dropouts hang around the square.
# 这个镇的很多脫离社会传统的人在广场上闲荡.
#
# All the keys hang not at one man's girdle.
# 钥匙不一定都挂在一个人的腰带上.

# %% [markdown]
# # rule
#
# 英\[ruːl\] 美\[ruːl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/rule)**
#
# n. 规则；规章；条例；建议；应做之事；习惯；常规；惯常的做法
#
# v. 控制；统治；支配；操纵；决定；裁定；判决
#
# **例句**：
#
# Obviously economic forces rule.
# 很显然经济力量起决定作用.
#
# The rule is still in effect.
# 本规则仍然有效.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. if
# 2. safety
# 3. kernel
# 4. hang
# 5. rule
