# %% [markdown]
# # Day217

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=218>

# %% [markdown]
# # dual
#
# 英\[ˈdjuːəl\] 美\[ˈduːəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/dual)**
#
# adj. 双的，两部分的，二体的，二重的
#
# **例句**：
#
# The Apple Tree; dual personality; pity; chivalry; romantic; bourgeois.
# 《苹果树》; 两面性; 怜悯; 骑士精神; 浪漫化; 资产阶级.
#
# This committee has a dual function.
# 这个委员会有双重的功能.

# %% [markdown]
# # linker
#
# 英\['lɪŋkə\] 美\['lɪŋkə\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/linker)**
#
# n. （目标代码）连接器
#
# **例句**：
#
# Specifies additional command line options that will be passed to the linker.
# 指定传递给链接器的其它命令行选项.
#
# The linker places this name in the DLL's import library.
# 链接器将此名称放到DLL的导入库中.

# %% [markdown]
# # valid
#
# 英\[ˈvælɪd\] 美\[ˈvælɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/valid)**
#
# adj. 有效的; 有法律效力的; 正当的; 健全的
#
# **例句**：
#
# And the valid calculator system installs excellent turn the method seem to be more for key.
# 而且有效的计算机系统配置优化方法显得更为关键.
#
# Unable to find any valid Outlook Express mailbox files in the specified directory.
# 在指定的目录中找不到任何有效的outlookExpress邮箱文件.

# %% [markdown]
# # indirectly
#
# 英\[ˌɪndɪ'rektlɪ\] 美\[ˌɪndəˈrɛktlɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/indirectly)**
#
# adv. 间接地; 迂回地; 婉转地; 不坦率地
#
# **例句**：
#
# Indirectly, I did cause her death. I shouldn'thave left her there.
# 的确，她的死是我间接造成的。我不该把她留在那里。
#
# The two sides would only meet indirectly, through middlemen.
# 双方只会通过中间人间接接触。

# %% [markdown]
# # allow
#
# 英\[əˈlaʊ\] 美\[əˈlaʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/allow)**
#
# vt. 允许; 承认; 给予; 准许（做某事）
#
# vi. 容许; 考虑
#
# **例句**：
#
# The assembly voted to delay the legislation to allow further consultation to take place.
# 议会投票决定暂缓立法以便进一步磋商.
#
# I'll allow you three guesses.
# 我让你猜三次.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. dual
# 2. linker
# 3. valid
# 4. indirectly
# 5. allow
