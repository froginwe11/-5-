# %% [markdown]
# # Day172

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=173>

# %% [markdown]
# # tape
#
# 英\[teɪp\] 美\[teɪp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/tape)**
#
# n. 带子; 胶带，磁带; 卷尺
#
# vt. 用带子捆起来; 录音
#
# vt.& vi. 录音
#
# **例句**：
#
# The torn page is mended with tape.
# 撕破的一页用胶带补好了.
#
# Please rewind the tape at the end of the film.
# 电影结束后请将盒带倒回.

# %% [markdown]
# # byte
#
# 英\[baɪt\] 美\[baɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/byte)**
#
# n. 字节
#
# **例句**：
#
# A byte composed of three binary element.
# 一种由三个二进制位组成的字节.
#
# Notice in the above code the maximum possible hexadecimal values for char, byte, and short.
# 注意在上述代码中,最大的十六进制值只会在char, byte以及short身上出现.

# %% [markdown]
# # introduce
#
# 英\[ˌɪntrəˈdjuːs\] 美\[ˌɪntrəˈduːs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/introduce)**
#
# vt. 提出; 介绍; 引进; 作为…的开头
#
# **例句**：
#
# Relative pronouns and adverbs introduce attributive clauses.
# 关系代词和关系副词引导定语从句.
#
# The educational bureau demands that all schools introduce a new course into the curriculum.
# 教育局要求所有的学校开设一门新课程.

# %% [markdown]
# # lexical
#
# 英\[ˈleksɪkl\] 美\[ˈleksɪkl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/lexical)**
#
# adj. 词汇的; 具词典性质的，词典的
#
# **例句**：
#
# Pr é parez un dictionnaire personnel , classez les mots par champ lexical non par fonction grammaticale.
# 准备一本个人的字典.
#
# Perspective taking is closely related to the process of lexical choice.
# 视角的选取与词汇选择过程密切相关.

# %% [markdown]
# # sign
#
# 英\[saɪn\] 美\[saɪn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sign)**
#
# n. 符号; 手势; 迹象; 指示牌
#
# vt.& vi. 签名; 打手势
#
# **例句**：
#
# The plus sign is used in addition and the minus is used in subtraction.
# 加号用于加法;减号用于减法.
#
# I should make a few discreet enquiries about the firm before you sign anything.
# 我应先审慎打探一下这家公司的底细,然后你再签字.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. tape
# 2. byte
# 3. introduce
# 4. lexical
# 5. sign
