# %% [markdown]
# # Day230

# %% [markdown]
# # drive
#
# 英\[draɪv\] 美\[draɪv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/drive)**
#
# v. 驾驶; 开车; 驱动; 迫使
#
# n. 驱车旅行; 驱动力; 车道; 驱动器
#
# **例句**：
#
# You can drive a hard bargain in the free market.
# 在自由市场上你可使劲地讨价还价.
#
# The enemy drive towards the town seemed checked.
# 敌人对市镇的进攻似乎已被阻止.

# %% [markdown]
# # recursive
#
# 英\[rɪˈkɜ:sɪv\] 美\[rɪˈkɜrsɪv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/recursive)**
#
# adj. 回归的，递归的
#
# **例句**：
#
# That is the recursive utility function which we will discuss in this paper.
# 这就是本文主要讨论的递归效用函数.
#
# PageWalker is a recursive or to substituting pages Asp. Net Control tree structure.
# PageWalker是一个能够递归跌代asp. net页面控件的树型结构.

# %% [markdown]
# # whichever
#
# 英\[wɪtʃˈevə(r)\] 美\[wɪtʃˈevər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/whichever)**
#
# pron. 任何一个; 无论哪个; 究竟哪一个
#
# **例句**：
#
# Shippers with sizeable volume on hand can choose to use whichever line they like.
# 货量大的货主可以任意挑选他们所喜欢用的船公司.
#
# Whichever day you come, we will be pleased to see you.
# 无论你哪一天来, 我们都很高兴.

# %% [markdown]
# # convenience
#
# 英\[kənˈviːniəns\] 美\[kənˈviːniəns\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/convenience)**
#
# n. 方便，便利; 便利设施; 个人的舒适或利益; （公共）厕所
#
# **例句**：
#
# This new green grocer's provides us with a lot of convenience.
# 小区里新开的菜店方便了大家买菜.
#
# I have always considered my face a convenience rather than an ornament.
# 我一直把我的面孔与其看作是装饰品,倒不如说是看作一种方便的东西.

# %% [markdown]
# # upgrade
#
# 英\[ˌʌpˈɡreɪd , ˈʌpɡreɪd\] 美\[ˌʌpˈɡreɪd , ˈʌpɡreɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/upgrade)**
#
# vt. 提升; 使（机器、计算机系统等）升级; 提高（设施、服务等的）档次; 提高（飞机乘客、旅馆住客等）的待遇
#
# **例句**：
#
# Growing period: advertisement strategy should hold out and upgrade the product � � s brand visualization.
# 在产品的成长期,广告策略应分析同类竞争产品的广告,保持已占领市场,并努力拓展潜在市场,继续维持并提升品牌形象.
#
# The default upgrade method skips upgrades that would introduce conflicts or require installation of additional packages.
# 默认的升级方法会跳过那些引起冲突或需要安装额外软件包的升级.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. drive
# 2. recursive
# 3. whichever
# 4. convenience
# 5. upgrade
