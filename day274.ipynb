# %% [markdown]
# # Day274

# %% [markdown]
# # density
#
# 英\[ˈdensəti\] 美\[ˈdensəti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/density)**
#
# n. 密度; 稠密，浓厚; [物]浓度，比重; 愚钝
#
# **例句**：
#
# The effect of baffle density on the collector efficiency has been also presented and discussed.
# 本研究亦探讨档板密度对收集器效率之影响.
#
# Hole Density: The number of holes per unit area on a PCB.
# 孔密度: PCB上单位面积上的孔数.

# %% [markdown]
# # erase
#
# 英\[ɪˈreɪz\] 美\[ɪˈreɪs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/erase)**
#
# vt. 擦掉; 抹去; 擦掉; 清除
#
# **例句**：
#
# Try as I might , I cannot erase such a terrible experience from my mind.
# 我怎么也不能把这可怕的经历从我的记忆中抹掉.
#
# She couldn't erase the terrible experience from her memory.
# 她无法把那次可怕的经历从记忆中抹去.

# %% [markdown]
# # comparison
#
# 英\[kəmˈpærɪsn\] 美\[kəmˈpærɪsn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/comparison)**
#
# n. 比较，对照; [语]比喻; 比较级
#
# **例句**：
#
# This dress is really cheaper by comparison.
# 比较起来,这件衣服确实便宜.
#
# There is no comparison between the two.
# 二者不能相比.

# %% [markdown]
# # equal
#
# 英\[ˈiːkwəl\] 美\[ˈiːkwəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/equal)**
#
# adj. 相等的，平等的; 平稳的; 势均力敌的; 胜任的
#
# vt. 等于; 比得上; 使相等; 同样看待
#
# n. 同样的人; 相等的数量; 能与之比拟的东西; （地位、实力等）相同的人
#
# vi. 相等，相平（与out连用）
#
# **例句**：
#
# These two shares are not equal. Please even them up.
# 这两份多少不均,再匀一匀吧.
#
# He doesn't seem equal to meeting our demands.
# 他似乎不太合乎我们的要求.

# %% [markdown]
# # phrase
#
# 英\[freɪz\] 美\[freɪz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/phrase)**
#
# n. <语>短语; 成语; 说法; 乐句
#
# vt. 叙述，措词
#
# vt.& vi. 划分乐句，分乐节（尤指为奏乐或歌唱）
#
# **例句**：
#
# His statement was too general and should have been qualified with phrase " in most cases ".
# 他的话太笼统,本应加上 “ 在大多数情况下 ” 加以限制.
#
# She was, in her own memorable phrase,'a woman without a past '.
# 用她自己的令人记忆深刻的话来说, 她“历史清白 ”.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. density
# 2. erase
# 3. comparison
# 4. equal
# 5. phrase
