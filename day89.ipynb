# %% [markdown]
# # Day89

# %% [markdown]
# # runtime
#
# 英\[rʌn'taɪm\] 美\[rʌn'taɪm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/runtime)**
#
# 运行时间
#
# **例句**：
#
# The framework includes two main components: common language runtime ( CLR ) and. NET framework class library.
# .NETFramework 有两个主要组件: 公共语言运行环境 ( CommonLanguage Runtime, 简称CLR ) 和. NETFramework类库.
#
# You need the Java runtime to run Jython code.
# 你需要Java运行库才能运行Jython代码.

# %% [markdown]
# # locate
#
# 英\[ləʊˈkeɪt\] 美\[ˈloʊkeɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/locate)**
#
# vt. 位于; 说出来源; 查找…的地点; 确定…的位置
#
# vi. 定位; 定居
#
# **例句**：
#
# Locate the remaining materials needed to complete the glider. Once completed, traverse to the underground laboratory.
# 找到完成滑翔机所需的剩下的零件. 一旦完成, 穿过地下的实验室.
#
# Tests have been done on the Methods: To locate defects and their qualitative evaluation.
# 试验研究了爬 波检测 时缺陷定位、定性评定的方法,并给出了主要结论.

# %% [markdown]
# # forced
#
# 英\[fɔ:st\] 美\[fɔrst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/forced)**
#
# adj. 被迫的; 强迫的
#
# v. 强制(force的过去式和过去分词)
#
# **例句**：
#
# They forced her off her homeland many years ago.
# 许多年前他们迫使她离开了她的家乡.
#
# He was forced into crime by circumstances.
# 他为环境所迫而犯罪.

# %% [markdown]
# # possibility
#
# 英\[ˌpɒsəˈbɪləti\] 美\[ˌpɑːsəˈbɪləti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/possibility)**
#
# n. 可能，可能性; 希望，可能发生的事物
#
# **例句**：
#
# Detectives have not ruled out the possibility that she was abducted.
# 侦探尚未排除她被绑架的可能性.
#
# This Utopian dream is far beyond the range of possibility.
# 这种乌托邦式的梦想根本不可能实现.

# %% [markdown]
# # serial
#
# 英\[ˈsɪəriəl\] 美\[ˈsɪriəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/serial)**
#
# adj. 连续的; 连载的; 顺序排列的; 分期偿付的
#
# n. 连载小说; 电视连续剧; 定期刊物; [军]行军梯队
#
# **例句**：
#
# After demodulation, receive dates will be sent to PC by CAN bus or the serial port.
# 地面接收机负责将数据解调后,通过串口或者CAN总线将接收数据送往上位机软件.
#
# Communication Instrument: Including Series of 5110 serial Wire Analyzer and 5260 optical communication serial product.
# 通信测量仪器系列: 包括5110系列有线综合测试仪、5260光通信系列产品等.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. runtime
# 2. locate
# 3. forced
# 4. possibility
# 5. serial
