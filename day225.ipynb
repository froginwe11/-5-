# %% [markdown]
# # Day225

# %% [markdown]
# # insert
#
# 英\[ɪnˈsɜːt , ˈɪnsɜːt\] 美\[ɪnˈsɜːrt , ˈɪnsɜːrt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/insert)**
#
# vt. 插入; 嵌入; （在文章中）添加; 加插
#
# n. 添入物（尤指一页印刷品图中插入或套印的小图）; （书报的）插页; 插入物; 添加物
#
# **例句**：
#
# Follow up order , prepayment , tracking order delivery schedule . Insert POs to ERP Monitor and update there.
# 跟踪采购定单,跟踪及控制交货期, 付款及运输,维护更新系统定单状态.
#
# SQL can insert new records in a database.
# SQL能在数据库中插入一条新的记录.

# %% [markdown]
# # reach
#
# 英\[riːtʃ\] 美\[riːtʃ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reach)**
#
# v. 到达，走到; 够…，抓…; 完成
#
# n. 手脚能够到的范围; 范围，区域; 影响的范围，管辖的范围
#
# **例句**：
#
# We ought to be heading back if we want to reach home before dark.
# 如果我们想天黑前到家,现在该往回走了.
#
# We work hard to reach new height.
# 为了达到新高峰,我们努力工作.

# %% [markdown]
# # local
#
# 英\[ˈləʊkl\] 美\[ˈloʊkl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/local)**
#
# adj. 地方的; 当地的，本地的; 局部的; 褊狭的
#
# n. 慢车; 本地居民（律师、教士、医生）; 住处附近的当地酒店; 本地新闻
#
# **例句**：
#
# Public general hospital originated in the almshouse infirmaries established as early as colonial times by local governments to care for the poor.
# 公立医院源自殖民地时期政府为了救济穷人而建立的救济院中的医务所.
#
# All local farmers protested against building the new airport on their farm land.
# 当地农民抗议在他们的农田上建新飞机场.

# %% [markdown]
# # pending
#
# 英\[ˈpendɪŋ\] 美\[ˈpendɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/pending)**
#
# prep. 直到，在等待…期间
#
# adj. 未决的; 未定的; 待定的; 即将发生的
#
# **例句**：
#
# Clarification pending from the relevant government authorities application of withholding to the returns.
# 目前正在等待有关政府部门解释相关银行代扣代缴税款的规定.
#
# Pending resolution of this matter, we ask you to hold all further shipment.
# 在此事尚未解决之前, 我们要求贵方停止所有其他货物的装运.

# %% [markdown]
# # buffer
#
# 英\[ˈbʌfə(r)\] 美\[ˈbʌfər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/buffer)**
#
# n. 缓冲器; 起缓冲作用的人（或物）; [化]缓冲液，缓冲剂; [计]缓冲区
#
# vt. 缓冲; [化]把缓冲液加入（溶液）
#
# **例句**：
#
# It acts as a buffer against harmful environmental change.
# 它可作为缓冲来对抗有害的环境变化.
#
# Matches at the end of buffer only.
# 只匹配缓冲区的结尾.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. insert
# 2. reach
# 3. local
# 4. pending
# 5. buffer
