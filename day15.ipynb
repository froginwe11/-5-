# %% [markdown]
# # Day15

# %% [markdown]
# # well
#
# 英\[wel\] 美\[wel\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/well)**
#
# adv. 好; 很; 好意地; 高高兴兴地
#
# adj. 健康的; 井的; 良好的; 恰当的
#
# int. （用于表示惊讶，疑虑，接受等）
#
# n. 泉; 源泉; 水井
#
# vi. （液体）涌出; 流出; 涌流; 涌上
#
# vt. 涌出，喷出
#
# **例句**：
#
# Mao's fame surpassed well beyond the limits of China.
# 毛泽东的名声远远超越了中国国界.
#
# A rubber ball bounces well.
# 橡皮球弹力好.

# %% [markdown]
# # calling
#
# 英\[ˈkɔ:lɪŋ\] 美\[ˈkɔlɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/calling)**
#
# n. 呼喊; （从事某职业或活动的）欲望; 职业; 邀请
#
# v. 叫( call的现在分词); 通电话; 认为; 估计
#
# **例句**：
#
# I have omitted calling on you for fear of disturbing you.
# 我怕打扰你而没有来拜访你.
#
# Ann was strolling along aimlessly when I brought her up short by calling her name from the other side of the street.
# 安正在街上漫无目标地闲逛,我从街对面叫她,她便停了下来.

# %% [markdown]
# # reappears
#
# 英\[ri:ə'pɪəz\] 美\[riə'pɪrz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reappears)**
#
# vi. 再现，重现
#
# v. 再（出）现( reappear的第三人称单数 )
#
# **例句**：
#
# Instead, most of the incoming energy reappears as the reflected wave.
# 相反, 大部分入射能量都重现为反射波.
#
# Every bit of mechanical energy expended reappears as heat.
# 所消耗的每一点机械能都再现为热能.

# %% [markdown]
# # permanent
#
# 英\[ˈpɜːmənənt\] 美\[ˈpɜːrmənənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/permanent)**
#
# adj. 永久（性）的，永恒的，不变的，耐久的，持久的，经久的; 稳定的; 常务的，常设的
#
# **例句**：
#
# He wore a permanent scowl on his face.
# 他脸上终日带着怒容.
#
# They have transformed themselves into permanent city dwellers.
# 他们已成为永久的城市居民.

# %% [markdown]
# # customize
#
# 英\[ˈkʌstəmaɪz\] 美\[ˈkʌstəˌmaɪz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/customize)**
#
# vt. 定制，定做; 按规格改制
#
# **例句**：
#
#
# You can customize the software in several ways.
# 你可用几种方法按需要编制这个软件。
#
#
# Customize the commands that your users click to insert and remove this section.
# 可以对用户单击以插入和删除节的命令进行自定义。

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. well
# 2. calling
# 3. reappears
# 4. permanent
# 5. customize
