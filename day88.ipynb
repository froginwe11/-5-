# %% [markdown]
# # Day88

# %% [markdown]
# # unrecognized
#
# 英\[ʌnˈrekəɡnaɪzd\] 美\[ ʌnˈrekəɡnaɪzd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unrecognized)**
#
# adj. 未被承认的
#
# **例句**：
#
# There is the possibility that hypothermia can go unrecognized.
# 人们有可能察觉不到体温的过低。
#
# The problem of ageism in the workplace often goes unrecognized .
# 工作场所的年龄歧视问题常被忽视。

# %% [markdown]
# # internal
#
# 英\[ɪnˈtɜːnl\] 美\[ɪnˈtɜːrnl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/internal)**
#
# adj. 国内的; 内部的; 体内的; 内心的
#
# **例句**：
#
# These acts constitute an interference in the internal affairs of other countries.
# 这种行动构成对别国内政的干涉.
#
# He suffered internal injuries in an accident.
# 他在一次意外事故中受了内伤.

# %% [markdown]
# # allowed
#
# 英\[ə'laʊd\] 美\[ə'laʊd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/allowed)**
#
# adj. [计]容许的
#
# v. 允许( allow的过去式和过去分词 ); 承认; 酌增; 接受
#
# **例句**：
#
# I was allowed to do whatever I wanted with my life.
# 我可以自由支配自己的生活。
#
# Directors weren't allowed any proprietary airs about the product they made.
# 主管们不允许对他们生产的产品以所有者自居。

# %% [markdown]
# # independent
#
# 英\[ˌɪndɪˈpendənt\] 美\[ˌɪndɪˈpendənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/independent)**
#
# adj. 自主的; 不相关连的; 无党派的; 不相干的人所做的（或提供的）
#
# n. 独立自主的人; 无党派人士
#
# **例句**：
#
# An independent adviser has been brought in to conciliate between the two sides involved in the conflict.
# 一位独立顾问被请来调停卷入冲突的两方.
#
# Morocco is an independent monarchy.
# 摩洛哥是个独立的君主国家.

# %% [markdown]
# # easy
#
# 英\[ˈiːzi\] 美\[ˈiːzi\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/easy)**
#
# adj. 容易的; 舒适的; 宽裕的; 从容的
#
# adv. 容易地; 不费力地; 悠闲地; 缓慢地
#
# **例句**：
#
# Nowadays it is very easy to earn a living.
# 现今谋生很容易.
#
# It's easy to borrow again if one returns the borrowed things in time.
# 好借好还,再借不难.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. unrecognized
# 2. internal
# 3. allowed
# 4. independent
# 5. easy
