# %% [markdown]
# # Day179

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=180>

# %% [markdown]
# # subsequent
#
# 英\[ˈsʌbsɪkwənt\] 美\[ˈsʌbsɪkwənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/subsequent)**
#
# adj. 后来的; 随后的; 作为结果而发生的; 附随的
#
# **例句**：
#
# We are all slaves of our pasts that shackle our memories and prescribe our subsequent actions.
# 我也是少数回到家园分享我的文化体验的人,我也是少数中一位工作及学习成功地混合由国际组织所捐献的学术单位提供不很实际的国际关系大学课程与实际开发的讲究实效的课程.
#
# Record the related information and assist SCMC Customer Service dept for subsequent handling.
# 记录相关的信息并协助SCMC客户服务部处理后续的事宜.

# %% [markdown]
# # quick
#
# 英\[kwɪk\] 美\[kwɪk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/quick)**
#
# adj. 快的，急速的; 聪明的，凌厉的; 灵活的; 短时间做成的
#
# adv. 迅速地，快速地
#
# n. （指甲下的）活肉; 感情的中枢，感觉最敏锐的地方; 要害，核心
#
# **例句**：
#
# The debater was quick on the draw.
# 辩论者思维敏捷.
#
# He gave his face a quick rub with a towel and went off to work.
# 他用手巾胡噜了一把脸就上工了.

# %% [markdown]
# # indentation
#
# 英\[ˌɪndenˈteɪʃn\] 美\[ˌɪndɛnˈteʃən\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/indentation)**
#
# n. 凹进; 缩格; 凹口; 缺口
#
# **例句**：
#
# The amount of indentation needed in pixels.
# 缩进量,需要用像素为单位.
#
# You cannot use indentation in combination with other tags, as box or code.
# 缩进标记不能和其他标记组合使用, 例如框体或者代码.

# %% [markdown]
# # equivalent
#
# 英\[ɪˈkwɪvələnt\] 美\[ɪˈkwɪvələnt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/equivalent)**
#
# adj. 相等的，相当的，等效的; 等价的，等积的; [化学]当量的
#
# n. 对等物; [化学]当量
#
# **例句**：
#
# Signs of a rebound are evident in the City, the British equivalent of Wall Street.
# 作为英国的华尔街, 伦敦金融城已浮现明显的回升迹象.
#
# But an equivalent betrayal is felt on the Palestinian side.
# 但从巴勒斯坦方面感觉相当于背叛.

# %% [markdown]
# # working
#
# 英\[ˈwɜːkɪŋ\] 美\[ˈwɜːrkɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/working)**
#
# adj. （涉及）工作的; （人）有工作的; （时间）用于工作上的; （想法等）可作为基础的
#
# v. （使）工作( work的现在分词); （使）运作; 运转; （使）产生效果
#
# n. 工作; 活动; 制作; 操纵
#
# **例句**：
#
# Her health was the forfeIt'she paid for working too hard.
# 她的健康的丧失是辛劳过度所致.
#
# We should phase in the new working plans.
# 我们应逐步采用这个新的工作计划.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. subsequent
# 2. quick
# 3. indentation
# 4. equivalent
# 5. working
