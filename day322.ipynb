# %% [markdown]
# # Day322

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=323>

# %% [markdown]
# # box
#
# 英\[bɒks\] 美\[bɑːks\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/box)**
#
# n. 盒; 箱状物; 包厢; 哨房
#
# vt. 把…装入盒[箱，匣]中
#
# vt.& vi. 拳击
#
# **例句**：
#
# That blockhead delivered the wrong box!
# 那个笨蛋送错了盒子.
#
# The whole thing fits into a tubular box.
# 整个东西可装入一支管状盒内.

# %% [markdown]
# # compiler
#
# 英\[kəmˈpaɪlə(r)\] 美\[kəmˈpaɪlɚ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/compiler)**
#
# n. 汇编者; 编辑者; 编纂者; （电脑的）编译程序
#
# **例句**：
#
# The standard JIT compiler runs on demand.
# 标准JIT编译器上运行的需求.
#
# Compiler parser in principle, have to with documentation of the code analysis.
# 编译解析器在原则上, 必须处理的文件的代码分析.

# %% [markdown]
# # advanced
#
# 英\[ədˈvɑːnst\] 美\[ədˈvænst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/advanced)**
#
# adj. 先进的; 高等的，高深的; 年老的; 晚期的
#
# v. 前进(advance的过去式和过去分词); 增加; 上涨
#
# **例句**：
#
# We should apply advanced experience according to local conditions and shouldn't apply it mechanically.
# 对先进的经验我们应该因地制宜,不应生搬硬套.
#
# Her illness has reached an advanced stage.
# 她的病已到晚期.

# %% [markdown]
# # caution
#
# 英\[ˈkɔːʃn\] 美\[ˈkɔːʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/caution)**
#
# n. 小心; 警告; 〈英〉担保; 〈口〉须警惕的事或人
#
# vt. 警告; 提醒
#
# **例句**：
#
# Caution. It is dangerous to take this preparation except under medical supervision.
# 注意: 非经医生指示,服食此药有危险.
#
# Will the wrappers ultimately say, " caution, French fries are fattening "?
# 有朝一日,麦当劳的包装纸上最终是否要印 “ 当心薯条导致发胖 ” 呢 ?

# %% [markdown]
# # addressing
#
# 英\[ə'drəsɪŋ\] 美\[ ə'drɛsɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/addressing)**
#
# v. 称呼（address的现在分词）; 演讲; 致函; 处理
#
# **例句**：
#
# Despite my attempts to get him to call me by my Christian name he insisted on addressing me as "Mr Kennedy".
# 虽然我一再让他叫我的教名，可他执意称我为“肯尼迪先生”。
#
# We'll soon see why goals are so important in addressing this issue.
# 在后面的章节中,我们很快就会谈到为什么目标对解决这一问题是如此的重要.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. box
# 2. compiler
# 3. advanced
# 4. caution
# 5. addressing
