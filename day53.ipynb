# %% [markdown]
# # Day53

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=54>

# %% [markdown]
# # border
#
# 英\[ˈbɔːdə(r)\] 美\[ˈbɔːrdər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/border)**
#
# n. 边; 镶边; 包边; 边界
#
# vt.& vi. 与…接界，在…的边上
#
# vt. 沿…的边，环绕…，给…镶边
#
# vi. 近似，毗邻
#
# **例句**：
#
# At the border the guard waved me through.
# 在边境卫兵挥手让我通过.
#
# Has the parcel been cleared with the border police yet ?
# 那个包裹通过边防警察的检查了 吗 ?

# %% [markdown]
# # unsafe
#
# 英\[ʌnˈseɪf\] 美\[ʌnˈsef\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unsafe)**
#
# adj. 不安全的; 危险的; 不安稳的
#
# **例句**：
#
# Dangerous structure, this bridge is unsafe.
# 危险结构, 该桥不安全.
#
# Your tire is bald and unsafe.
# 你的轮胎磨平了,不安全.

# %% [markdown]
# # analyst
#
# 英\[ˈænəlɪst\] 美\[ˈænəlɪst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/analyst)**
#
# n. 分析家，化验员; 〈美〉精神病医师
#
# **例句**：
#
# Thirdly, why does the part cast an analyst to always do not value Alibaba?
# 其三, 部分投行分析师为何总不看好阿里巴巴?
#
# A local stock analyst remarked: " Only twenty some things like Huang have such courage. "
# 当地一股票分析员对我笑指黄川说: “ 只有这样20多岁的人才有如此的勇气. ”

# %% [markdown]
# # function
#
# 英\[ˈfʌŋkʃn\] 美\[ˈfʌŋkʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/function)**
#
# n. 功能，作用; 因变量，函数; 职务; 重大聚会
#
# vi. 有或起作用; 行使职责
#
# **例句**：
#
# Making copies of those plates for different users is an important function of the library.
# 把这些照片复制,供给不同的使用者是该馆的一项重要任务.
#
# The function of the kidneys is to excrete wastes from the body.
# 肾的功能是排泄人体里的废物.

# %% [markdown]
# # user
#
# 英\[ˈjuːzə(r)\] 美\[ˈjuːzər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/user)**
#
# n. 用户，使用者; 吸毒成瘾者
#
# **例句**：
#
# This has had the chemical reaction in the Chinese computer user.
# 这在中国电脑用户中产生了化学反应.
#
# Of course, our growth and the quality of products and user support is inseparable from the!
# 当然, 我们的壮大与产品的质量以及用户的支持是分不开的!

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. border
# 2. unsafe
# 3. analyst
# 4. function
# 5. user
