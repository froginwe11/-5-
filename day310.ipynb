# %% [markdown]
# # Day310

# %% [markdown]
# # way
#
# 英\[weɪ\] 美\[weɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/way)**
#
# n. 道路; 方法; 方向; 某方面
#
# adv. 远远地，大大地
#
# **例句**：
#
# One way and another I'm going to finish this work before the end of the month.
# 无论如何,我打算在本月完成这项工作.
#
# I had better say a few words by way of explanation.
# 我最好以解释的方式说几句话.

# %% [markdown]
# # append
#
# 英\[əˈpend\] 美\[əˈpɛnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/append)**
#
# vt. 附加; 添加; 贴上; 签（名）
#
# **例句**：
#
# Unable to append the required extension to the file name. Please select a shorter file name.
# 不能将所需的扩展名附在文件名的后面. 请选择一个更短的文件名.
#
# You can even append SEARCH strings so that multiple strings can be highlighted.
# 你甚至可以追加查找的字符串,这样就可以有多个字符串被高亮度显示.

# %% [markdown]
# # tone
#
# 英\[təʊn\] 美\[toʊn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/tone)**
#
# n. [语]声调，语调; [画]色调，色泽，明暗; [乐]乐音，全音，全音程; [医]（正常的）健康状态
#
# vt. 使更健壮; 定调; 使变调子; [摄影术]给…上色
#
# vi. 带有某种腔调; 呈现某种色彩; （颜色）调和（与 with 连用）
#
# **例句**：
#
# I must ask you to tone down your remarks; they are giving offence to some of our visitors.
# 我们必须要求你说话语气和缓一些, 因为你的话得罪了一些客人.
#
# Their first exchange set the tone for a new relationship.
# 他们初步交换意见,为建立新关系定了调子.

# %% [markdown]
# # denote
#
# 英\[dɪˈnəʊt\] 美\[dɪˈnoʊt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/denote)**
#
# vt. 指代; 预示; 代表; 意思是
#
# **例句**：
#
# These nouns denote the physical organism of a person or an animal.
# 这些名词都表示人或动物的身体组织.
#
# These nouns all denote the agitation and anxiety caused by the presence or imminence of danger.
# 这些名词都含有因危险的出现或迫近而引起的不安和焦虑之意.

# %% [markdown]
# # color
#
# 英\['kʌlə(r)\] 美\[ˈkʌlɚ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/color)**
#
# n. <美>颜色，色彩; 肤色，脸色，血色; 颜料，染料; 本质
#
# v. <美>给…涂颜色; 改变…的颜色; 粉饰，渲染，使带上色彩; 脸红
#
# **例句**：
#
# On the new television sets, the color is locked in so that you don't need to keep changing the control.
# 这些新式的电视机的色彩已调定,你不必老去动控制钮.
#
# She differs from her sister in the color of her eyes.
# 她与她姐姐眼睛的颜色不同.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. way
# 2. append
# 3. tone
# 4. denote
# 5. color
