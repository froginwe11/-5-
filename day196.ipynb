# %% [markdown]
# # Day196

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=197>

# %% [markdown]
# # information
#
# 英\[ˌɪnfəˈmeɪʃn\] 美\[ˌɪnfərˈmeɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/information)**
#
# n. 信息，数据; 通知; 消息; 知识
#
# **例句**：
#
# She relayed the information to us.
# 她向我们转达了那消息.
#
# Ordinary people would then be able to use them to obtain valuable information.
# 那时平常的人便能运用它们去获取宝贵的信息.

# %% [markdown]
# # treat
#
# 英\[triːt\] 美\[triːt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/treat)**
#
# n. 款待; 招待; 乐事; 乐趣
#
# v. 对待; 治疗; 处理; 款待
#
# **例句**：
#
# Treat this house as your own, feel free.
# 把这所房子当作你自己的好了, 放轻松.
#
# If you treat your coat so roughly, it will be worn out soon.
# 你如果这么糟蹋你的外套, 它很快就不能穿了.

# %% [markdown]
# # reset
#
# 英\[ˌri:ˈset\] 美\[riˈsɛt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reset)**
#
# vt. 重置; 重排; 重新安装
#
# vi. 重置; 清零
#
# **例句**：
#
# Use a ball - point pen or similar to push the Reset button on the unit.
# 使用圆珠笔或类似物体按本机的重设按钮.
#
# Be sure the RED reset button ( High Limit Control ) is properly set: push in firmly reset.
# 确保红色重置按钮 ( 高温限制控制器 ) 被正确设置: 如果需要重置,请使劲按一下重置按钮.

# %% [markdown]
# # pause
#
# 英\[pɔːz\] 美\[pɔːz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/pause)**
#
# n. 暂时的停顿; 犹豫; （诗中）节奏的停顿; [乐]延长号
#
# vi. 暂停，中止; 逗留，停滞; （按暂停键）暂停放音; 犹豫
#
# **例句**：
#
# A more robust American posture was called for, to give the Kremlin pause.
# 要遏制克里姆林宫,美国就得摆出更坚定的姿态.
#
# You should pause and ponder now.
# 你现在应该停下来仔细考虑一下.

# %% [markdown]
# # redefine
#
# 英\[ˌri:dɪˈfaɪn\] 美\[ˌriːdɪˈfaɪn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/redefine)**
#
# v. 重新定义; 再定义
#
# **例句**：
#
# We will show how information technologies ( IT ) shape and redefine the health care marketplace.
# 我们将展示资讯科技 ( IT ) 如何塑形和重新定义健康照护市场.
#
# Your search returned no results. Redefine your query and search again.
# 您的搜索未返回任何结果. 请重新定义查询并再次搜索.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. information
# 2. treat
# 3. reset
# 4. pause
# 5. redefine
