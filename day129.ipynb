# %% [markdown]
# # Day129

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=130>

# %% [markdown]
# # math
#
# 英\[mæθ\] 美\[mæθ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/math)**
#
# n. 数学（等于mathematics）
#
# **例句**：
#
# He studied math in college.
# 他上大学时专业是数学。
#
# I flunked math in second grade.
# 我二年级时数学不及格。

# %% [markdown]
# # determine
#
# 英\[dɪˈtɜːmɪn\] 美\[dɪˈtɜːrmɪn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/determine)**
#
# vt.& vi. （使）下决心，（使）做出决定
#
# vt. 决定，确定; 判定，判决; 使决定; 限定
#
# vi. [主用于法律]了结，终止，结束
#
# **例句**：
#
# Correlation of the fault indications is important to determine responsibility for the fault.
# 这些故障指示的相互关系对确定对这些故障的响应措施是很重要的.
#
# I determine him to be a fool.
# 我确定他是一个傻子.

# %% [markdown]
# # interpret
#
# 英\[ɪnˈtɜːprət\] 美\[ɪnˈtɜːrprət\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/interpret)**
#
# vt. 解释; 理解; 诠释，体现; 口译
#
# vi. 作解释; 作口译
#
# **例句**：
#
# To read or interpret ( ambiguous, obscure, or illegible matter ).
# 解读解读 ( 含混 、 难以理解或无法辨认的东西 )
#
# Hence, managers need to know how to interpret accounting information for the purpose of project management.
# 因此, 项目经理需要知道怎样解读清算信息以便用于项目的管理.

# %% [markdown]
# # control
#
# 英\[kənˈtrəʊl\] 美\[kənˈtroʊl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/control)**
#
# vt. 控制; 管理; 限制; 支配
#
# n. 支配权; 操纵者; （对国家、地区、机构等的）管理权; （键盘上的）控制键
#
# **例句**：
#
# The control unit decoded the 18 bits.
# 控制器对这18位字进行了译码.
#
# She supports birth control.
# 她赞成计划生育.

# %% [markdown]
# # replace
#
# 英\[rɪˈpleɪs\] 美\[rɪˈpleɪs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/replace)**
#
# vt. 替换; 代替; 把…放回原位; （用…）替换
#
# **例句**：
#
# Those glasses are expensive to replace.
# 要换一副眼镜是很贵的.
#
# Can test automation replace manual testing?
# 测试自动化能否替代手工测试?

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. math
# 2. determine
# 3. interpret
# 4. control
# 5. replace
