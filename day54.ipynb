# %% [markdown]
# # Day54

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=55>

# %% [markdown]
# # limitations
#
# 英\[lɪmɪ'teɪʃnz\] 美\[lɪmɪ'teɪʃnz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/limitations)**
#
# n. 限制，边界; 限制( limitation的名词复数 ); 局限; 极限; 起限制作用的规则（或事实、条件）
#
# **例句**：
#
# I then realized how possible it was to overcome your limitations.
# 那时我才意识到，人克服自身局限的可能性到底有多大。
#
# Certain exclusions and limitations apply.
# 一些排除因素和限制条件比较适用。

# %% [markdown]
# # finished
#
# 英\[ˈfɪnɪʃt\] 美\[ˈfɪnɪʃt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/finished)**
#
# adj. 完成了的; 技术高超的; 精湛的; 〈俚〉死了的，完蛋了的
#
# v. 结束，完成( finish的过去式和过去分词)
#
# **例句**：
#
# Everything is finished between us!
# 我们之间的关系了结了!
#
# Have you finished loading up yet?
# 你把货物装好了 吗 ?

# %% [markdown]
# # send
#
# 英\[send\] 美\[send\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/send)**
#
# vt. 送; 使作出（某种反应）; 派遣; 使进入（某状态）
#
# vt.& vi. 用无线电波发送，发出信息
#
# vi. 派遣，发出，派人
#
# **例句**：
#
# Please send clothes to the laundry.
# 请把这些衣物送往洗衣店.
#
# I'll ask them to send someone out straightaway to fix the car.
# 我会请他们马上派人修理汽车的.

# %% [markdown]
# # attribute
#
# 英\[əˈtrɪbjuːt\] 美\[ əˈtrɪbjuːt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/attribute)**
#
# vt. 认为…是; 把…归于; 把…品质归于某人; 认为某事[物]属于某人[物]
#
# n. 属性；性质；特征
#
# n. 属性; （人或物的）特征; 价值; [语法学]定语
#
# **例句**：
#
# This paper tried to make an analyses on attribute and its position in different sentences.
# 文章拟对定语及其句位进行分析.
#
# This attribute contains an OSI presentation address.
# 这个属性包含了一个OSI地址表示方法.

# %% [markdown]
# # compression
#
# 英\[kəmˈprɛʃən\] 美\[kəmˈprɛʃən\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/compression)**
#
# n. 压缩，压紧，浓缩，紧缩; 加压，压抑; （表现的）简练; 应压试验
#
# **例句**：
#
# The FICBQ division and can obtain higher compression ratio with less computation time in coding.
# FICBQ方法简单且易于实现,压缩比和编码速度得到明显提高.
#
# Methods for calculating expanded size of punched hole and compression punching type are introduced.
# 简述抽孔、压缩抽型的展开时几种情况下的计算方法.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. limitations
# 2. finished
# 3. send
# 4. attribute
# 5. compression
