# %% [markdown]
# # Day201

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=202>

# %% [markdown]
# # although
#
# 英\[ɔːlˈðəʊ\] 美\[ɔːlˈðoʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/although)**
#
# conj. 尽管; 虽然; 但是; 然而
#
# **例句**：
#
# Although the two countries were officially at peace, fighting continued.
# 尽管两国公开表示和平共处, 但战斗还在继续.
#
# Although she felt ill, she still went to work.
# 她虽然觉得身体不舒服, 但仍然去上班了.

# %% [markdown]
# # prompt
#
# 英\[prɒmpt\] 美\[prɑːmpt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/prompt)**
#
# adj. 敏捷的; 迅速的; 立刻的; 准时的
#
# v. 促使; 导致; 鼓励; 提示
#
# n. 激励; 提示符; 提词; 提示
#
# adv. 准时地
#
# **例句**：
#
# Urge a prompt reply and note that the letter is confirmation of a telexed message.
# 敦促早日回复,指出本函是用来确认电传.
#
# Automatic diagnosis, error warning and prompt functions.
# 具有自诊断, 故障报警,提示功能.

# %% [markdown]
# # square
#
# 英\[skweə(r)\] 美\[skwer\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/square)**
#
# n. 正方形; 广场; 平方; 方格
#
# adj. 成直角的; 平方的; （尤指在生意上）公平的; 正方形的
#
# adv. 四四方方地; 成直角地; 正直地; 坚定地
#
# vt. 使成正方形; 使成直角; 检测…的角度; 调整，改正
#
# vi. 一致; 成方形
#
# **例句**：
#
# Many of the town's dropouts hang around the square.
# 这个镇的很多脫离社会传统的人在广场上闲荡.
#
# Square up the books to make them look neat.
# 把书摆正,使其整齐美观.

# %% [markdown]
# # figure
#
# 英\[ˈfɪɡə(r)\] 美\[ˈfɪɡjər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/figure)**
#
# n. 数字; 算术; 人物; 身材
#
# vi. 计算; 出现; 扮演角色
#
# vt. 计算在内; 估计; 推测; 认为
#
# **例句**：
#
# Figure the situation to yourself, what can I do?
# 你设身处地想想, 我能做什么?
#
# Don't figure on going abroad this summer; we may not be able to afford it.
# 别指望今年夏天出国, 我们可能负担不起旅行费用.

# %% [markdown]
# # expire
#
# 英\[ɪkˈspaɪə(r)\] 美\[ɪkˈspaɪər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/expire)**
#
# vi. 期满; 文件、协议等（因到期而）失效; 断气; 逝世
#
# **例句**：
#
# My lease will expire on September 30 th of this year.
# 我的租约今年九月三十日到期.
#
# His term of office as president will expire next year.
# 他的总统任期明年将届满.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. although
# 2. prompt
# 3. square
# 4. figure
# 5. expire
