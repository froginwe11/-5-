# %% [markdown]
# # Day173

# %% [markdown]
# # horizontally
#
# 英\[ˌhɒrɪ'zɒntəlɪ\] 美\[ˌhɑrɪˈzɑntəlɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/horizontally)**
#
# adv. 水平地，横地
#
# **例句**：
#
# You can move the camera both vertically and horizontally.
# 你可以上下左右移动摄像机。
#
# The wind was cold and drove the snow at him almost horizontally.
# 寒风凛冽，雪花几乎是朝他扑面而来。

# %% [markdown]
# # track
#
# 英\[træk\] 美\[træk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/track)**
#
# n. 小路，小道; 痕迹，踪迹; 轨道，音轨; 方针，路线
#
# vt. 跟踪; 监看，监测; 追踪
#
# vi. 沿着轨道前进; 沿着一条路走，旅行; 位于一队列中
#
# **例句**：
#
# The boy breezed the horse around the track.
# 男孩策马沿跑道飞奔.
#
# Production has already been put on the right track.
# 生产已经走上轨道.

# %% [markdown]
# # facility
#
# 英\[fəˈsɪləti\] 美\[fəˈsɪləti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/facility)**
#
# n. 设备，设施，便利条件; 容易; 能力，天赋; 灵巧
#
# **例句**：
#
# A facility that combines Term Loan and Overdraft.
# 这是结合定期贷款与透支的贷款便利.
#
# The facility recently recorded finding 1,890 grammes of gold per tonne of ash from incinerated sludge.
# 这个污水厂最近说它从一吨焚化污泥后的灰烬中提取了1,890克黄金.

# %% [markdown]
# # undefined
#
# 英\[ˌʌndɪˈfaɪnd\] 美\[ˌʌndɪˈfaɪnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/undefined)**
#
# adj. 未阐明的; 未限定的
#
# **例句**：
#
# The money was lent for an undefined period of time.
# 这笔钱无限期借出。
#
# The meeting of any person filled Nixon with an undefined dread.
# 与任何生人的会见使尼克松充满了莫名其妙的紧张.

# %% [markdown]
# # specification
#
# 英\[ˌspesɪfɪˈkeɪʃn\] 美\[ˌspesɪfɪˈkeɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/specification)**
#
# n. 规格; 详述; 说明书
#
# **例句**：
#
# For each child node the specification effort is calculated.
# 对于每个子节点规范努力计算.
#
# Thus this specification is a definition of the syntax and semantics of the XSLT namespace.
# 因些本规范是一个XSLT命名空间的语法和语义的定义.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. horizontally
# 2. track
# 3. facility
# 4. undefined
# 5. specification
