# %% [markdown]
# # Day125

# %% [markdown]
# # certainty
#
# 英\[ˈsɜːtnti\] 美\[ˈsɜːrtnti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/certainty)**
#
# n. 确定性，确实性; 确定的事，必然的事
#
# **例句**：
#
# He had no certainty of success.
# 他没有成功的把握.
#
# I do not know with certainty if Mark will be at home tomorrow.
# 我并不确实知道马克明天是否在家.

# %% [markdown]
# # all
#
# 英\[ɔːl\] 美\[ ɔːl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/all)**
#
# pron. 全部; 一切; 每个人，每件东西; 全部情况
#
# adv. 全部地; 完全地; 每个; 非常
#
# n. 全体; [常作A-]整体; [常与my, your, his, her等连用]（某人）所有的一切
#
# **例句**：
#
# Even a child knows all this.
# 这种事连小孩都知道.
#
# The captain ordered all sails lowered so the ship could ride out the storm.
# 船长命令把所有的帆放下以便船只安全渡过暴风雨.

# %% [markdown]
# # wordperfect
#
#
#
# **[释义](https://fanyi.baidu.com/#en/zh/wordperfect)**
#
# adj. 一字不错地熟记的
#
# **例句**：
#
# Direct integration into winword 6.0 , 7.0 and 97 as well as wordperfect 6.1.
# 直接集成进WinWord6.0、7.0和97,还有WordPerfect6.1.

# %% [markdown]
# # pressed
#
# 英\[prest\] 美\[prɛst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/pressed)**
#
# adj. 紧缺的; （食物）压成某种形状的; 压平的; 金钱（或空间、时间等） 有限
#
# v. 按( press的过去式和过去分词 ); 逼迫; 压榨; 使紧贴
#
# **例句**：
#
# It was getting dark, so they pressed on.
# 天快黑了, 因此他们加劲干着.
#
# She pressed herself against the wall.
# 她紧贴着墙靠着.

# %% [markdown]
# # restriction
#
# 英\[rɪˈstrɪkʃn\] 美\[rɪˈstrɪkʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/restriction)**
#
# n. 限制，限定; 拘束，束缚; 管制
#
# **例句**：
#
# Salt Threshold Value Measurements for Instruction Salt Restriction Diet in Patients witn Heart Diseases.
# 测定盐阈指导心脏病病人合理限盐饮食.
#
# The protocol chooses the QoS routing path based on dynamic delay restriction and link stability factor.
# 该协议基于动态时延约束和链路稳定因子来选择QoS路由.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. certainty
# 2. all
# 3. wordperfect
# 4. pressed
# 5. restriction
