# %% [markdown]
# # Day135

# %% [markdown]
# # link
#
# 英\[lɪŋk\] 美\[lɪŋk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/link)**
#
# n. 环，节; [计算机]链接; 关联，关系
#
# vt. 连结; 挽住，勾住
#
# vi. 用环连接; 联系在一起
#
# **例句**：
#
# He is the stereotyped monster of the horror films and the adventure books, and an obvious ( though not perhaps strictly scientific ) link with our ancestral past.
# 它们是恐怖电影和惊险小说中的老一套的怪物, 并且与我们的祖先有着明显的 ( 虽然可能没有科学的 ) 联系.
#
# The Alumnae Association is my link to the school's present administration.
# 女校友协会是我和现在学校行政部门之间的纽带

# %% [markdown]
# # redundant
#
# 英\[rɪˈdʌndənt\] 美\[rɪˈdʌndənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/redundant)**
#
# adj. 多余的，累赘的; （因人员过剩）被解雇的，失业的; 重沓; 衍
#
# **例句**：
#
# Any CEO who has to make half the force redundant needs to feel a similar detachment.
# 任何一名不得不裁掉一半员工的首席执行官,都需要具备类似的超脱感.
#
# Seventy men at the factory were made redundant.
# 该厂有七十人作为冗员被裁.

# %% [markdown]
# # disk
#
# 英\[dɪsk\] 美\[dɪsk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/disk)**
#
# n. 磁盘; 唱片; 圆盘; 光盘
#
# **例句**：
#
# This driver monitors disk accesses capturing performance data.
# 此驱动程序磁盘访问监视器捕获的性能数据.
#
# Note field back bets by only disk hemisphere.
# 本场盘口受注后退止半球盘.

# %% [markdown]
# # connectivity
#
# 英\[ˌkɒnekˈtɪvɪti\] 美\[ˌkɑnekˈtɪvɪti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/connectivity)**
#
# n. 连通性
#
# **例句**：
#
# You cannot disable the selected network adapter because it is used for network connectivity.
# 选定的网络适配器正用于网络连接,无法禁用它.
#
# Filter route establish the basic rules for connectivity through a firewall.
# 过滤路由器为通过防火墙的连通性建立基本规则.

# %% [markdown]
# # copyright
#
# 英\[ˈkɒpiraɪt\] 美\[ˈkɑːpiraɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/copyright)**
#
# n. 版权，著作权
#
# adj. 受版权保护的; 版权的
#
# vt. 获得…的版权
#
# **例句**：
#
# HOW is not liable for any copyright infringement on the part of the entrant.
# 对于产品的任何侵权行为,HOW将不负责.
#
# A Book publisher may alter or abridge a work with the permission of the copyright owner.
# 图书出版者经版权拥有者许可,可以对作品修改或删节.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. link
# 2. redundant
# 3. disk
# 4. connectivity
# 5. copyright
