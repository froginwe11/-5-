# %% [markdown]
# # Day38

# %% [markdown]
# # reload
#
# 英\[ˌri:ˈləʊd\] 美\[ˌriˈloʊd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reload)**
#
# vt. 再装，重新装
#
# **例句**：
#
# This flag bypasses calling this method and always performs the reload.
# 此标志会跳过调用此方法,并且总是会执行重新加载.
#
# The reload with the appropriate file overwrite it to return to a familiar work environment.
# 重装之后,用相应的文件覆盖就可回到熟悉的工作环境中了.

# %% [markdown]
# # care
#
# 英\[keə(r)\] 美\[ker\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/care)**
#
# v. 关心; 担心; 照顾; 喜爱
#
# n. 照顾; 小心; 忧虑
#
# **例句**：
#
# Public general hospital originated in the almshouse infirmaries established as early as colonial times by local governments to care for the poor.
# 公立医院源自殖民地时期政府为了救济穷人而建立的救济院中的医务所.
#
# With a little care you could have avoided the mishap.
# 你要是小心一点,本来是可以避免这场不测之祸的.

# %% [markdown]
# # smooth
#
# 英\[smuːð\] 美\[smuːð\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/smooth)**
#
# adj. 光滑的; 流畅的; 柔软的; 温和的，安详的
#
# vt. 使平滑; 排除，消除; 安抚，平息; 使优雅
#
# vi. 变平和，变缓和
#
# **例句**：
#
# We could feel the smooth texture of silk.
# 我们能感觉出丝绸的光滑质地.
#
# The cloth feels smooth.
# 这块布料摸起来很滑.

# %% [markdown]
# # deactivate
#
# 英\[ˌdi:ˈæktɪveɪt\] 美\[diˈæktəˌvet\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/deactivate)**
#
# vt. 解除动员; 使无效; 复员; 使不活动
#
# **例句**：
#
# To deactivate the key combination for StickyKeys, click Settings.
# 要停用粘滞键组合, 请单击“设置”.
#
# To deactivate the key combination for ToggleKeys, click Settings.
# 要停用切换键组合, 请单击“设置”.

# %% [markdown]
# # find
#
# 英\[faɪnd\] 美\[faɪnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/find)**
#
# v. 发现; 找到; 查明; 发觉
#
# n. 发现物; 被发现的人
#
# **例句**：
#
# We find the mother featured in the son.
# 我们发现这个儿子很象她母亲.
#
# I have to find a convenient location for the shelves.
# 我得找一合适的地方放这些书架.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. reload
# 2. care
# 3. smooth
# 4. deactivate
# 5. find
