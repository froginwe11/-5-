# %% [markdown]
# # Day12

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=13>

# %% [markdown]
# # scatter
#
# 英\[ˈskætə(r)\] 美\[ˈskætər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/scatter)**
#
# vt. （使）散开，（使）分散，驱散
#
# vi. 撒开; 分散
#
# n. 散布，散播
#
# **例句**：
#
# The appearance of any plane was the signal to dismount and scatter.
# 一经发现飞机,就得下车疏散.
#
# First, an uncorrelated projection space is constructed based on the total population scatter matrix.
# 首先根据总体散布矩阵构造无相关投影空间.

# %% [markdown]
# # perform
#
# 英\[pəˈfɔːm\] 美\[pərˈfɔːrm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/perform)**
#
# vt.& vi. 执行; 履行; 表演; 扮演
#
# vt. 工作; 做; 进行; 完成
#
# vi. 运行，表现; （驯兽）玩把戏
#
# **例句**：
#
# I have a duty to perform.
# 我有一种义务要尽.
#
# He has taught his dog to perform some clever tricks.
# 他已经训练他的狗玩几样灵巧的把戏了.

# %% [markdown]
# # first
#
# 英\[fɜːst\] 美\[fɜːrst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/first)**
#
# n. 第一，最初; 头等; 一号，; [乐]高音部
#
# adv. 最早，最初; 首次; 宁愿; 优先
#
# num. 第一
#
# **例句**：
#
# He missed the first prize by a whisker.
# 他和头奖擦肩而过.
#
# Let's clean their room first and then ours.
# 咱们先打扫他们的房间,再打扫我们的房间.

# %% [markdown]
# # locating
#
# 英\[ləʊ'kəɪtɪŋ\] 美\[loʊ'kəɪtɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/locating)**
#
# v. 找出，指出（地点或位置）( locate的现在分词 ); （在…）设置，坐落于; 创办于（某地）
#
# **例句**：
#
# She decided to head for the dormitory to take another crack at locating Blanche.
# 她决定回宿舍再找找布兰奇。
#
# Some of these methods are suitable for either detecting or locating leaks.
# 这些方法中,有一些适合于检查漏气或者确定漏气位置.

# %% [markdown]
# # social
#
# 英\[ˈsəʊʃl\] 美\[ˈsoʊʃl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/social)**
#
# adj. 社会的，社会上的; 交际的，社交的; 群居的; 合群的
#
# n. 联谊会，联欢会; 社交聚会
#
# **例句**：
#
# Economic conditions may lie responsible for the creation of social unrest.
# 经济状况可能是产生社会不安的根源.
#
# This can become a driving force for social advance.
# 这能成为促使社会前进的动力.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. scatter
# 2. perform
# 3. first
# 4. locating
# 5. social
