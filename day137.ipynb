# %% [markdown]
# # Day137

# %% [markdown]
# # personal
#
# 英\[ˈpɜːsənl\] 美\[ˈpɜːrsənl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/personal)**
#
# adj. 个人的，私人的; 身体的; 亲自的; 人身攻击的
#
# n. （报刊上的）人事栏，分类人事广告版; 人称代名词; 关于个人的简讯
#
# **例句**：
#
# The Chinese make a point of their personal honor.
# 中国人特别重视个人荣誉.
#
# He never reaches after personal fame and gain.
# 他从不追求个人名利.

# %% [markdown]
# # lending
#
# 英\[ˈlendɪŋ\] 美\[ˈlɛndɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/lending)**
#
# n. 出借; 出租; 贷款; 出借物
#
# v. 把…借给( lend的现在分词 ); 贷（款）; 增加; 增添
#
# **例句**：
#
# Do not insult your friend by lending him merits from your own pocket.
# 不要从你自己的袋里掏出勋绩借给你的朋友,这是污辱他的.
#
# The federal government would over most student lending.
# 联邦政府将接手大部分助学贷款.

# %% [markdown]
# # exponential
#
# 英\[ˌekspəˈnenʃl\] 美\[ˌekspəˈnenʃl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/exponential)**
#
# adj. 指数的，幂数的; 越来越快的
#
# **例句**：
#
# Moreover, the control laws using smooth time varying feedback do not at exponential convergence rate.
# 已有的光滑时变反馈方法是非指数收敛的.
#
# These measurements showed that the electronic heat well below Tc was dominated by an exponential dependence.
# 这些测量结果表明,在远低于Tc的温度下,电子比热是按指数规律变化的.

# %% [markdown]
# # time
#
# 英\[taɪm\] 美\[taɪm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/time)**
#
# n. 时间; 时刻; 时代; 次
#
# vt. 为…安排时间; 测定…的时间; 调准（机械的）速度; 拨准（钟、表）的快慢
#
# vi. 合拍; 和谐; 打拍子
#
# **例句**：
#
# The ship drifted helplessly for a time.
# 那艘船孤零无依地漂泊了一阵子.
#
# My mother makes a fuss of me every time I come home.
# 我每次回家,母亲总对我体贴备至.

# %% [markdown]
# # previous
#
# 英\[ˈpriːviəs\] 美\[ˈpriːviəs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/previous)**
#
# adj. 先前的; 以前的; 过早的; （时间上）稍前的
#
# adv. 在先；在…以前
#
# **例句**：
#
# I should like to echo the words of the previous speaker.
# 我想重复前面一位发言者的话.
#
# He cannot go for he has a previous engagement.
# 他不能去,因他已先有约会.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. personal
# 2. lending
# 3. exponential
# 4. time
# 5. previous
