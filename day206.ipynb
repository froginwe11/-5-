# %% [markdown]
# # Day206

# %% [markdown]
# # anywhere
#
# 英\[ˈeniweə(r)\] 美\[ˈeniwer\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/anywhere)**
#
# adv. 什么地方; 任何地方; 无论何处; 〈口〉（用于否定句〕根本(不）
#
# **例句**：
#
# She never gets anywhere on time. She's hopelessly disorganized.
# 她从不准时,做事无头绪,简直无可救药.
#
# Our dog will nose out a rabbit anywhere it hides.
# 无论兔子藏在哪里,我们的狗都会嗅出来.

# %% [markdown]
# # synchronize
#
# 英\[ˈsɪŋkrənaɪz\] 美\[ˈsɪŋkrənaɪz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/synchronize)**
#
# vt. 使同步; 使同时
#
# vi. 同时发生; 共同行动
#
# **例句**：
#
# A NTP client is a program which user can synchronize the time with time server assigned.
# 阿的NTP客户端是一个计划,用户可以同步时间与时间服务器分配.
#
# Offline methods should be able and synchronize after any part of the enterprise system was down.
# 最重要的是,作为业务基础,没有这方面,企业无法管理,甚至存在.

# %% [markdown]
# # worker
#
# 英\[ˈwɜːkə(r)\] 美\[ˈwɜːrkər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/worker)**
#
# n. 工人，员工; 劳动者; [虫]工蜂，工蚁
#
# **例句**：
#
# The worker hammered the iron flat.
# 工人把铁锤平了.
#
# I judge him a skilled worker.
# 我断定他是个熟练工人.

# %% [markdown]
# # sounding
#
# 英\[ˈsaʊndɪŋ\] 美\[ˈsaʊndɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sounding)**
#
# n. 探通术
#
# v. （使）发出声音，响( sound的现在分词 ); 发（音）; 试探; 探测
#
# **例句**：
#
# And, at the risk of sounding parochial, adopt a capital regime similar to the Canadian system.
# 此外 —— 虽然有狭隘之嫌 —— 采用与加拿大体系类似的资本规则.
#
# The signal goes on sounding at fixed intervals.
# 讯号在固定的间隔时间内鸣响.

# %% [markdown]
# # prevent
#
# 英\[prɪˈvent\] 美\[prɪˈvent\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/prevent)**
#
# vt. 预防; 阻碍; 阻止; [宗教]引领
#
# vi. 阻挠，阻止
#
# **例句**：
#
# The fence is strategically sited to prevent anyone getting onto the beach.
# 这个围栏的地点选择得很有策略,可以阻止任何人到海滩上.
#
# How can we prevent such distress?
# 我们怎样才能避免这种贫困?

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. anywhere
# 2. synchronize
# 3. worker
# 4. sounding
# 5. prevent
