# %% [markdown]
# # Day187

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=188>

# %% [markdown]
# # processor
#
# 英\[ˈprəʊsesə(r)\] 美\[ˈprɑːsesər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/processor)**
#
# n. 加工; 数据处理机; （计算机的）中央处理器; 加工机（或工人）
#
# **例句**：
#
# Chroma keying can be performed in either software or hardware on a media processor.
# 色度键控可以在媒体处理器上以软件或者硬件形式来实现.
#
# Plot out films using Laser plotter and develop the film using film processor.
# 用激光绘图机拍出菲林并用显影机显影.

# %% [markdown]
# # procedure
#
# 英\[prəˈsiːdʒə(r)\] 美\[prəˈsiːdʒər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/procedure)**
#
# n. 程序，手续; 工序，过程，步骤; 诉讼程序，（议会的）议事程序; 〈罕〉进行
#
# **例句**：
#
# He is rigid about points of procedure.
# 他坚持议事程序上的要点.
#
# Revising the procedure was an entirely profitless exercise.
# 对程序进行修改是徒劳无功的.

# %% [markdown]
# # adapter
#
# 英\[ə'dæptə\] 美\[əˈdæptɚ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/adapter)**
#
# n. 适配器; 改编者; 改写者适应者; 适应物
#
# **例句**：
#
# Place the tester adapter over the opening.
# 把试验器连接装置放在加油口上.
#
# Plug in the AC adapter and restart your notebook.
# 插入交流电适配器并重新启动笔记本电脑.

# %% [markdown]
# # found
#
# 英\[faʊnd\] 美\[faʊnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/found)**
#
# vt. 创办，成立，建立
#
# v. 发现( find的过去式); 找到; 到达; 发觉
#
# **例句**：
#
# We found him to be the right sort of timber.
# 我们发现他是真正的人才.
#
# The difference is found by subtraction.
# 用减法得出差额.

# %% [markdown]
# # signal
#
# 英\[ˈsɪɡnəl\] 美\[ˈsɪɡnəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/signal)**
#
# n. 信号，暗号; 预兆，征象; 动机; 导火线
#
# vt. 向…发信号; 用动作（手势）示意; 以信号告知
#
# vi. 发信号
#
# adj. 显著的，优越的; 暗号的，作信号用的
#
# **例句**：
#
# Experts regarded it as a warning signal of an economic smashup.
# 专家们把它看作是一场经济灾难的警告信号.
#
# The carrier wave has got out of phase with the signal wave.
# 载波同信号波是异相的.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. processor
# 2. procedure
# 3. adapter
# 4. found
# 5. signal
