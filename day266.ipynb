# %% [markdown]
# # Day266

# %% [markdown]
# # break
#
# 英\[breɪk\] 美\[breɪk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/break)**
#
# vt. （使）破; 打破（纪录）; （常指好天气）突变; 开始
#
# vi. （嗓音）突变; 突破; 破晓; （价格）突然下跌
#
# n. 破裂; 中间休息; 间断; 短假
#
# **例句**：
#
# We had to break the door out to escape from the fire.
# 我们不得不把门砸开以逃避火灾.
#
# The branch bent but did not break.
# 那树枝弯曲,但没有折断.

# %% [markdown]
# # whenever
#
# 英\[wenˈevə(r)\] 美\[wenˈevər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/whenever)**
#
# adv. 究竟什么时候; 不论何时
#
# conj. 无论什么时候; 随时; 无论何时; 每当
#
# **例句**：
#
# Our street floods whenever we have rain.
# 我们的街道一下雨就淹水.
#
# He likes to fight it out whenever others disagree with him.
# 当别人与他意见不一致时,他总喜欢争个明白.

# %% [markdown]
# # decide
#
# 英\[dɪˈsaɪd\] 美\[dɪˈsaɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/decide)**
#
# vt. 决定; 决心; 解决; 裁决
#
# vi. 决定; 下决心
#
# **例句**：
#
# I can't decide what to do. I'll sleep on it and let you know tomorrow.
# 我不能决定该怎么做. 我考虑一下,明天告诉你.
#
# We'll decide on our team as and when we qualify for the competition.
# 我们等到有资格参加比赛时再来决定本队参赛人员.

# %% [markdown]
# # rename
#
# 英\[ˌri:ˈneɪm\] 美\[ˌriːˈneɪm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/rename)**
#
# vt. 给…重新取名，改名
#
# **例句**：
#
# Use the numeric keypad on your remote to enter letters to rename the manual record.
# 使用遥控器上的数字小键盘输入字母以重命名手动录制.
#
# Base upon customer data and circuit board structure to define layer's properties and rename.
# 根据客户资料及线路板的结构定义层的属性并重新命名.

# %% [markdown]
# # reason
#
# 英\[ˈriːzn\] 美\[ˈriːzn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reason)**
#
# n. 理由; 原因; 理性; 理智
#
# vt.& vi. 推理，思考; 争辩; 辩论; 向…解释
#
# **例句**：
#
# Tell me the when and the why ( = reason ) of it.
# 请告诉我时间和原因.
#
# He is pervious to reason.
# 他可以理喻.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. break
# 2. whenever
# 3. decide
# 4. rename
# 5. reason
