# %% [markdown]
# # Day109

# %% [markdown]
# # discard
#
# 英\[dɪˈskɑːd , ˈdɪskɑːd\] 美\[dɪˈskɑːrd , ˈdɪskɑːrd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/discard)**
#
# vt. 丢弃，抛弃; 解雇; 出牌
#
# n. 被抛弃的人[物]; 丢弃，抛弃; 打出的牌
#
# vi. 出无用的牌; 垫牌
#
# **例句**：
#
# Make sure you leave a little of the red tip intacteffect. Discard one half.
# 记得务必留下火柴的红色小尖头哦,另外的一半先放着.
#
# You discard your gold ring because it is only a gold ring.
# 你卖掉你的金戒指因为那仅仅是一个金戒指.

# %% [markdown]
# # round
#
# 英\[raʊnd\] 美\[raʊnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/round)**
#
# adj. 圆形的; 弧形的; 丰满的，肥胖的; 整数的
#
# adv. 到处; 在周围; 迂回地; 朝反方向
#
# prep. 大约; 绕过，环绕; （表示位置）在…四周; 附近
#
# n. 圆，圆形; 循环; 圆形物，球状物; （会议的）一回合
#
# v. 使成圆形; 绕行; 拐过，绕过; 把…四舍五入
#
# **例句**：
#
# How do you demonstrate that the earth is round?
# 你怎样证明地球是圆的?
#
# He has been hiking round Scotland for a month.
# 他围着苏格兰徒步旅行了一个月.

# %% [markdown]
# # preset
#
# 英\[ˌpriːˈset\] 美\[ˌpriːˈset\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/preset)**
#
# vt. 预先布置; 事先调整; 预先决定; 事先安排
#
# **例句**：
#
# Installed in a mainline it prevents upstream pressure from dropping below a preset minimum.
# 安装在主管线内,防止上游压力降到预置最小压力以下.
#
# Some preset the system time on their computers to view blackout, with help from online instructions.
# 一些人预先设定了电脑的系统时间, 在在线说明的帮助下看黑屏.

# %% [markdown]
# # separator
#
# 英\[ ˈsepəreɪtə(r)\] 美\[ ˈsepəreɪtər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/separator)**
#
# n. 分离器，分离装置; 防胀器
#
# **例句**：
#
# Then pump bilge water into oily water separator.
# 再泵入油水分离器.
#
# Paper separator and pressure device can be installed.
# 可配分纸压线装置.

# %% [markdown]
# # indent
#
# 英\[ɪnˈdent , ˈɪndent\] 美\[ɪnˈdent , ˈɪndent\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/indent)**
#
# vt. 切割…使呈锯齿状; 缩进排版
#
# n. 订单；订购
#
# n. （印刷中的）缩进; 订单，订购
#
# **例句**：
#
# The indent agent takes a commission on the value of his purchase.
# 这种订货代理商按所订购的货物价值收取佣金.
#
# The mountains indent the horizon.
# 山峦使地平线成锯齿状.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. discard
# 2. round
# 3. preset
# 4. separator
# 5. indent
