# %% [markdown]
# # Day333

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=334>

# %% [markdown]
# # documentation
#
# 英\[ˌdɒkjumenˈteɪʃn\] 美\[ˌdɑːkjumenˈteɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/documentation)**
#
# n. 证明某事属实的证据; 记录; 参考资料; 文献的编集，文件分类
#
# **例句**：
#
# Possibly the biggest problem with documenting code has been maintaining that documentation.
# 对于程序的文档化,最大的问题莫过于对文档的维护.
#
# Class documentation can also be used for interfaces ( see Chapter 8 ).
# 类文档亦可用于“接口”目的 ( 本书后面会详细解释 ).

# %% [markdown]
# # enable
#
# 英\[ɪˈneɪbl\] 美\[ɪˈneɪbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/enable)**
#
# vt. 使能够，提供做…的权利[措施]; 使可能; 授予权利或方法
#
# **例句**：
#
# The sessions will enable you to discuss problems with fellow asthma sufferers.
# 这些环节让你和其他哮喘病患者一起讨论问题.
#
# This dictionary will enable better international understanding.
# 这部辞典将促进国际间更好的理解.

# %% [markdown]
# # exact
#
# 英\[ɪɡˈzækt\] 美\[ɪɡˈzækt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/exact)**
#
# adj. 准确的; 严密的; 精密的，精确的
#
# vt. 要求; 苛求; 迫使; 强求
#
# **例句**：
#
# His answer is quite exact.
# 他的回答完全正确.
#
# I don't know the exact number of people who have been invited but off the top of my head I should think there will be about forty.
# 我不知道被邀请者的确切人数,但不用思索,我认为会有40人左右.

# %% [markdown]
# # available
#
# 英\[əˈveɪləbl\] 美\[əˈveɪləbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/available)**
#
# adj. 可获得的; 有空的; 可购得的; 能找到的
#
# **例句**：
#
# All the evidence of the crime is available.
# 罪证俱在.
#
# This book is not available here.
# 这里没有这本书.

# %% [markdown]
# # dimension
#
# 英\[daɪˈmenʃn\] 美\[daɪˈmenʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/dimension)**
#
# n. 尺寸; [复]面积，范围; [物]量纲; [数]次元，度，维
#
# **例句**：
#
# We can now prove invariance of dimension, one of the most important results about vector spaces.
# 现证明维数的不变性, 它是向量空间最重要的结果之一.
#
# Minimum dimension from centerline of valve to handwheel when ordered without floorstand.
# 如果不订购地轴承架,则最小长度尺寸为阀门中心至手轮的长度.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. documentation
# 2. enable
# 3. exact
# 4. available
# 5. dimension
