# %% [markdown]
# # Day122

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=123>

# %% [markdown]
# # delete
#
# 英\[dɪˈliːt\] 美\[dɪˈliːt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/delete)**
#
# vt.& vi. 删除
#
# **例句**：
#
# The first, correct an error quickly, delete false information.
# 第一 、 迅速改正错误, 删除虚假信息.
#
# You must delete all sections Entitled '' Endorsements '' .
# 你必须删除标题为 背书 的所有章节.

# %% [markdown]
# # cpu
#
# 英\[ˌsi: pi: ˈju:\] 美\[ˌsipi'ju\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/cpu)**
#
# n. 中央处理器
#
# **例句**：
#
# The 8080,6800, Z - 80, and 8085 systems were presented to illustrate the simplicity of CPU assemply.
# 本章之所以介绍8080,6800, Z-80, 和8085系统,目的在于说明CPU装配的简易性.
#
# Quick access to your host information, including CPU, memory and so on.
# 快速获取您所使用的主机信息, 包括CPU, 内存等等.

# %% [markdown]
# # swap
#
# 英\[swɒp\] 美\[swɑːp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/swap)**
#
# n. 交换; 交换物，被掉换者
#
# vi. 交换（工作）
#
# vt. 用…替换，把…换成，掉换（过来）
#
# **例句**：
#
# Just swap out the logo, a few images and you're good to go.
# 只需更换标识, 一些图片和您良好的路要走.
#
# Swap arrangements made by other insurers require payments only if a default occurs.
# 其他保险公司销售的掉期所做的交易安排是,只有在发生违约时才需要付款.

# %% [markdown]
# # single
#
# 英\[ˈsɪŋɡl\] 美\[ˈsɪŋɡl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/single)**
#
# adj. 单一的; （打斗、比赛等）一对一的; 惟一的; 适于一人的
#
# n. 单程票; （旅馆等的）单人房间; [复数]（高尔夫球一对一的）二人对抗赛; [常用复数][美国、加拿大英语]未婚（或单身）男子（或女子）
#
# **例句**：
#
# The soldiers were walking in single file.
# 战士们排成一列纵队前进.
#
# This single item will suffice to typify all the rest.
# 即此一端,可概其余.

# %% [markdown]
# # employee
#
# 英\[ɪmˈplɔɪiː\] 美\[ɪmˈplɔɪiː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/employee)**
#
# n. 雇工，雇员，职工
#
# **例句**：
#
# The stolen laptop of a Veterans Affairs employee has been recovered.
# 一退伍士兵的被盗手提又回来了.
#
# As to any enterprise, the most important strategic resource is its employee.
# 员工是企业最重要的战略资源.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. delete
# 2. cpu
# 3. swap
# 4. single
# 5. employee
