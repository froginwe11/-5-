# %% [markdown]
# # Day48

# %% [markdown]
# # instant
#
# 英\[ˈɪnstənt\] 美\[ˈɪnstənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/instant)**
#
# n. 瞬间，顷刻; 此刻; 当月; 速食食品，即溶饮料
#
# adj. 立即的; 迫切的; 正在考虑的，目前的; 即食的
#
# **例句**：
#
# He paused for an instant.
# 他停了一会儿.
#
# Not for an instant did I believe he had lied.
# 我根本就不相信他撒了谎.

# %% [markdown]
# # into
#
# 英\[ˈɪntu\] 美\[ˈɪntu\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/into)**
#
# prep. （表示方向）进入…中; （表示所属）输入; （表示状态）进入…状态; （表示时间）持续到
#
# **例句**：
#
# I will run you in if the bus isn't going into the town because of the snow today.
# 如果今天公共汽车因为下雪不送你进城的话,我会开车送你去的.
#
# The word has passed into complete disuse.
# 这个词已经完全不用了.

# %% [markdown]
# # suitable
#
# 英\[ˈsuːtəbl\] 美\[ˈsuːtəbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/suitable)**
#
# adj. 合适的，适当的，适宜的，恰当的
#
# **例句**：
#
# This is not a suitable time for launching forth on a new business undertaking.
# 现在,不宜着手搞新的经营项目.
#
# The girl always complains about lacking suitable raiment.
# 这个女孩总是抱怨没有合适的衣服.

# %% [markdown]
# # correct
#
# 英\[kəˈrekt\] 美\[kəˈrekt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/correct)**
#
# adj. 正确的; 合适的; 符合公认准则的; 得体的
#
# v. 改正; 批改; 指出错误
#
# **例句**：
#
# Please correct any errors that you find.
# 若有差错,请斧正.
#
# She gave a correct answer.
# 她给了个正确的答案.

# %% [markdown]
# # year
#
# 英\[jɪə(r)\] 美\[jɪr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/year)**
#
# n. 年; 年纪; 一年的期间; 某年级的学生
#
# **例句**：
#
# His son joined the army last year.
# 他儿子去年入伍.
#
# My income for that year amounted to 1000 dollars.
# 我那一年的收入达到1000美元.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. instant
# 2. into
# 3. suitable
# 4. correct
# 5. year
