# %% [markdown]
# # Day257

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=258>

# %% [markdown]
# # monitor
#
# 英\[ˈmɒnɪtə(r)\] 美\[ˈmɑːnɪtər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/monitor)**
#
# n. 显示屏，屏幕; [计]显示器; 监测仪; 监控人员，班长
#
# vt. 监控，监听; 搜集，记录; 测定; 监督
#
# vi. 监视
#
# **例句**：
#
# Follow up order , prepayment , tracking order delivery schedule . Insert POs to ERP Monitor and update there.
# 跟踪采购定单,跟踪及控制交货期, 付款及运输,维护更新系统定单状态.
#
# We may monitor all email communication to protect our business.
# 我们可以监控所有电子邮件通讯来保护我们的业务.

# %% [markdown]
# # finish
#
# 英\[ˈfɪnɪʃ\] 美\[ˈfɪnɪʃ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/finish)**
#
# vt.& vi. 完成; 结束; 吃光; 使筋疲力尽
#
# n. 结尾; 结束; 最后阶段; 抛光
#
# **例句**：
#
# You'd better finish it today.
# 你最好今天把它搞完.
#
# One way and another I'm going to finish this work before the end of the month.
# 无论如何,我打算在本月完成这项工作.

# %% [markdown]
# # keyed
#
# 英\[ki:d\] 美\[kid\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/keyed)**
#
# adj. （乐器）有键的; 定好音调的; 与…相宜的
#
# **例句**：
#
# I wasn't able to sleep that night, I was so keyed up.
# 那一夜我无法入睡，我太激动了。
#
# Brian keyed in his personal code.
# 布赖恩键入了他的个人密码。

# %% [markdown]
# # conventional
#
# 英\[kənˈvenʃənl\] 美\[kənˈvenʃənl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/conventional)**
#
# adj. 传统的; 习用的，平常的; 依照惯例的; 约定的
#
# **例句**：
#
# Suse latex foam pad is the back of conventional products.
# 素色垫背面发泡乳胶是常规产品.
#
# It was not that she had , in the conventional sense , any doubt of Mrs. Hatch's irreproachableness.
# 按传统的概念, 她并非怀疑哈琪太太行为不检.

# %% [markdown]
# # through
#
# 英\[θruː\] 美\[θruː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/through)**
#
# prep. 通过，穿过; 经由; 透过; 凭借
#
# adv. 从头到尾; 彻底; 自始至终
#
# adj. （电话）接通; 通话完毕; 有洞的; 直达的
#
# **例句**：
#
# Your behavior is causing our name to be dragged through the mud.
# 你的所作所为已经损坏了我们的名誉.
#
# He stumbled blindly on through the dark building.
# 他摸索着跌跌撞撞地穿过漆黑的建筑物.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. monitor
# 2. finish
# 3. keyed
# 4. conventional
# 5. through
