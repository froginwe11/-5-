# %% [markdown]
# # Day290

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=291>

# %% [markdown]
# # compatibility
#
# 英\[kəmˌpætəˈbɪləti\] 美\[kəmˌpætəˈbɪlətɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/compatibility)**
#
# n. 适合; 互换性; 通用性; 和睦相处
#
# **例句**：
#
# All UDDI Operator Sites must support all of the Unicode characters, including all compatibility characters.
# 所有的UDDI操作入口都必须支持全部的Unicode字符集, 这同样适用于那些兼容的字符.
#
# Processed landscape element compatibility design and material, technical and management adjustment relations.
# 处理景观元素适应性设计与材料, 技术及管理的调节关系.

# %% [markdown]
# # probably
#
# 英\[ˈprɒbəbli\] 美\[ˈprɑːbəbli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/probably)**
#
# adv. 大概; 或许; 很可能; 备不住
#
# **例句**：
#
# She probably dropped the parcel unawares.
# 她很可能无意中丢失了那包裹.
#
# We're going on holiday soon, probably next month.
# 我们很快要去度假了, 可能是下个月.

# %% [markdown]
# # input
#
# 英\[ˈɪnpʊt\] 美\[ˈɪnpʊt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/input)**
#
# n. 输入，投入; 输入电路; <电>输入端; 输入的数据
#
# vt. 把…输入电脑; [自][电子] 输入; 输入，给料
#
# **例句**：
#
# The computing methods of rainfall input and runoff flow concentration in grid elements are discussed deeply.
# 深入探讨了单元网格的降雨输入和产汇流计算方法.
#
# He gives an apriori argument pointing out that the MMH faces an " input problem. "
# 他并提出一先验论证批评大量模组假设面临 [ 输入问题 ].

# %% [markdown]
# # main
#
# 英\[meɪn\] 美\[meɪn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/main)**
#
# adj. 主要的，最重要的; 全力的
#
# n. 最主要的部分，重点; 主要管道; 体力; [航海]公海
#
# **例句**：
#
# We can sum up the main point of the lesson in three sentences.
# 我们可以用三句话来概括本课要点.
#
# He led the main strength of his army against the city.
# 他率领主力部队攻城.

# %% [markdown]
# # status
#
# 英\[ˈsteɪtəs\] 美\[ˈsteɪtəs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/status)**
#
# n. 地位; 情形，状态; 身份
#
# **例句**：
#
# We all are interested in the status of world affairs.
# 我们都关心世界形势.
#
# It was a lavish reception as befitted a visitor of her status.
# 这场铺张的招待可算得正适合她这种身份的来访者。

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. compatibility
# 2. probably
# 3. input
# 4. main
# 5. status
