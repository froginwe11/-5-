# %% [markdown]
# # Day294

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=295>

# %% [markdown]
# # numerous
#
# 英\[ˈnjuːmərəs\] 美\[ˈnuːmərəs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/numerous)**
#
# adj. 很多的，许多的; 数量庞大的; 数不清的
#
# **例句**：
#
# The scoundrel's crimes were too numerous to record.
# 这个歹徒罪行累累,罄竹难书.
#
# In a big department store, there are numerous departments selling different kinds of goods.
# 大百货公司里有许多部门分售各类商品.

# %% [markdown]
# # delimiter
#
# 英\[dɪ'lɪmɪtə\] 美\[dɪ'lɪmɪtə\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/delimiter)**
#
# n. 定界符，分隔符
#
# **例句**：
#
# Use the lists below to select the appropriate delimiter.
# 请用下面的列表选择相应的定界符.
#
# The Default Repeating Delimiter is limited to 100 characters in length.
# 默认重复分隔符的长度限于100个字符.

# %% [markdown]
# # depth
#
# 英\[depθ\] 美\[depθ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/depth)**
#
# n. 深度; 深处，深海; 深奥，奥妙; 进深
#
# **例句**：
#
# Most old overseas Chinese keep in the depth of their souls a longing for their motherland.
# 多数老华侨深深怀念祖国.
#
# Snow accumulated to a depth of five feet.
# 积雪达5英尺.

# %% [markdown]
# # usually
#
# 英\[ˈjuːʒuəli\] 美\[ˈjuːʒuəli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/usually)**
#
# adv. 通常，经常，平常，惯常地; 一直，向来; 动不动，一般; 素
#
# **例句**：
#
# Winds from the sea are usually moist.
# 海风通常是潮湿的.
#
# Such shoes usually wholesale for much less.
# 这种鞋批发出售通常要便宜得多.

# %% [markdown]
# # interpreter
#
# 英\[ɪnˈtɜːprətə(r)\] 美\[ɪnˈtɜːrprətər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/interpreter)**
#
# n. 解释者; 口译译员; [军事]判读员; [自]翻译器
#
# **例句**：
#
# I don't understand their language, so you have to as an interpreter.
# 我不懂他们的语言, 你不得不充当一个翻译.
#
# A translator always plays the role of an interpreter in the process of translation.
# 在翻译中,译者总是同时扮演着阐释者的角色.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. numerous
# 2. delimiter
# 3. depth
# 4. usually
# 5. interpreter
