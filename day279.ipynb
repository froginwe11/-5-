# %% [markdown]
# # Day279

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=280>

# %% [markdown]
# # future
#
# 英\[ˈfjuːtʃə(r)\] 美\[ˈfjuːtʃər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/future)**
#
# adj. 将来的，未来的; [语法学]将来时的; 将来发生的
#
# n. 将来; 未来; 未来的事; 前途
#
# **例句**：
#
# This is the prototype for future school buildings.
# 这是未来的学校建筑的蓝本.
#
# I look forward to hearing from you in the near future.
# 我盼望着不久收到你的信.

# %% [markdown]
# # beep
#
# 英\[bi:p\] 美\[bip\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/beep)**
#
# n. 哔哔声
#
# v. 嘟嘟响
#
# **例句**：
#
# Turn up the beep volume of the copier.
# 把复印机“哔”的音量放大.
#
# Please leave a message after the beep.
# 请在哔哔声之后留言.

# %% [markdown]
# # session
#
# 英\[ˈseʃn\] 美\[ˈseʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/session)**
#
# n. （议会等的）会议，会期; （法庭的）开庭; （某项活动的）一段时间，一场，一节; 学年
#
# adj. （音乐家）伴奏的
#
# **例句**：
#
# This is a recording session.
# 这是一段录音的时间.
#
# I'll be at the plenary session of the conference.
# 我将出席大会的全体会议.

# %% [markdown]
# # subject
#
# 英\[ˈsʌbdʒɪkt , səbˈdʒekt\] 美\[ˈsʌbdʒɪkt , səbˈdʒekt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/subject)**
#
# n. 主题，话题; 学科，科目; [哲]主观; 实验对象
#
# adj. 须服从…的; （在君主等）统治下的
#
# v. 提供，提出; 使…隶属
#
# **例句**：
#
# I shall have to read up on this subject if I am to give a talk about it.
# 如果我准备做一次关于这课题的讲座,我就必须把它彻底研究一番.
#
# This area is subject to earthquakes.
# 该地区常发生地震.

# %% [markdown]
# # window
#
# 英\[ˈwɪndəʊ\] 美\[ˈwɪndoʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/window)**
#
# n. 窗，窗户; 窗口; 〈美俚〉眼镜
#
# **例句**：
#
# It's a pity the room has no north window and you don't get a draught.
# 可惜这房间没北窗,没有过堂风.
#
# She flattened her nose and lips against the window.
# 她把鼻子和嘴唇紧贴着窗户.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. future
# 2. beep
# 3. session
# 4. subject
# 5. window
