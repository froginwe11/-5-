# %% [markdown]
# # Day110

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=111>

# %% [markdown]
# # consideration
#
# 英\[kənˌsɪdəˈreɪʃn\] 美\[kənˌsɪdəˈreɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/consideration)**
#
# n. 考虑，考察; 照顾，关心; 报酬; 尊敬
#
# **例句**：
#
# The suggestion merits serious consideration.
# 该建议值得认真考虑.
#
# I think the suggestion merits consideration.
# 我认为这个建议值得考虑.

# %% [markdown]
# # modifier
#
# 英\[ˈmɒdɪfaɪə(r)\] 美\[ˈmɑdɪfaɪə(r)\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/modifier)**
#
# n. 调节器; <语>修饰语
#
# **例句**：
#
# Physical modification methods of UHMWPE mainly included blending, rheological modifier and liquid crystal insitu composite modification.
# UHMWPE物理改性方法主要有共混改性 、 流动改性剂改性及液晶高分子原位复合材料改性.
#
# The paper introduces a new type composite modifier and modification technology.
# 介绍了一种新型复合变质剂及其变质工艺.

# %% [markdown]
# # landler
#
# 英\['lændlər\] 美\['lændlər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/landler)**
#
# n. 兰德勒舞（奥地利农村的民间舞），兰德勒舞曲
#
# **例句**：

# %% [markdown]
# # virtual
#
# 英\[ˈvɜːtʃuəl\] 美\[ˈvɜːrtʃuəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/virtual)**
#
# adj. 实质上的，事实上的; （计算机）虚拟的
#
# **例句**：
#
# We can use the principle of virtual power to establish consistent boundary conditions.
# 我们可以采用虚功率原理建立相容的边界条件.
#
# This new type of virtual instrument has simple hardware structure but has the comprehensive functions.
# 此套新型的虚拟仪器硬件结构简单,功能却很全面.

# %% [markdown]
# # report
#
# 英\[rɪˈpɔːt\] 美\[rɪˈpɔːrt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/report)**
#
# n. 报告; 成绩报告单; 传闻; 流言蜚语
#
# vt.& vi. 报道; 公布; 宣告
#
# vt. 告发，举报; 使报到
#
# **例句**：
#
# The report lays bare the shocking housing conditions in this city.
# 那份报告揭露了这座城巿恶劣的住房条件.
#
# The report takes a global view of the company's problems.
# 这份报告对公司的问题作了综合性的论述.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. consideration
# 2. modifier
# 3. landler
# 4. virtual
# 5. report
