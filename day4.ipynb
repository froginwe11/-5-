# %% [markdown]
# # Day4

# %% [markdown]
# # useless
#
# 英\[ˈjuːsləs\] 美\[ˈjuːsləs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/useless)**
#
# adj. 无用的，无效的; 无价值的; 差劲的; 不怎么样的
#
# **例句**：
#
# You must obey the rule. It is useless for you to kick against the pricks.
# 你必须遵守规定, 对抗对你是无益的.
#
# Our car was useless for want of petrol.
# 由于缺少汽油,我们的汽车派不上用场.

# %% [markdown]
# # explanation
#
# 英\[ˌekspləˈneɪʃn\] 美\[ˌekspləˈneɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/explanation)**
#
# n. 解释; 说明; 辩解; （消除误会后）和解
#
# **例句**：
#
# An explanation is clearly called for.
# 这里无疑需要一个解释.
#
# I had better say a few words by way of explanation.
# 我最好以解释的方式说几句话.

# %% [markdown]
# # programming
#
# 英\[ˈprəʊɡræmɪŋ\] 美\[ˈproʊɡræmɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/programming)**
#
# n. 规划，设计; 编程
#
# v. 训练( programme的现在分词 ); 培养; 预调
#
# **例句**：
#
# This allows a safer use mode and it can be used to detect programming errors.
# 这样就允许了一种安全的使用模式,它可以被用于检测程序的错误.
#
# Programming and debug fixtures are available as options.
# 编程和调试设备可作为选择.

# %% [markdown]
# # returned
#
# 英\[rɪ'tɜ:nd\] 美\[rɪ'tɜnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/returned)**
#
# adj. 被送回的，归来的
#
# v. 返回，回来( return的过去式和过去分词 ); 恢复; 还; 归还
#
# **例句**：
#
# The waiter returned with their order and Graham signed the bill.
# 侍者把他们点的餐端了过来，格雷厄姆签了单。
#
# He was returned to prison in 1977 for impersonating a police officer.
# 他1977年因冒充警官而再次入狱。

# %% [markdown]
# # sensitive
#
# 英\[ˈsensətɪv\] 美\[ˈsensətɪv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sensitive)**
#
# adj. 敏感的; 感觉的; [仪]灵敏的; 易受影响的
#
# **例句**：
#
# This speech touched him on his most sensitive spot.
# 这个发言击中了他的痛处.
#
# There was a careful avoidance of the sensitive topic in the scholastic circles.
# 学术界小心地避开那个敏感的话题.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. useless
# 2. explanation
# 3. programming
# 4. returned
# 5. sensitive
