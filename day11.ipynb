# %% [markdown]
# # Day11

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=12>

# %% [markdown]
# # different
#
# 英\[ˈdɪfrənt\] 美\[ˈdɪfrənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/different)**
#
# adj. 不同的; 各式各样的; 个别的; 不平常
#
# **例句**：
#
# The boy's manner of speech jarred on the teacher, who came from a different part of the country.
# 那孩子说话的神态令那位来自外地的老师感到不舒服.
#
# We grow many different vegetables: potatoes, eggplant, etc.
# 我们种了许多不同的蔬菜,如土豆 、 茄子等.

# %% [markdown]
# # reference
#
# 英\[ˈrefrəns\] 美\[ˈrefrəns\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reference)**
#
# n. 参考; 参考书; 提及，涉及; 证明人，介绍人
#
# v. 引用; 参照
#
# **例句**：
#
# The library contains a large number of foreign language reference books.
# 图书馆有大量的外文参考书.
#
# We spent days going through all related reference material.
# 我们花了好多天功夫查阅所有有关的参考资料.

# %% [markdown]
# # hierarchical
#
# 英\[ˌhaɪəˈrɑ:kɪkl\] 美\[ˌhaɪəˈrɑrkɪkl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hierarchical)**
#
# adj. 按等级划分的，等级（制度）的; 分层的
#
# **例句**：
#
# The hierarchical model was developed because hierarchical relationships are commonly found in business applications.
# 由于级别关系在企业运营中十分普遍,分级模式被发展起来.
#
# Hierarchical road map considering the uneven feature of terrain and its establishment.
# 顾及地形起伏信息的三维层次道路图模型及其构建方法.

# %% [markdown]
# # yet
#
# 英\[jet\] 美\[jet\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/yet)**
#
# adv. 但是; 还; 已经; 又，再
#
# conj. 然而，但是
#
# **例句**：
#
# Have we got to the zoo yet?
# 我们到动物园了 吗 ?
#
# Have you finished loading up yet?
# 你把货物装好了 吗 ?

# %% [markdown]
# # summary
#
# 英\[ˈsʌməri\] 美\[ˈsʌməri\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/summary)**
#
# n. 摘要，概要; 总结，一览
#
# adj. 概括的，总结的; 即刻的，立即的
#
# **例句**：
#
# I would like to know all of their own this year, the general summary of what?
# 我想知道大家对自己这一年的大体总结是什么?
#
# Table 1. 5 presents a broader summary of the price trends since 1950.
# 表1.5提供了1950年以来价格趋势的更广泛的概况.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. different
# 2. reference
# 3. hierarchical
# 4. yet
# 5. summary
