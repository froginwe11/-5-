# %% [markdown]
# # Day192

# %% [markdown]
# # field
#
# 英\[fiːld\] 美\[fiːld\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/field)**
#
# n. 田; （作某种用途的）场地; （学习或研究的）领域; 运动场
#
# vi. [棒球、板球等]担任外场员，担任守队队员; 接守，接防; 接，掷还（球）
#
# vt. 保护; 把（农作物等）晒在场上; [棒球、板球等]按（或截）（球）; 即席圆满回答
#
# **例句**：
#
# He is recognized internationally as an authority in this field.
# 国际上承认他是这方面的一个权威.
#
# At the approach of cold weather, the troops were unable to keep holding the field.
# 寒冷的天气到来时, 部队无力继续作战.

# %% [markdown]
# # labeled
#
# 英\['leɪbld\] 美\['leɪbld\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/labeled)**
#
# [医]标记的，示踪的
#
# **例句**：
#
# On the customs declaration, the sender labeled the freight as agricultural machinery.
# 在报关单上，寄货人将货物列为农用机械。
#
# She labeled the case with her name and address.
# 她在箱子上贴有自己姓名地址的标签.

# %% [markdown]
# # stated
#
# 英\['steɪtɪd\] 美\['steɪtɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/stated)**
#
# adj. 定期的，规定的，一定的
#
# v. 规定( state的过去式和过去分词 ); 陈述; 确定; [法律]详述（案情等）
#
# **例句**：
#
# My reasons were stated in writing and circulated to all committee members.
# 我提出的几个理由以书面形式呈现，在所有委员会成员中传阅。
#
# The aims of the treaty are stated in its preamble.
# 条约的宗旨已在序言中说明。

# %% [markdown]
# # substantial
#
# 英\[səbˈstænʃl\] 美\[səbˈstænʃl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/substantial)**
#
# adj. 大量的; 结实的，牢固的; 重大的
#
# **例句**：
#
# The country bought a substantial number of weapons.
# 这个国家购买了大量武器.
#
# Those workers have built many substantial buildings in the recent years.
# 近几年那些工人建造了许多坚固的建筑.

# %% [markdown]
# # matching
#
# 英\[ˈmætʃɪŋ\] 美\[ˈmætʃɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/matching)**
#
# v. 使…相配(match的ing形式)
#
# adj. 相配的; 一致的; 相称的
#
# **例句**：
#
# Whatever matched the sub - expression is split out in a separate field by the matching algorithms.
# 子表达式匹配的部分会被匹配算法单独分离出去.
#
# A busload of volunteers in matching red hats was bumping along the village's rutted dirt road.
# 一辆满载戴着统一红帽的志愿者的汽车也在乡间绵延土路颠簸而来.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. field
# 2. labeled
# 3. stated
# 4. substantial
# 5. matching
