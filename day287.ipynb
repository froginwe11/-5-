# %% [markdown]
# # Day287

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=288>

# %% [markdown]
# # inverse
#
# 英\[ˌɪnˈvɜːs\] 美\[ˌɪnˈvɜːrs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/inverse)**
#
# adj. 相反的; 逆向的; 倒转的
#
# **例句**：
#
# The inverse beamforming ( IBF ) algorithm is simple and easy to be used in the practical engineering.
# 本文给出的逆波束形成 ( IBF ) 方法具有抗多途效应效果好、算法简单、易于工程实现等优点.
#
# In this paper, we will mainly discuss two inverse problems about curve.
# 本文主要讨论了两个与曲线有关反问题.

# %% [markdown]
# # translation
#
# 英\[trænzˈleɪʃn\] 美\[trænzˈleɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/translation)**
#
# n. 翻译; 译本; 转变; 转化
#
# **例句**：
#
# Try to catch the elusive charm of the original in translation.
# 翻译时设法把握住原文中难以捉摸的风韵.
#
# The translation does not quite correspond to the original.
# 译文不切原意.

# %% [markdown]
# # hex
#
# 英\[heks\] 美\[heks\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hex)**
#
# v. 施魔法于，施魔法
#
# **例句**：
#
# Everyone else was no match for hex in Beauty.
# 没有谁能比得上她的美貌.
#
# HEX file format conversion tool for BIN file format of the code.
# 一个将HEX文件 格式转换成BIN文件格式的工具的源代码.

# %% [markdown]
# # want
#
# 英\[wɒnt\] 美\[wɑːnt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/want)**
#
# v. 想要; 希望; 打算; 需要…在场
#
# n. 需要的东西; 缺少; 贫穷
#
# **例句**：
#
# I want to apply for the job.
# 我想申请这项工作.
#
# I don't want to be associated with your scheme; I'm contracting out.
# 我不想参与你们的计划, 我要退出.

# %% [markdown]
# # scope
#
# 英\[skəʊp\] 美\[skoʊp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/scope)**
#
# n. （处理、研究事务的）范围; 眼界，见识; （活动或能力的）余地; 广袤，地域
#
# v. 审视，仔细研究
#
# **例句**：
#
# Scope: Weaving Freight car . Weaving . Freight car.
# 经营范围: 织布. 汽车货运.
#
# Completing the declarations of class Outer puts the declaration of the function handle in scope.
# 对Outer类声明的完成将函数handle的声明放在作用域中.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. inverse
# 2. translation
# 3. hex
# 4. want
# 5. scope
