# %% [markdown]
# # Day149

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=150>

# %% [markdown]
# # secondary
#
# 英\[ˈsekəndri\] 美\[ˈsekənderi\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/secondary)**
#
# adj. 第二的，中等的; 助手，副手; 中等教育的; 间接的
#
# **例句**：
#
# The relationship between impact toughness and tempering temperature indicated secondary tempering brit - tleness peak at between 570 - 580.
# 试验确认20MnSi螺纹钢筋的第二类回火脆性产生温度在570～580.
#
# This product condensation, and never can be the construction of secondary water mixing.
# 本品凝结后, 决不可二次加水搅拌施工.

# %% [markdown]
# # order
#
# 英\[ˈɔːdə(r)\] 美\[ˈɔːrdər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/order)**
#
# n. 命令; 秩序; 规则，制度; 次序
#
# vt. 命令; 订购; 整理
#
# vi. 下订单
#
# **例句**：
#
# Opportunism consists of sacrificing fundamental interests in order to gain temporary, partial benefits.
# 机会主义就是牺牲根本的利益,贪图暂时的 、 局部的利益.
#
# She would pinch on food in order to spend on clothing.
# 她过去常把伙食费省下来买衣服.

# %% [markdown]
# # bus
#
# 英\[bʌs\] 美\[bʌs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/bus)**
#
# n. 公共汽车; 巴士; 大客车
#
# v. 用公共汽车运送; 乘公共汽车; 用校车送; 收拾 （餐桌）
#
# **例句**：
#
# I will run you in if the bus isn't going into the town because of the snow today.
# 如果今天公共汽车因为下雪不送你进城的话,我会开车送你去的.
#
# The bus stop is few yards below the post office.
# 公共汽车站在邮局向南几码的地方.

# %% [markdown]
# # title
#
# 英\[ˈtaɪtl\] 美\[ˈtaɪtl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/title)**
#
# n. 标题; 头衔; [体]冠军; [影视]字幕
#
# vt. 加标题; 赋予头衔; 把…称为
#
# **例句**：
#
# With no direct descendent, who will succeed to the title?
# 没有直系后裔, 谁来继承爵位 呢 ?
#
# He is worthy of the title of labour hero.
# 劳动英雄的称号,他当之无愧.

# %% [markdown]
# # exceeded
#
# 英\[ɪk'si:dɪd\] 美\[ɪk'sidɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/exceeded)**
#
# adj. 过度的，非常的
#
# v. 超过( exceed的过去式和过去分词 ); 超越; （在数量和质量等方面）胜过; 越过…的界限
#
# **例句**：
#
# Three of the six have comfortably exceeded their normal life expectancy.
# 6人中已经有3人轻松超过了正常的预期寿命。
#
# Their total grain output still exceeded that of the previous year.
# 他们的粮食总产量仍超过头一年.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. secondary
# 2. order
# 3. bus
# 4. title
# 5. exceeded
