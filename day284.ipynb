# %% [markdown]
# # Day284

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=285>

# %% [markdown]
# # fixed
#
# 英\[fɪkst\] 美\[fɪkst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/fixed)**
#
# adj. 固定的，不变的; 不易挥发的; 处境…的，常作复合词; （比赛等）通过作弊预先安排好结果的
#
# v. 固定( fix的过去式和过去分词)
#
# **例句**：
#
# The marriage was fixed for the 7 th June.
# 婚期定于6月7日.
#
# All eyes are fixed upon Asia as the Land of Promise for millions yet unborn.
# 全世界都盯着亚洲,把她看做未来千万生灵的乐土.

# %% [markdown]
# # retain
#
# 英\[rɪˈteɪn\] 美\[rɪˈteɪn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/retain)**
#
# vt. 保持; 留在心中，记住; 雇用; 付定金保留
#
# **例句**：
#
# Thus owners can end up suffering dilution just to retain those who turn up every week.
# 因此到最后,所有者为了挽留那些每周才露一次面的人,只好忍受稀释之痛.
#
# Some of are enthusiastic at some time and other retain for a day or a week.
# 一些人时不时有点热情,少数人能够维持一天至一周的热情.

# %% [markdown]
# # issue
#
# 英\[ˈɪʃuː\] 美\[ˈɪʃuː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/issue)**
#
# n. 问题; （报刊的）期，号; 发行物; 流出
#
# vt. 发行; 发布; 流出
#
# vi. 发行; 造成…结果; 在…上挑起争论
#
# **例句**：
#
# He has taken a public stand on the issue of misuse of hospital funds.
# 在滥用医院资金问题上,他采取公开的反对态度.
#
# He's the boss in name only, because I issue all the orders.
# 他只是名义上的老板, 所有的命令都是我下的.

# %% [markdown]
# # world
#
# 英\[wɜːld\] 美\[wɜːrld\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/world)**
#
# n. 世界; 地球; 领域; 尘世
#
# **例句**：
#
# We ought to face the world and brave the storm.
# 我们应该经风雨,见世面.
#
# The entire world consists of matter.
# 整个世界都是由物质组成的.

# %% [markdown]
# # override
#
# 英\[ˌəʊvəˈraɪd\] 美\[ˌoʊvərˈraɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/override)**
#
# vt. 推翻，无视; 践踏; 优先于; 覆盖
#
# **例句**：
#
# Whoever modified it must have given it the ability to override my direct control.
# 被改进过的型号一定被赋予了违背我直接命令的能力.
#
# Derived classes cannot override an interface member implemented in a base class.
# 派生类不能重写在基类里面实现的接口成员.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. fixed
# 2. retain
# 3. issue
# 4. world
# 5. override
