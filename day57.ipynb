# %% [markdown]
# # Day57

# %% [markdown]
# # redraw
#
# 英\[ˌri:ˈdrɔ:\] 美\[ˌriːˈdrɔː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/redraw)**
#
# v. 重画; 刷新屏幕
#
# **例句**：
#
# There is not enough memory to redraw the screen. Save your work and close other programs.
# 内存不足,无法重绘屏幕. 请保存您的工作并关闭其他程序.
#
# XHTML is the W 3 C's attempt to redraw lines blurred by browser makers.
# XHTML就是W3C的一次尝试,重新划定由浏览器制造者弄模糊的界限.

# %% [markdown]
# # module
#
# 英\[ˈmɒdjuːl\] 美\[ˈmɑːdʒuːl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/module)**
#
# n. 模块; 组件; （宇宙飞船上各个独立的）舱; 测量流水等的单位
#
# **例句**：
#
# Unplug the existing cable from the NMT Interface connector on the RF module, if necessary.
# 如果必要,从RF模块上的NMTInterface连接器上拔下现有的电缆.
#
# The author has designed a relevant analysis calculation program module, which has been testified by experiments.
# 设计了相应的分析计算模块, 用实验进行了验证.

# %% [markdown]
# # endeavor
#
# 英\[ɪnˈdɛvə\] 美\[ɪnˈdɛvər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/endeavor)**
#
# vt.& vi. 尝试，试图; 尽力，竭力
#
# n. 努力，尽力
#
# **例句**：
#
# Entertains the most high hope. for the greatest endeavor. makes the worst plan.
# 抱最大的希望. 为最大的努力. 做最坏的打算.
#
# But make no mistake: This cannot solely be America's endeavor.
# 但必须指出的是,这不仅仅是美国的事务.

# %% [markdown]
# # simply
#
# 英\[ˈsɪmpli\] 美\[ˈsɪmpli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/simply)**
#
# adv. 简单地，朴素地; （引出概括或解释）不过，仅仅; 简直; <非正>实在
#
# **例句**：
#
# The name simply didn't register with me.
# 我对这个名字简直没有印象.
#
# You simply must go.
# 你必得去一趟.

# %% [markdown]
# # consequently
#
# 英\[ˈkɒnsɪkwəntli\] 美\[ˈkɑːnsɪkwentli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/consequently)**
#
# adv. 所以，因此; 因此，因而; 终于，这样; 合乎逻辑的推论是
#
# **例句**：
#
# Consequently, it cannot be the cause of the superconductivity.
# 因此, 它无法成为超导性质的起因.
#
# The goods are in short supply, consequently the market will probably rise next week.
# 这种货物供应不足, 因此下周市场行情可能看涨.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. redraw
# 2. module
# 3. endeavor
# 4. simply
# 5. consequently
