# %% [markdown]
# # Day301

# %% [markdown]
# # avoid
#
# 英\[əˈvɔɪd\] 美\[əˈvɔɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/avoid)**
#
# vt. 避开，避免，预防; [法]使无效，撤销，废止
#
# **例句**：
#
# The driver has swerved on a sudden to avoid a file of geese.
# 为了躲避一队鹅,司机突然来个急转弯.
#
# I'd like to avoid a showdown with my boss if I possibly can.
# 我尽可能地避免同老板摊牌.

# %% [markdown]
# # bottom
#
# 英\[ˈbɒtəm\] 美\[ˈbɑːtəm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/bottom)**
#
# n. 底部; 末端; 臀部; 尽头
#
# adj. 底部的
#
# **例句**：
#
# The river slows on the flat bottom.
# 河水在平坦的河床上减慢了流速.
#
# The bottom of the bucket has worn through after all this time.
# 经过这么长时间,这只桶的底部终于磨穿了.

# %% [markdown]
# # typewriter
#
# 英\[ˈtaɪpraɪtə(r)\] 美\[ˈtaɪpraɪtər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/typewriter)**
#
# n. 打字机
#
# **例句**：
#
# A typewriter in which the characters are situated on a type cylinder.
# 字符位于打印筒上的一种打字机.
#
# A: Did you get me a typewriter ribbon?
# 你给我买了打字机的色带 吗 ?

# %% [markdown]
# # minus
#
# 英\[ˈmaɪnəs\] 美\[ˈmaɪnəs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/minus)**
#
# prep. （表示否定）没有; 缺少; （表示运算）减去; （表示数目）在零度以下
#
# n. 减号; 负号; 不利; 不足
#
# adj. 负的; 不利的; 略低于某标准的
#
# **例句**：
#
# With the chill factor, it's nearly minus forty here.
# 加上风寒指数, 气温接近零下40度.
#
# Don't forget the minus sign.
# 不要忘记那个负号.

# %% [markdown]
# # restricted
#
# 英\[rɪˈstrɪktɪd\] 美\[rɪˈstrɪktɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/restricted)**
#
# adj. 有受限制的; （土地）对公众不完全开放的; 保密的
#
# v. 限制( restrict的过去式)
#
# **例句**：
#
# Secondly, it is a good sign that you feel dissatisfied and restricted by your vocabulary.
# 其次, 如果你对自己的词汇量不满那真是个好现象.
#
# He has a severely restricted diet.
# 他严格控制饮食.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. avoid
# 2. bottom
# 3. typewriter
# 4. minus
# 5. restricted
