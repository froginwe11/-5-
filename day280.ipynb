# %% [markdown]
# # Day280

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=281>

# %% [markdown]
# # sure
#
# 英\[ʃʊə(r)\] 美\[ʃʊr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sure)**
#
# adj. 确信的，确实的; 有把握的; 无疑的; 一定的
#
# adv. 当然; 确实地; 无疑地
#
# **例句**：
#
# Never mind, next time I'm sure you can do better.
# 不要紧, 我相信你下一次一定能做得好些的.
#
# The doctor is sure to pull her through.
# 医生一定能使她康复.

# %% [markdown]
# # offer
#
# 英\[ˈɒfə(r)\] 美\[ˈɔːfər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/offer)**
#
# vt. 提供，给予; 提出，提议; 出价，开价; 表示愿意
#
# vi. 提议; 企图，想要; 供奉
#
# n. 提议; 出价，开价; 试图; 求婚
#
# **例句**：
#
# In the light of his remarks, we rejected her offer.
# 鉴于他的评语, 我们拒绝了她的提议.
#
# We have to offer higher rates.
# 我们不得不付更高的价钱.

# %% [markdown]
# # telephone
#
# 英\[ˈtelɪfəʊn\] 美\[ˈtelɪfoʊn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/telephone)**
#
# n. 电话; 电话机; （电话机的）话筒; 受话器
#
# vt.& vi. 以电话传送（消息），给（某人）打电话; 用电话与（某人）交谈
#
# **例句**：
#
# I put the telephone down and took up my work again.
# 我放下电话继续干我的活.
#
# Someone has been listening in to our telephone conversation.
# 有人一直在窃听我们的电话谈话.

# %% [markdown]
# # unsigned
#
# 英\['ʌn'saɪnd\] 美\[ʌn'saɪnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unsigned)**
#
# adj. 无符号的，无正负之分的
#
# **例句**：
#
# The envelope contained a typed, unsigned letter demanding £75,000 in cash.
# 信封里装着一封打印的、没签名的信，索要75,000英镑。
#
# Scholars ascribe the unsigned painting to Rubens.
# 学者们认为这幅无落款的画的作者是鲁本斯.

# %% [markdown]
# # indefinitely
#
# 英\[ɪnˈdefɪnətli\] 美\[ɪnˈdefɪnətli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/indefinitely)**
#
# adv. 无限期地; 不定期地; 不明确地; 遥遥无期地
#
# **例句**：
#
# This could go on indefinitely.
# 这是否可以继续下去,尚不确定.
#
# This guaranteed that the best and brightest minds could be of use to society indefinitely.
# 如此就保证了最优秀和最精英的头脑可以无限期地为社会做贡献.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. sure
# 2. offer
# 3. telephone
# 4. unsigned
# 5. indefinitely
