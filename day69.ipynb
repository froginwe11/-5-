# %% [markdown]
# # Day69

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=70>

# %% [markdown]
# # receive
#
# 英\[rɪˈsiːv\] 美\[rɪˈsiːv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/receive)**
#
# vt.& vi. 收到; 接到; 接纳; 接待
#
# vt. 接收; 受理; 欢迎; 承受
#
# vi. 接到，获得; 接见，欢迎; [电子学] 接收; [橄榄球] 接球
#
# **例句**：
#
# Then he smiled and told me I would receive an extra ￡100 a year!
# 后来他笑了,并且告诉我说,我将一年收到一百英镑的额外收入!
#
# The managing director agreed to receive a deputation from the factory.
# 总经理同意接见工厂派来的代表团.

# %% [markdown]
# # unchanged
#
# 英\[ʌnˈtʃeɪndʒd\] 美\[ʌnˈtʃeɪndʒd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unchanged)**
#
# adj. 未改变的，无变化的，依然如故的
#
# **例句**：
#
# Apart from the hair, he looked extraordinarily unchanged.
# 令人惊奇的是，除了头发，他看起来一点儿都没变。
#
# For many years prices have remained virtually unchanged.
# 价格多年来几乎没变。

# %% [markdown]
# # numeral
#
# 英\[ˈnjuːmərəl\] 美\[ˈnuːmərəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/numeral)**
#
# n. 数词，数字
#
# **例句**：
#
# This numeral means a onefold increase in production.
# 这个数字意味着产量提高了一倍.
#
# A table comparing numerals in two different numeral systems.
# 一种可以比较两种不同数制中的数字的表格.

# %% [markdown]
# # dependent
#
# 英\[dɪˈpendənt\] 美\[dɪˈpendənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/dependent)**
#
# adj. 依靠的; 依赖的; 取决于…的; 有瘾的
#
# **例句**：
#
# The company is dependent on government financial help.
# 这家公司依靠政府的财政援助.
#
# The charity is totally dependent on the Church's bounty.
# 慈善业完全依靠全体基督徒的慷慨赠予.

# %% [markdown]
# # pointer
#
# 英\[ˈpɔɪntə(r)\] 美\[ˈpɔɪntɚ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/pointer)**
#
# n. 建议; 线索; 教鞭; （测量仪器上的）指针
#
# **例句**：
#
# Led Torch , Head Light, Keychain, Drink Promotional Items, Laser Pointer, Medical Products Emergency Lights.
# 采购产品手电筒, 头光, 钥匙链, 饮料宣传品, 激光指针, 医疗产品,紧急照明灯.
#
# Accordingly, this library also provides improved versions of the standard function pointer adapters.
# 因此, 本库也提供了标准函数指针适配器的改良版本.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. receive
# 2. unchanged
# 3. numeral
# 4. dependent
# 5. pointer
