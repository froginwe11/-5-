# %% [markdown]
# # Day212

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=213>

# %% [markdown]
# # spill
#
# 英\[spɪl\] 美\[spɪl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/spill)**
#
# vt.& vi. 溢出; 泼出; 涌出; 蜂拥而出
#
# vt. 使跌落; 泄露机密
#
# n. 洒出（量）; 泼出（量）; 溢出（量）; 小塞子
#
# **例句**：
#
# Well , Bella , looks like you took quite a spill. How do you feel?
# 好吧Bella看起来你摔的不轻觉得 怎么样 ?
#
# Waiters should know how to deal with spill.
# 侍者应懂得如何处理液体外溢.

# %% [markdown]
# # floppy
#
# 英\[ˈflɒpi\] 美\[ˈflɑpi\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/floppy)**
#
# adj. 松软的; 懒散的
#
# **例句**：
#
# Yes, floppy day , as did 9600 baud dial up modems.
# 是的, 当时软件是最主要的工具,还有9600波特拨号调制解调器.
#
# Click OK. When the computer restarts, remove the Client Add Pack floppy disk.
# 单击[确定]. 当计算机重新启动时, 请取出客户端许可证添加软件包软盘.

# %% [markdown]
# # eventually
#
# 英\[ɪˈventʃuəli\] 美\[ɪˈventʃuəli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/eventually)**
#
# adv. 终于，最后; 竟; 总归; 终究
#
# **例句**：
#
# He was eventually brought to book for his treachery.
# 他终于因叛变行为而受到惩罚.
#
# I eventually arrived at my destination.
# 我终于到达了目的地.

# %% [markdown]
# # recoverable
#
# 英\[rɪˈkʌvərəbl\] 美\[rɪˈkʌvərəbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/recoverable)**
#
# adj. 可重获的
#
# **例句**：
#
# Travel expenses will be recoverable from the company.
# 差旅费用可到公司报销。
#
# If you decide not to buy, the money you have spent on the survey is not recoverable.
# 如果你决定不买，你在调查上花的钱是收不回来的。

# %% [markdown]
# # splitting
#
# 英\[ˈsplɪtɪŋ\] 美\[ˈsplɪtɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/splitting)**
#
# adj. 爆裂似的，极快的
#
# v. （使）裂开， （使）破裂( split的现在分词 ); 分裂; 分开; [俚语]（迅速）离开
#
# **例句**：
#
# I thought the implication was that they were splitting up.
# 我想这潜在的意思就是他们分手了.
#
# PWM wave is generated by splitting Zero vector quasi circular locus method.
# 该系统用零矢量分割的准圆轨迹法生成PWM波形.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. spill
# 2. floppy
# 3. eventually
# 4. recoverable
# 5. splitting
