# %% [markdown]
# # Day56

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=57>

# %% [markdown]
# # pass
#
# 英\[pɑːs\] 美\[ pæs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/pass)**
#
# vt.& vi. 走过; 通过; 批准; 度过
#
# vt. 传球; 及格; 发生; 不要
#
# n. 通道; 通行证; 关口; 越过
#
# **例句**：
#
# May I trouble you to pass on a message to her?
# 烦您给她捎个信儿.
#
# The teacher began to pass out the papers at 8:15.
# 8点15分老师开始发卷.

# %% [markdown]
# # stop
#
# 英\[stɒp\] 美\[stɑːp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/stop)**
#
# vi. 停止; 中断; 逗留; （使）停止工作
#
# vt. 塞住; 堵塞; 阻挠; 止付
#
# n. 停止; （管风琴的）音栓; 停车站; （管风琴的）音管
#
# **例句**：
#
# Stop fussing about; the bus will arrive on time.
# 别慌, 公共汽车会准时到达.
#
# I wish you'd stop trying to butter me up.
# 我希望你不要再恭维我了.

# %% [markdown]
# # therefore
#
# 英\[ˈðeəfɔː(r)\] 美\[ˈðerfɔːr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/therefore)**
#
# adv. 因此; 所以; 故; 乃
#
# **例句**：
#
# Therefore need to select one of the best reverberation time.
# 因此需要选择一个最佳混响时间.
#
# Pilfering is therefore impossible.
# 因此偷窃是不可能发生的.

# %% [markdown]
# # entire
#
# 英\[ɪnˈtaɪə(r)\] 美\[ɪnˈtaɪər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/entire)**
#
# adj. 全部的; 整个的; 全体的; 囫囵
#
# **例句**：
#
# The entire world consists of matter.
# 整个世界都是由物质组成的.
#
# The entire committee will talk over the proposal.
# 全体委员会将讨论这项建议.

# %% [markdown]
# # dos
#
# 英
#
# **[释义](https://fanyi.baidu.com/#en/zh/dos)**
#
# abbr. dosage 剂量; dose 剂量; dosiology 剂量学; dosimetric 放射量测定的
#
# **例句**：
#
# They always have all-night dos there.
# 他们经常在那儿闹通宵。
#
# Where do I find the instructions to load DOS programs from Windows 98?
# 我从哪儿可以找到从Windows98载入DOS程序的指令呢？

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. pass
# 2. stop
# 3. therefore
# 4. entire
# 5. dos
