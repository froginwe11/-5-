# %% [markdown]
# # Day321

# %% [markdown]
# # collapse
#
# 英\[kəˈlæps\] 美\[kəˈlæps\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/collapse)**
#
# vi. 折叠; 倒塌; 崩溃; （尤指工作劳累后）坐下
#
# vt. 使倒塌; 使坍塌; 使瓦解
#
# n. 垮台; （身体的）衰弱
#
# **例句**：
#
# The earthquake was the occasion of the building's collapse.
# 地震是房屋倒塌的起因.
#
# The wall is going to collapse.
# 这堵墙要垮了.

# %% [markdown]
# # device
#
# 英\[dɪˈvaɪs\] 美\[dɪˈvaɪs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/device)**
#
# n. 装置，设备; 方法; 策略; 手段
#
# **例句**：
#
# The police suspect that the device is not a real bomb but a dummy.
# 警方怀疑那个装置不是真炸弹,只是一个假货.
#
# The device will be in production by the end of the year.
# 该装置将于年底投入生产.

# %% [markdown]
# # accuracy
#
# 英\[ˈækjərəsi\] 美\[ˈækjərəsi\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/accuracy)**
#
# n. 精确（性），准确（性）
#
# **例句**：
#
# In journalism, timeliness and accuracy should be equally important.
# 在新闻杂志业中, 及时与准确应该同等重要.
#
# The accuracy of CBM recovery factor prediction will directly influence the calculation of recoverable reserves.
# 煤层气预测采收率准确与否,直接影响着可采储量的计算精度.

# %% [markdown]
# # much
#
# 英\[mʌtʃ\] 美\[mʌtʃ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/much)**
#
# adv. 非常; 差不多; 很多地; 很大程度上
#
# pron. 很多; 大量; 很好的东西; （与不可数名词连用，尤用于否定句，或与 how 连用以询问数量，也可与 as、so 和 too 连用）许多
#
# **例句**：
#
# There is much noise in this radio.
# 这收音机杂音很多.
#
# Courtesy costs little and means much.
# 礼节并不失去什么却获益甚多.

# %% [markdown]
# # scroll
#
# 英\[skrəʊl\] 美\[skroʊl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/scroll)**
#
# n. （常用于录写正式文件的）纸卷; 书卷，画卷，卷轴; 涡卷形（装饰）; 〈古〉表，目录
#
# vt. 使成卷形; （电脑屏幕上）从上到下移动（资料等），卷页
#
# vi. （似卷轴般）卷起; （像展开卷轴般地）将文字显示于屏幕
#
# **例句**：
#
# Scroll tells also about power full guardians which can be created by using that artifact.
# 卷轴还提到了用这块石头创造的强大的卫兵.
#
# The analyses of some real scroll case structures through the simulating models.
# 通过所建立的仿真模型对实际水电站蜗壳结构进行分析.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. collapse
# 2. device
# 3. accuracy
# 4. much
# 5. scroll
