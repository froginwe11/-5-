# %% [markdown]
# # Day317

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=318>

# %% [markdown]
# # alter
#
# 英\[ˈɔːltə(r)\] 美\[ˈɔːltər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/alter)**
#
# vt. 改变; 更改; 改建（房屋）; （人）变老
#
# vi. 改变; 修改
#
# **例句**：
#
# During meditation brain waves alter.
# 冥想时的脑波改变.
#
# A Book publisher may alter or abridge a work with the permission of the copyright owner.
# 图书出版者经版权拥有者许可,可以对作品修改或删节.

# %% [markdown]
# # capitalized
#
# 英\['kæpɪtəlɑɪzd\] 美\['kæpɪtəlɑɪzd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/capitalized)**
#
# n. [计]大写的
#
# v. 用大写字母写或印刷( capitalize的过去式和过去分词 ); 将（某事物）转作资本、用作资本或资本化
#
# **例句**：
#
# The company will be capitalized at £2 million.
# 该公司将以200万英镑的价格出售。
#
# We capitalized our assets to avoid bankruptcy.
# 我们把资产转作资金以避免破产。

# %% [markdown]
# # definition
#
# 英\[ˌdefɪˈnɪʃn\] 美\[ˌdefɪˈnɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/definition)**
#
# n. 定义; 规定，明确; [物]清晰度; 解释
#
# **例句**：
#
# In the job definition, use two single quotation marks around strings.
# 在任务定义中, 用2个单引号包围字符串.
#
# Thus this specification is a definition of the syntax and semantics of the XSLT namespace.
# 因些本规范是一个XSLT命名空间的语法和语义的定义.

# %% [markdown]
# # marking
#
# 英\[ˈmɑ:kɪŋ\] 美\[ˈmɑrkɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/marking)**
#
# n. 标记，记号; （支票的）认付; 斑纹; 批改，打分
#
# **例句**：
#
# Every tribe has its own traditions for marking a cub's passage into adulthood.
# 每个部族都有自己的办法给成年的幼仔留下印记.
#
# Marking the main assessment criteria which fall on the material.
# 阅卷主要评定标准也落在材料当中.

# %% [markdown]
# # cache
#
# 英\[kæʃ\] 美\[kæʃ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/cache)**
#
# n. 藏物处; 隐藏处; 藏匿的珍宝; <电脑>快速缓冲贮存区
#
# vt. 贮藏
#
# vi. 躲藏
#
# **例句**：
#
# It'served as an emergency cache should Alderaan ever need to take up arms again.
# 这艘船将成为奥德兰需要重新拾起武装时的紧急储藏所.
#
# Police discovered a cache of weapons in the room.
# 警方在房间里发现了一批隐藏的武器.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. alter
# 2. capitalized
# 3. definition
# 4. marking
# 5. cache
