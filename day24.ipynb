# %% [markdown]
# # Day24

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=25>

# %% [markdown]
# # also
#
# 英\[ˈɔːlsəʊ\] 美\[ˈɔːlsoʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/also)**
#
# adv. 也; 同样; 并且
#
# **例句**：
#
# Problems also exist in agriculture.
# 农业也存在着一些问题.
#
# This is due to the enemy's underestimation of China and also to his shortage of troops.
# 这是由于敌人对中国估计不足而来的,也有他自己兵力不足的原因.

# %% [markdown]
# # argument
#
# 英\[ˈɑːɡjumənt\] 美\[ˈɑːrɡjumənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/argument)**
#
# n. 争论，争吵; 论据; [数]幅角; 主题，情节
#
# **例句**：
#
# It is difficult to relate his argument to the facts.
# 很难把他的论证同事实联系起来.
#
# His argument savo ( u ) red of sophistry.
# 他的论点有些 诡辩 的味道.

# %% [markdown]
# # anticipate
#
# 英\[ænˈtɪsɪpeɪt\] 美\[ænˈtɪsɪpeɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/anticipate)**
#
# vt. 预感; 预见; 预料; 先于…行动
#
# vi. 过早地提出; 过早地考虑（或说、做）一件事; （在口头或用文字）预言; 预测
#
# **例句**：
#
# Jim did not anticipate any trouble, but we considered everything carefully and expected the worst.
# 译文:吉姆没料到会有任何麻烦, 但我们仔细考虑了一切,并做好了最坏的打算.
#
# I anticipate success in effective economic control.
# 我预料对经济的控制会获得成功的.

# %% [markdown]
# # mouse
#
# 英\[maʊs\] 美\[maʊs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/mouse)**
#
# n. 老鼠; 鼠标; 羞怯[胆小]的人; [非正式用语] 眼部青肿
#
# **例句**：
#
# The noun " mouse " is the singular form of " mice " .
# 名词mouse是 mice 的单数形式.
#
# A lion at home, a mouse abroad.
# 在家是狮子, 出门成老鼠.

# %% [markdown]
# # forward
#
# 英\[ˈfɔːwəd\] 美\[ˈfɔːrwərd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/forward)**
#
# adv. 前进地; 向前; 至将来; 提前地
#
# adj. 向前方的; 迅速的; （社会、政治）进步的; 早熟的
#
# vt. 促进，助长; （按新地址）转寄; 发送
#
# n. 前锋
#
# **例句**：
#
# I look forward to hearing from you in the near future.
# 我盼望着不久收到你的信.
#
# The child at the back craned forward to see what was happening.
# 后面的孩子探出头看看出了什么事.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. also
# 2. argument
# 3. anticipate
# 4. mouse
# 5. forward
