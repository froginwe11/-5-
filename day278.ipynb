# %% [markdown]
# # Day278

# %% [markdown]
# # archive
#
# 英\[ˈɑːkaɪv\] 美\[ˈɑːrkaɪv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/archive)**
#
# v. 存档
#
# n. 档案文件; 档案室
#
# **例句**：
#
# Marxism reveals the logical core of archive information multiplication.
# 马克思主义揭示了档案信息增值的合理内核.
#
# The parameter LOG _ ARCHIVE _ DEST should not refer to a raw device.
# 归档日志都是文件方式,不支持裸设备的方式.

# %% [markdown]
# # city
#
# 英\[ˈsɪti\] 美\[ˈsɪti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/city)**
#
# n. 城市; 全市居民; （由国王或女王授予特权，通常有大教堂的）特许市; （由政府授予特权的）特权市
#
# **例句**：
#
# He traded a job in New York City for the life of a cowboy.
# 他放弃了在纽约的工作,去过牛仔生活.
#
# The city is justly famous for its nightclubs.
# 这座城市因其夜总会而闻名,的确不无道理.

# %% [markdown]
# # random
#
# 英\[ˈrændəm\] 美\[ˈrændəm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/random)**
#
# adj. 任意的; 随机的; 胡乱的
#
# **例句**：
#
# The symptoms are seemingly random stoppages in production and premature failures in the electronics.
# 表面上看来,这些症状可以是生产过程的随机停止,和电子元件的过早故障.
#
# Your character is spawned at a random location.
# 你的特种兵角色被随机放置在地图的一个位置.

# %% [markdown]
# # example
#
# 英\[ɪɡˈzɑːmpl\] 美\[ɪɡˈzæmpl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/example)**
#
# n. 例子; 榜样; 范例; 先例
#
# vt. . 作为…的例子; 为…做出榜样
#
# vi. . 举例
#
# **例句**：
#
# He set us an example of plain living.
# 他为我们树立了简朴生活的榜样.
#
# The captain's example incited the men to bravery.
# 船长的榜样激发了水手们的勇敢精神.

# %% [markdown]
# # note
#
# 英\[nəʊt\] 美\[noʊt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/note)**
#
# n. 笔记; 便笺; 音符; 钞票
#
# vt. 注意; 记录; 对…加注释; 指出
#
# **例句**：
#
# The letter ended on a cheerful note.
# 这封信以乐观的口气收尾.
#
# He rewarded the bearer before reading the note.
# 他在读那短笺之前,先给送信人小费.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. archive
# 2. city
# 3. random
# 4. example
# 5. note
