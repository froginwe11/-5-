# %% [markdown]
# # Day2

# %% [markdown]
# # dump
#
# 英\[dʌmp\] 美\[dʌmp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/dump)**
#
# vt. 倾倒; 丢下，卸下; 摆脱，扔弃; 倾销
#
# vi. 突然跌倒或落下; 卸货; 转嫁（责任等）
#
# n. 垃圾场; 仓库; 无秩序地累积
#
# **例句**：
#
# In the distance he hears the screech of a dump truck's brakes.
# 在很远处,他听见了卡车的急刹车声.
#
# After hanging out with us, now you dump us?
# 才跟我们混了几天就想把我们甩了?

# %% [markdown]
# # interval
#
# 英\[ˈɪntəvl\] 美\[ˈɪntərvl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/interval)**
#
# n. 间隔; 幕间休息; （数学）区间
#
# **例句**：
#
# Sleep — during this interval is out of the question.
# 要在这样的间歇里睡觉是不可能的.
#
# B, Interval between top sheet and foundation drapes covered by sterile pillowcases.
# B上单与底单间隙用无菌枕套覆盖.

# %% [markdown]
# # exponent
#
# 英\[ɪkˈspəʊnənt\] 美\[ɪkˈspoʊnənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/exponent)**
#
# n. 指数; 典型; 说明者; 样品，说明物
#
# **例句**：
#
# If the number has an exponent that exceeds the range allowed, then overflow occurs.
# 如果一个浮点数的幂的大小超出了允许的范围, 那么溢出将发生.
#
# This article gives a further development of the power exponent function and some related examples.
# 摘要对幂指函数的求导法则做了进一步推广,并给出了相应的求导举例.

# %% [markdown]
# # bad
#
# 英\[bæd\] 美\[bæd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/bad)**
#
# adj. 坏的，不好的; 严重的; 不舒服的; 低劣的，有害的
#
# n. 坏人，坏事
#
# adv. 不好地，非常地
#
# **例句**：
#
# If anything should happen to him, that would be too bad.
# 如什么意外的事临到他的头上, 可就糟了.
#
# That's not a bad idea.
# 那个主意 倒 不错.

# %% [markdown]
# # do
#
# 英\[duː ,du ,də\] 美\[duː ,du ,də\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/do)**
#
# aux. 构成疑问句和否定句; 代替动词; 用于加强语气
#
# vt. 做; 干; 进行; 从事
#
# vi. 表现; 进展; 引起; 行过
#
# n. 社交聚会; 社交活动; 宴会
#
# **例句**：
#
# Figure the situation to yourself, what can I do?
# 你设身处地想想, 我能做什么?
#
# This pen is not very good, but we'll have to make it do.
# 这支笔不太好, 但我们得对付着用.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. dump
# 2. interval
# 3. exponent
# 4. bad
# 5. do
