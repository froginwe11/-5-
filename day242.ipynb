# %% [markdown]
# # Day242

# %% [markdown]
# # strike
#
# 英\[straɪk\] 美\[straɪk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/strike)**
#
# vt. 罢（工、课等）; 撞; 攻击; 来到
#
# vi. 罢工; 打击; 朝某一方向前进
#
# n. 攻击; 罢工[课，市]; 发现
#
# **例句**：
#
# The tie happened to strike Paul's fancy, so he bought it.
# 保罗看中了这条领带, 就买下了.
#
# We'll lead with the dock strike.
# 我们将以码头工人罢工作为头条新闻.

# %% [markdown]
# # soft
#
# 英\[sɒft\] 美\[sɔːft\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/soft)**
#
# adj. 软的，柔软的; 温和的，柔和的; 不含酒精的; 轻松的
#
# **例句**：
#
# Add milk to produce a soft dropping consistency.
# 加牛奶至一种柔滑可滴的黏稠度.
#
# We padded the box with soft cloth.
# 我们用软布填塞那箱子.

# %% [markdown]
# # magenta
#
# 英\[məˈdʒentə\] 美\[məˈdʒɛntə\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/magenta)**
#
# adj. 紫红色的，洋红色的
#
# **例句**：
#
# Semidouble magenta red large frilled star.
# 半重瓣大朵折边洋红色星形花.
#
# CMYK color mode: from Royal Blue , magenta, yellow, and yellow, also known as reducing color mode.
# CMYK不 暗白模式: 由品蓝, 品赤, 品黄和黄色构不败, 又叫失神模式.

# %% [markdown]
# # menu
#
# 英\[ˈmenjuː\] 美\[ˈmenjuː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/menu)**
#
# n. 菜单; 菜，菜肴
#
# **例句**：
#
# He signaled the waiter to bring the menu.
# 他作手势要侍者拿菜单来.
#
# Many restaurants do a very reasonable set menu at lunchtime.
# 许多餐馆中午都提供价钱合理的客饭.

# %% [markdown]
# # debug
#
# 英\[ˌdi:ˈbʌg\] 美\[diˈbʌɡ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/debug)**
#
# vt. 拆除窃听器; 排除故障
#
# **例句**：
#
# The production lines ground to a halt for hours while technicians tried to debug software.
# 生产线停工达数小时之久，在此期间技术人员试图纠除软件错误。
#
# We'll use DEBUG to look at a floppy disk's Boot Record.
# 我们将使用DEBUG来看看软盘的引导记录.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. strike
# 2. soft
# 3. magenta
# 4. menu
# 5. debug
