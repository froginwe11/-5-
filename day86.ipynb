# %% [markdown]
# # Day86

# %% [markdown]
# # interface
#
# 英\[ˈɪntəfeɪs\] 美\[ˈɪntərfeɪs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/interface)**
#
# n. 界面; <计>接口; 交界面
#
# v. （使通过界面或接口）接合，连接; [计算机]使联系
#
# vi. 相互作用（或影响）; 交流，交谈
#
# **例句**：
#
# A few considerations early in the design phase can focus interface design.
# 设计前期的一些考虑将焦点放在接口设计上.
#
# This system can show the running state of hydroelectric turbines through a friendly interface.
# 该系统可以动态的显示水轮机的运行状态,具有良好的人机界面性能.

# %% [markdown]
# # range
#
# 英\[reɪndʒ\] 美\[reɪndʒ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/range)**
#
# n. 范围; 射程; 类别; （山脉，房屋等的）排列
#
# vi. 变化; 包括; 涉及
#
# vt. 排列; 徘徊
#
# **例句**：
#
# We'll give the enemy beans when they come within range.
# 敌人一旦进入射程,我们就惩罚他们.
#
# The country is importing a broad range of skilled personnel.
# 这个国家正在引进各种专业技术人员.

# %% [markdown]
# # root
#
# 英\[ruːt\] 美\[ruːt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/root)**
#
# n. 根，根源; 原因，本质; 祖先; [乐]和弦基音
#
# vt. 使生根; 使固定; 根源在于; 欢呼，喝彩
#
# vi. 生根; 根除
#
# **例句**：
#
# The root of the tree rotted away.
# 树根烂了.
#
# Are you going to root here forever?
# 你留在这儿永远不走了 吗 ?

# %% [markdown]
# # bar
#
# 英\[bɑː(r)\] 美\[ bɑːr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/bar)**
#
# n. 条，棒; （门、窗等的）闩; 障碍; 酒吧间
#
# vt. 闩（门等）; 阻碍，封锁; 排除，去除
#
# prep. 除…之外
#
# **例句**：
#
# He is studying for bar.
# 他为准备做律师而学习.
#
# He did not go to the bar against his father's will.
# 他违背了他父亲的意愿,没有当律师.

# %% [markdown]
# # making
#
# 英\[ˈmeɪkɪŋ\] 美\[ˈmeɪkɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/making)**
#
# n. 制造; 产生的过程; 成功改进的手段; 原料，材料
#
# v. “make”的现在分词
#
# **例句**：
#
# I saw him making signs at us.
# 我看见他向我们做着手势.
#
# He was making a name for himself as one of the moderns.
# 他正给自已树立现代派画家的声誉.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. interface
# 2. range
# 3. root
# 4. bar
# 5. making
