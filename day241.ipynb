# %% [markdown]
# # Day241

# %% [markdown]
# # developer
#
# 英\[dɪˈveləpə(r)\] 美\[dɪˈveləpər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/developer)**
#
# n. 开发者; <摄>显影剂，显像剂
#
# **例句**：
#
# You will be a key developer working on the CLR managed services team.
# 你们会成为CLR托管服务开发团队中的关键开发者.
#
# Truly learn another language, and I promise that your abilities a developer will start to blossom.
# 真正学会了另一门语言后, 我保证你的开发能力一定会突飞猛进.

# %% [markdown]
# # nearly
#
# 英\[ˈnɪəli\] 美\[ˈnɪrli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/nearly)**
#
# adv. 几乎，差不多; 险乎
#
# **例句**：
#
# The ball struck him so hard that he nearly fell into the water.
# 那球重重地打在他身上,他几乎掉下水去.
#
# Halfway across the field , the farmer ploughed out some very large stones which nearly broke his machine.
# 这个农民在地里犁地犁到半路的时候, 犁出一些很大的石头,几乎弄坏了他的机器.

# %% [markdown]
# # terminate
#
# 英\[ˈtɜːmɪneɪt\] 美\[ˈtɜːrmɪneɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/terminate)**
#
# vt.& vi. 结束; 使终结; 解雇; 到达终点站
#
# **例句**：
#
# The meeting terminate at 10 o'clock.
# 会议在十点钟结束.
#
# Click or press ESCAPE to terminate rotation.
# 点击鼠标或按下ESC键终止旋转.

# %% [markdown]
# # configure
#
# 英\[kənˈfɪgə(r)\] 美\[kənˈfɪgjər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/configure)**
#
# v. 配置; 设定; 使成形; 使具一定形式
#
# **例句**：
#
# Add, remove, and configure game controller hardware such as joysticks and gamepads.
# 添加 、 删除或配置游戏控制器硬件,如游戏杆和游戏板.
#
# This wizard helps you configure your computer to send and receive faxes.
# 此向导帮助您配置您的计算机以便发送和接收传真.

# %% [markdown]
# # rather
#
# 英\[ˈrɑːðə(r) , ˌrɑːˈðɜː(r)\] 美\[ˈræðər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/rather)**
#
# adv. 稍微，有点; 相当，颇; 宁愿; 相反地
#
# int. 当然啦；怎么不（回答问题时用）
#
# conj. 而不是
#
# **例句**：
#
# The suitcase is rather heavy.
# 这箱子怪沉的.
#
# He speaks in concepts rather than specifics.
# 他讲话时尽用抽象概念,而不谈具体.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. developer
# 2. nearly
# 3. terminate
# 4. configure
# 5. rather
