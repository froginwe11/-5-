# %% [markdown]
# # Day51

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=52>

# %% [markdown]
# # central
#
# 英\[ˈsentrəl\] 美\[ˈsentrəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/central)**
#
# adj. 中央的，中心的; 重要的，核心的
#
# **例句**：
#
# A huge bomb blast rocked central London last night.
# 昨晚一次剧烈的炸弹爆炸震动了伦敦市中心.
#
# Explorers traced the Nile River to its several headstreams in Central Africa.
# 探险者在中非找到了尼罗河的几处源头.

# %% [markdown]
# # inclusive
#
# 英\[ɪnˈkluːsɪv\] 美\[ɪnˈkluːsɪv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/inclusive)**
#
# adj. 包括的，包罗广泛的; 包括…的; 一切开支包括在内的; （语言使用上）不分男女的
#
# **例句**：
#
# An all-inclusive two-week holiday costs around £880 per person.
# 为期两周、包括所有费用的度假大约每人花费880英镑。
#
# The bill is inclusive of the food and lodging.
# 账单包括吃、住费用.

# %% [markdown]
# # superimpose
#
# 英\[ˌsu:pərɪmˈpəʊz\] 美\[ˌsupərɪmˈpoʊz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/superimpose)**
#
# vt. 添加; 附加
#
# **例句**：
#
# I did not see the number received, he superimpose number to me.
# 见我没领到号码, 他硬是把号码塞给了我.
#
# Method: Naproxen pellets were developed in coating superimpose, the preparation and the quality were evaluated.
# 方法: 采用层积式制丸法制备萘普生微丸, 对制备工艺和微丸质量进行了评价.

# %% [markdown]
# # criterion
#
# 英\[kraɪˈtɪəriən\] 美\[kraɪˈtɪriən\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/criterion)**
#
# n. （批评、判断等的）标准，准则; 规范
#
# **例句**：
#
# Results: Using the Torrance � � s health state � � s classification system as a standard, HRLQS has a good criterion validity.
# 结果: 以Torance健康状态分类系统(HCS) 为标准, HRLQS具有较好的准则效度.
#
# But can conclude from logic, if freedom cannot get legal protection, criterion it is irretentive.
# 但从逻辑上可以得出结论, 倘若自由得不到法律保护, 则它不能保持.

# %% [markdown]
# # wrap
#
# 英\[ræp\] 美\[ræp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/wrap)**
#
# vt. 包; 缠绕; 用…包裹（或包扎、覆盖等）; 掩护
#
# n. 膝毯，披肩，围巾，围脖，头巾，罩衫，外套，大衣; 包装纸; 〈俚〉机密
#
# vi. 缠绕，盘绕（通常与 over, around 等连用）; 包上，裹上; 穿上（衣服等）
#
# **例句**：
#
# Schoolmate, this is yours wrap what up?
# 同学, 这是你的包 吗 ?
#
# Wrap plenty of paper round it.
# 用大量的纸把它包起来.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. central
# 2. inclusive
# 3. superimpose
# 4. criterion
# 5. wrap
