# %% [markdown]
# # Day263

# %% [markdown]
# # constant
#
# 英\[ˈkɒnstənt\] 美\[ˈkɑːnstənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/constant)**
#
# adj. 不断的，持续的; 永恒的，始终如一的; 坚定; 忠实的
#
# n. [数]常数，常量; 不变的事物; 永恒值
#
# **例句**：
#
# In history, change is constant.
# 在历史上, 变化是不断的.
#
# The market is in a constant state of flux.
# 市场行情在不断变化.

# %% [markdown]
# # three
#
# 英\[θriː\] 美\[θriː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/three)**
#
# num. 三; 三个; 第三（章，页等）
#
# n. 三岁; 三个人[东西]; 三，三个
#
# **例句**：
#
# I intend to amortize the total cost of the car over three years.
# 我打算用三年时间分期偿还汽车的所有费用.
#
# The number 410 contains three digits.
# 数字410中包括三个数目字.

# %% [markdown]
# # conditional
#
# 英\[kənˈdɪʃənl\] 美\[kənˈdɪʃənəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/conditional)**
#
# adj. 视…而定的; [语]条件的，假定的; [心]有条件的，由一定条件诱发的
#
# n. 条件（从句），条件语
#
# **例句**：
#
# A conditional release of an offender from confinement before the expiration of his or her sentence.
# 囚犯在服刑期满前有条件地释放出来,但必须置于假释官的督导之下.
#
# The first conditional statement is used for input validation.
# 第一个条件语句用于输入验证.

# %% [markdown]
# # correctly
#
# 英\[kə'rektlɪ\] 美\[kəˈrɛktlɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/correctly)**
#
# adv. 正确地，得体地; 实事求是
#
# **例句**：
#
# When an accident happens, quite correctly questions are asked.
# 当事故发生时，理所当然要询问一些情况。
#
# It is important to judge the weight of your washing load correctly.
# 正确估计待洗衣物的重量很重要。

# %% [markdown]
# # varying
#
# 英\['veərɪŋ\] 美\['veərɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/varying)**
#
# v. 变化( vary的现在分词 ); [生物学]变异; 相应变化; 呈现不同
#
# **例句**：
#
# Different writers will prepare to varying degrees.
# 不同作者的准备程度也会各不相同。
#
# Racism still exists to varying degrees.
# 种族主义仍不同程度地存在着.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. constant
# 2. three
# 3. conditional
# 4. correctly
# 5. varying
