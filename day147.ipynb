# %% [markdown]
# # Day147

# %% [markdown]
# # desktop
#
# 英\[ˈdesktɒp\] 美\[ˈdesktɑːp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/desktop)**
#
# n. 桌面
#
# **例句**：
#
# Another distinct difference between embedded systems and desktop applications is the importance of environmental context.
# 嵌入系统和桌面应用的另一个主要区别在于使用情境的不同.
#
# Secondly, due to the desktop computer platform, the instruments are not suitable for outdoor occasion.
# 其二是测试仪是基于台式计算机的, 无法满足野外使用的要求.

# %% [markdown]
# # syntax
#
# 英\[ˈsɪntæks\] 美\[ˈsɪnˌtæks\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/syntax)**
#
# n. 句法; 句法规则[分析]; 语构; 语法
#
# **例句**：
#
# Thus this specification is a definition of the syntax and semantics of the XSLT namespace.
# 因些本规范是一个XSLT命名空间的语法和语义的定义.
#
# In our semantic analysis, EBC is shown to manifest a perfect match between syntax and semantics.
# 删除的过程受黄(1991b)中提到“方向性制约”的约束,在我们的语义分析中, 可以看出,“显性比字句”表现出句法和语义完美搭配.

# %% [markdown]
# # clipper
#
# 英\[ˈklɪpə(r)\] 美\[ˈklɪpər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/clipper)**
#
# n. 剪刀，理发剪; 剪削者，削取人; （十九世纪的）快速帆船; 快马，移动很快的人或物
#
# **例句**：
#
# The pirate ship boarded the clipper.
# 海盗船强行靠近快艇.
#
# Starting where you left off at the shoulders, clipper the sides to the hip joint.
# 在你离开时开始在肩上, 快船的髋关节的两边.

# %% [markdown]
# # desire
#
# 英\[dɪˈzaɪə(r)\] 美\[dɪˈzaɪər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/desire)**
#
# vt. 希望; 渴望; 要求; 请求
#
# n. 愿望; 欲望; 希望; 请求
#
# vi. 有希望; 期望; 愿望; 想望
#
# **例句**：
#
# He has a strong desire to meet you.
# 他极想见你.
#
# She repressed her desire to mention his name.
# 她压制住自己没有提他的名字.

# %% [markdown]
# # page
#
# 英\[peɪdʒ\] 美\[peɪdʒ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/page)**
#
# n. 页; （计算机的）页面; 年史; <文>重要事件
#
# vt. 标记…的页数; 翻页; 喊出名字以寻找; （在公共传呼系统上）呼叫
#
# vi. 翻书页; 浏览
#
# **例句**：
#
# The fable is given on the next page.
# 这篇寓言登在下一页上.
#
# Have you had experience in mocking up a page?
# 你装扮过花童 吗 ?

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. desktop
# 2. syntax
# 3. clipper
# 4. desire
# 5. page
