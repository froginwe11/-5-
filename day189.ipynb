# %% [markdown]
# # Day189

# %% [markdown]
# # individually
#
# 英\[ˌɪndɪˈvɪdʒuəli\] 美\[ˌɪndɪˈvɪdʒuəli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/individually)**
#
# adv. 分别地; 各个地; 各自地; 独特地
#
# **例句**：
#
# The candidates are being called out individually for interviews.
# 求职者正被请去进行单独面试.
#
# We usually pack our shirts individually in polyethylene bags, ten dozen to one carton.
# 我们的衬衣通常每件单独装一塑料袋, 10打装一纸箱.

# %% [markdown]
# # bit
#
# 英\[bɪt\] 美\[bɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/bit)**
#
# n. 一点，一块; 少量，少许; 一会儿，一转眼; [计] 比特（二进位制信息单位）
#
# v. 咬，叮( bite的过去式); 刺痛; 咬饵; 有咬（或叮）的习性
#
# **例句**：
#
# I'm certainly going, but I'll be a little bit late.
# 我去是去, 可是得晚一点儿.
#
# That's going a bit too far.
# 你这 话 有点出格了.

# %% [markdown]
# # calculation
#
# 英\[ˌkælkjuˈleɪʃn\] 美\[ˌkælkjuˈleɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/calculation)**
#
# n. 计算，盘算; 估计; 计算的结果; 深思熟虑，慎重的计划
#
# **例句**：
#
# You can often use this calculation as a basis for the project budget.
# 通常,您可以将此计算用作项目预算的基础.
#
# The accuracy of CBM recovery factor prediction will directly influence the calculation of recoverable reserves.
# 煤层气预测采收率准确与否,直接影响着可采储量的计算精度.

# %% [markdown]
# # addition
#
# 英\[əˈdɪʃn\] 美\[əˈdɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/addition)**
#
# n. 加，增加，附加; [数]加法; 增加的人或事物
#
# **例句**：
#
# The new addition makes China the 5 th largest gold reserve holder in the world.
# 在各国公布的黄金储备中,我国排名第五.
#
# In addition to copper, there are many other metals which are good conductors.
# 除了铜之外, 还有很多其他金属都是良导体.

# %% [markdown]
# # freeze
#
# 英\[friːz\] 美\[friːz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/freeze)**
#
# vt. 使结冰，使冻僵; 冷藏; 吓呆; 冻结（存款，工资等）
#
# vi. 凝固，结冰; 冻伤，冻死
#
# n. 冻结; 严寒时期
#
# **例句**：
#
# Relations with somebody were still in deep freeze.
# 同某人的关系仍然极度冷淡.
#
# His influence is so strong that crowds of followers freeze onto him wherever he goes.
# 他颇有影响力,无论走到哪里,都有成群的追随者跟着他.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. individually
# 2. bit
# 3. calculation
# 4. addition
# 5. freeze
