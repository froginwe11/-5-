# %% [markdown]
# # Day304

# %% [markdown]
# # bios
#
# 英
#
# **[释义](https://fanyi.baidu.com/#en/zh/bios)**
#
# n. 酵母促生物; 生物活素; 生长素; 生命素; （尤其供公开发表的）个人简历(biography的缩写)( bio的名词复数 )
#
# **例句**：
#
# What is the BIOS actually doing when I turn on my computer?
# 当我开启电脑时BIOS到底做些什么?
#
# How do I determine the amount of RAM with the BIOS?
# 如何使用BIOS检测内存总容量?

# %% [markdown]
# # failure
#
# 英\[ˈfeɪljə(r)\] 美\[ˈfeɪljər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/failure)**
#
# n. 失败，不及格; 缺乏，不足; 破产，倒闭; 失败的事，失败者
#
# **例句**：
#
# He was rather apprehensive of failure.
# 他相当害怕失败.
#
# This washing machine was guaranteed from mechanical failure — I demand a new one!
# 这台洗衣机出售时曾担保过不出机械性故障——我要换一台新的.

# %% [markdown]
# # sufficient
#
# 英\[səˈfɪʃnt\] 美\[səˈfɪʃnt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sufficient)**
#
# adj. 足够的; 充足的; 充分的
#
# **例句**：
#
# The rain was not sufficient to do any harm.
# 雨量不足对庄稼有害.
#
# His income is sufficient for his needs.
# 他的收入能满足他的需要.

# %% [markdown]
# # test
#
# 英\[test\] 美\[test\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/test)**
#
# n. 试验; 考验; 测验; 化验
#
# vt. 测验; 考查; 考验; 勘探
#
# vi. 受试验; 受测验; 受考验; 测得结果
#
# **例句**：
#
# In a consumer taste test, Coke went up against Pepsi.
# 在一次消费者品尝测验中, 可口可乐与百事可乐交锋了.
#
# He has stood the test of war.
# 他经受住了战争的考验.

# %% [markdown]
# # month
#
# 英\[mʌnθ\] 美\[mʌnθ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/month)**
#
# n. 月，月份; 一个月的时间
#
# **例句**：
#
# One way and another I'm going to finish this work before the end of the month.
# 无论如何,我打算在本月完成这项工作.
#
# These tickets are available for one month.
# 这些票有效期一个月.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. bios
# 2. failure
# 3. sufficient
# 4. test
# 5. month
