# %% [markdown]
# # Day123

# %% [markdown]
# # product
#
# 英\[ˈprɒdʌkt\] 美\[ˈprɑːdʌkt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/product)**
#
# n. 产品; 结果; 乘积; 作品
#
# **例句**：
#
# Our product enjoys popularity throughout the world.
# 我们的产品饮誉全球.
#
# We should prevent others cashing in before we've time to market the product.
# 我们应该防止别人在我们没有来得及在市场上销售这产品之前大捞一笔.

# %% [markdown]
# # unmarked
#
# 英\[ʌnˈmɑ:kt\] 美\[ʌnˈmɑrkt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unmarked)**
#
# adj. 没有标志的，未被注意到的
#
# **例句**：
#
# Resource Mailbox Scan completed. No unmarked resource mailboxes found.
# 已完成资源邮箱扫描.没有发现未标记的资源邮箱.
#
# Each clip is unmarked and is the full duration of the media file.
# 每个剪贴都没有标记,并且是这个媒体文件的全宽度.

# %% [markdown]
# # left
#
# 英\[left\] 美\[left\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/left)**
#
# adj. 左边的，左侧的; 左派的; 剩下的
#
# n. 左，左面; [军]左翼; 左派，激进分子
#
# v. 离开（ leave的过去式和过去分词）
#
# **例句**：
#
# The snail left a trail of slime along the floor.
# 蜗牛在地板上留下一道黏液.
#
# Hearing that there was an emergency case, the doctor put down his chopsticks and left at once.
# 听说有急诊, 医生撂下筷子就走.

# %% [markdown]
# # presence
#
# 英\[ˈprezns\] 美\[ˈprezns\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/presence)**
#
# n. 出席，到场; 存在，出现; 风采，风度; 鬼魂，神灵
#
# **例句**：
#
# Your presence is immediately requested.
# 即请光临.
#
# One theory about the existence of extraterrestrial life rests on the presence of carbon compounds in meteorites.
# 地球外存在生命的理论是基于陨星上存在碳化合物质这一事实的.

# %% [markdown]
# # map
#
# 英\[mæp\] 美\[mæp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/map)**
#
# n. 地图，天体图; 类似地图的事物; 〈美俚〉脸，面孔; （染色体上基因排列的）遗传图
#
# vt. 绘制（一地区等的）地图; 勘查; 详细规划; [遗传学]比对
#
# **例句**：
#
# The complexity of the road map puzzled me.
# 错综复杂的公路图把我搞糊涂了.
#
# The map of the heavens showed all the northern constellations.
# 这份天体图标明了北半部所有的星座.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. product
# 2. unmarked
# 3. left
# 4. presence
# 5. map
