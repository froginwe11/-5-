# %% [markdown]
# # Day121

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=122>

# %% [markdown]
# # implicit
#
# 英\[ɪmˈplɪsɪt\] 美\[ɪmˈplɪsɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/implicit)**
#
# adj. 不言明[含蓄]的; 无疑问的，绝对的; 成为一部份的; 内含的
#
# **例句**：
#
# Each value type has an implicit default constructor that initializes the default value of that type.
# 每种值类型均有一个隐式的默认构造函数来初始化该类型的默认值.
#
# Implicit in these recombined forms are simultaneous ideas of structural vigor and failure.
# 重组形式,这些隐含的结构性活力和失败的同时想法.

# %% [markdown]
# # flag
#
# 英\[flæɡ\] 美\[flæɡ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/flag)**
#
# n. 旗; 旗帜; 信号旗; 菖蒲
#
# vt. 标示
#
# vi. 疲乏，变弱，热情衰减
#
# **例句**：
#
# Merchant ships salute each other by dipping the flag.
# 商船互相点旗致敬.
#
# The flag was aflutter in the air.
# 旗帜在空中飘扬.

# %% [markdown]
# # rectangular
#
# 英\[rekˈtæŋɡjələ(r)\] 美\[rekˈtæŋɡjələr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/rectangular)**
#
# adj. <数> 矩形的; 成直角的; 直角坐标的; 长方
#
# **例句**：
#
# Each comb plate is a simple rectangular paddle composed of cilia.
# 每个栉板都是纤毛组成的矩形的桨.
#
# Utilizing rectangular approximate in 3 dB fused - tapered optical fiber coupler coupling ratio is analyzed theoretically.
# 利用矩形近似理论对用熔锥法制作的耦合器分光比进行了分析.

# %% [markdown]
# # overall
#
# 英\[ˌəʊvərˈɔːl , ˈəʊvərɔːl\] 美\[ˌoʊvərˈɔːl , ˈoʊvərɔːl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/overall)**
#
# adj. 全部的; 全体的; 一切在内的; 综合的
#
# adv. 全面地; 总地; 总的说来
#
# n. 工装裤; 罩衫; 〈英〉（军官的）紧身军裤
#
# **例句**：
#
# Everybody has a share in fulfiling the various norms and the overall tasks of the enterprise.
# 人人身上有指标,全厂任务大家挑.
#
# There has been an overall growth in population, despite some draconian efforts to contain it.
# 尽管有严厉的遏制措施,人口还是在全面增长.

# %% [markdown]
# # permanently
#
# 英\[ˈpɜːmənəntli\] 美\['pɜːmənəntli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/permanently)**
#
# adv. 永久地，长期不变地
#
# **例句**：
#
# All the yellow safety mark plates supplied should be permanently kept in their original places.
# 所提供的黄色安全警告标识牌必须永久保持在其相应的地方.
#
# His illness had permanently weakened him.
# 疾病使他再也无法恢复体力.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. implicit
# 2. flag
# 3. rectangular
# 4. overall
# 5. permanently
