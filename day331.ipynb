# %% [markdown]
# # Day331

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=332>

# %% [markdown]
# # initialize
#
# 英\[ɪˈnɪʃəlaɪz\] 美\[ɪˈnɪʃəˌlaɪz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/initialize)**
#
# vt. 初始化
#
# **例句**：
#
# Assignment ( upon uninitialized ): To initialize the wrapped object with value of another wrapped object.
# 赋值 ( 到未初始化的对象 ): 以另一个包装对象的值初始化包装对象.
#
# Initialize Drag & Drop capabilities in the dialog.
# 初始化对话框的拖 放 性能.

# %% [markdown]
# # long
#
# 英\[lɒŋ\] 美\[lɔːŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/long)**
#
# adj. 长的; 长时间的; 冗长的，过长的; 长音的
#
# adv. 长久地; 始终; 遥远地
#
# vi. 渴望，极想
#
# **例句**：
#
# I was a tired man when the long race was over.
# 我跑完长跑后疲乏极了.
#
# At ( long ) last he knew the meaning of life.
# 终于,他知道了生命的意义.

# %% [markdown]
# # very
#
# 英\[ˈveri\] 美\[ˈveri\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/very)**
#
# adj. 很，非常; 恰好是，正是; 十足的; 特有的
#
# adv. 很，非常; 充分，完全
#
# **例句**：
#
# The process of adjustment to life in another country can be very difficult.
# 适应另一国家的生活可能会非常困难.
#
# She is very virulent about her former employer.
# 她对她过去的老板恨之入骨.

# %% [markdown]
# # compile
#
# 英\[kəmˈpaɪl\] 美\[kəmˈpaɪl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/compile)**
#
# vt. 汇编; 编辑; 编制; 编译
#
# **例句**：
#
# BCB 6.0 compile a complete network chat rooms source code.
# BCB6.0编译通过的完整的网络聊天室源代码.
#
# In this scenario, a compiler uses reflection emit to compile regular expressions in source code.
# 在此方案中, 编译器使用反射发出编译源代码中的正则表达式.

# %% [markdown]
# # tool
#
# 英\[tuːl\] 美\[tuːl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/tool)**
#
# n. 器具，工具; （有助于做工或完成某事的）用具; 受人利用的人; 压印机
#
# vt. 用工具给…加工; 压印; 驾车到处跑
#
# vi. 使用工具; 开车，乘车
#
# **例句**：
#
# At last the tracking laws derived above are indirectly validated using STK ( Satellite Tool Kit ).
# 最后利用STK ( SatelliteToolKit ) 对该跟踪规律进行了间接验证.
#
# However, tool wear is high in USM, due to the abrasive cutting action.
# 但是, 由于USM是磨削加工, 因而刀具损耗大.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. initialize
# 2. long
# 3. very
# 4. compile
# 5. tool
