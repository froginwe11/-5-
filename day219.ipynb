# %% [markdown]
# # Day219

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=220>

# %% [markdown]
# # underline
#
# 英\[ˌʌndəˈlaɪn\] 美\[ˌʌndərˈlaɪn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/underline)**
#
# vt. 在…下面画线; 加强，强调
#
# **例句**：
#
# Today at Cana many underline the grace of marriage and family.
# 今天在加纳很多人强调婚姻和家庭的恩典.
#
# OK . Now read 2 quickly again and underline the means of transportation and adverbs of frequency.
# 让学生再次阅读2,迅速找出含有交通方式和频率副词的句子.

# %% [markdown]
# # restart
#
# 英\[ˌri:ˈstɑ:t\] 美\[ˌriˈstɑrt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/restart)**
#
# v. 重新开始
#
# **例句**：
#
# Restart the computer in Safe mode or VGA mode.
# 重新启动计算机在安全模式或VGA模式.
#
# Force offscreen compositing even under Terminal Server ( requires restart )
# 强制屏幕外合成,即便是在终端服务器下 ( 需要重启动 )

# %% [markdown]
# # recent
#
# 英\[ˈriːsnt\] 美\[ˈriːsnt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/recent)**
#
# adj. 最近的; 新近的; 近代的; [地]全新世的
#
# **例句**：
#
# Consumption of oil has declined in recent years.
# 石油消耗量在最近几年下降了.
#
# The Chinese Government is deeply concerned at the recent development.
# 中国政府对事态发展深表关切.

# %% [markdown]
# # positive
#
# 英\[ˈpɒzətɪv\] 美\[ˈpɑːzətɪv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/positive)**
#
# adj. 积极的; 确实的，肯定的; [数]正的; [医]阳性的
#
# n. 正面; 正片; [语]原级形容词; [数]正量
#
# **例句**：
#
# French artist and inventor of the daguerreotype process for obtaining positive photographic prints.
# 达盖尔,路易斯·雅克·曼德1789-1851法国艺术家和发明家,发明了银版摄影术,能洗出照片的正画来.
#
# Without doubt , the national bourgeoisie tends to vacillate , but we should , nevertheless, make use of its positive side, uniting with it as well as struggling against it.
# 民族资产阶级 当然 是动摇的, 但是要利用它的积极的一面, 要有团结有斗争.

# %% [markdown]
# # data
#
# 英\[ˈdeɪtə\] 美\[ˈdeɪtə\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/data)**
#
# n. 资料，材料; datum的复数; [计算机]数据，资料; 从科学实验中提取的价值
#
# **例句**：
#
# We carried on experiments one after another and piled up experience and data as well.
# 我们进行了一个又一个的实验,也积累了经验和数据.
#
# Thank you for furnishing me with so many data.
# 谢谢你供给我这么多的资料.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. underline
# 2. restart
# 3. recent
# 4. positive
# 5. data
