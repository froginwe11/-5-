# %% [markdown]
# # Day340

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=341>

# %% [markdown]
# # assignment
#
# 英\[əˈsaɪnmənt\] 美\[əˈsaɪnmənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/assignment)**
#
# n. 分给，分配; 任务，工作，（课外）作业; <美>任命; 指定，委派
#
# **例句**：
#
# I finished my assignment just under the wire.
# 我恰好在最后期限之前完成了我的指派任务.
#
# This paper presents a classified compact dynamic channel assignment ( CCDCA ) scheme for cellular mobile communications systems.
# 提出一种分级紧致的动态信道分配 ( CCDCA ) 方案.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. assignment
