# %% [markdown]
# # Day156

# %% [markdown]
# # strong
#
# 英\[strɒŋ\] 美\[strɔːŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/strong)**
#
# adj. 强的; 坚强的; 强烈的; 强壮的
#
# **例句**：
#
# He is now well over sixty, but is still going strong.
# 他已六十多岁了, 可是还强壮得很.
#
# He twisted the three ropes to make one very strong rope.
# 他把3根绳子搓成一根非常结实的绳子.

# %% [markdown]
# # processing
#
# 英\[ˈprəʊsesɪŋ\] 美\[ ˈprɑːsesɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/processing)**
#
# n. （数据）处理; 整理; 配置; 工艺（生产方法）设计
#
# v. 加工( process的现在分词 ); 处理; 审阅; 审核
#
# **例句**：
#
# The fabric is strong enough to withstand harsh processing.
# 这种织物非常结实，能经受粗加工。
#
# The Data Processing analysis is likely to prevail in the long run.
# 从长远角度看,"数据加工"案的分析很可能起主导作用.

# %% [markdown]
# # tell
#
# 英\[tel\] 美\[tel\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/tell)**
#
# vt. 告诉，说; 辨别; 吩咐; 讲述
#
# vt.& vi. 分辨，辨别; 告诉，吩咐; 泄漏; 保证
#
# vi. 泄密，告发; （颜色、声音等）显示; 识别
#
# **例句**：
#
# Tell me where you've been out so late, or I'll knock your block off.
# 告诉我你到哪儿去了,这么晚才回来, 不说我就揍死你.
#
# We won't be able to tell what skills the man has until we try him out.
# 要等试用一个时期以后,我们才能知道这人有什么专长.

# %% [markdown]
# # preview
#
# 英\[ˈpriːvjuː\] 美\[ˈpriːvjuː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/preview)**
#
# n. 试映，预演; 预告片; 象征，预示
#
# vt. 预映; 预先观看; 概述; 扼要介绍
#
# **例句**：
#
# It is obvious control of a unit is a typical load preview control problem.
# 显然,对机组而言这是典型的负荷预见控制问题.
#
# Preview contents of print job before sending to printer and view the printed jobs content.
# 预览的内容打印作业之前,发送到打印机,并检视印刷工作的内容.

# %% [markdown]
# # indicator
#
# 英\[ˈɪndɪkeɪtə(r)\] 美\[ˈɪndɪkeɪtər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/indicator)**
#
# n. 指示器; [化]指示剂; 指示者
#
# **例句**：
#
# It is an indicator to observe the loss that occurs during the process of energy conversion.
# 它是观察能源在加工转换过程中损失量变化的指标.
#
# Gold prices are often seen as an indicator of inflation.
# 黃金价格常常被看作是通货膨胀的指标.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. strong
# 2. processing
# 3. tell
# 4. preview
# 5. indicator
