# %% [markdown]
# # Day144

# %% [markdown]
# # while
#
# 英\[waɪl\] 美\[waɪl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/while)**
#
# conj. 在…期间; 与…同时; 虽然; 而
#
# n. （一段）时间
#
# **例句**：
#
# Tazief was able to set up his camp very close to the volcano while it was erupting violently.
# 泰哲夫在火山猛烈爆发的时候,终于设法在离火山很近的地方搭起了帐蓬.
#
# He hummed and hawed for quite a while before he uttered a few words of comfort.
# 他吭哧了好一会才说出几句安慰话.

# %% [markdown]
# # enough
#
# 英\[ɪˈnʌf\] 美\[ɪˈnʌf\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/enough)**
#
# adv. 足够地，充足地; 十分地
#
# n. 充分，足够; 满足
#
# adj. （用于复数或不可数名词前）足够的，充足的，充分的
#
# **例句**：
#
# The fee his lawyer charged for drawing up the deed was enough in all conscience.
# 他的律师为起草契约所收的费用确实足够了.
#
# The fall of one leaf is enough to tell coming of autumn.
# 一叶知秋.

# %% [markdown]
# # forth
#
# 英\[fɔːθ\] 美\[fɔːrθ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/forth)**
#
# adv. 向前，向前方; 露着的，往外的; [废语]出外，离家
#
# **例句**：
#
# This is not a suitable time for launching forth on a new business undertaking.
# 现在,不宜着手搞新的经营项目.
#
# On summer evenings the flowers gave forth an almost intoxicating scent.
# 夏日的傍晚,鲜花散发出醉人的芳香.

# %% [markdown]
# # tab
#
# 英\[tæb\] 美\[tæb\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/tab)**
#
# n. 帐单; （易拉罐的）拉环; 标签，制表
#
# vt. <口>监视; 给…贴标签; 用垂饰安装
#
# abbr. (=Technical Assistance Board (of the United Nations))（联合国）技术援助委
#
# **例句**：
#
# Templates for creating tab icons in Adobe Photoshop are available in the Icon Templates Pack.
# 创建标签图标的PS文件,可在图标模板包里获得.
#
# Her father picked up the tab for all the champagne at the wedding.
# 婚礼上所有的香槟酒都是他父亲买单.

# %% [markdown]
# # overlay
#
# 英\[ˌəʊvəˈleɪ , ˈəʊvəleɪ\] 美\[ˌoʊvərˈleɪ , ˈoʊvərleɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/overlay)**
#
# v. 覆盖; 镀金
#
# n. 覆盖物; 轮廓纸
#
# **例句**：
#
# Show the top overlay and select Browse Guide from the navigation menu.
# 资料显示最常见覆盖,并选择浏览指南从导航菜单中.
#
# A topic overlay network search ( TONS ) algorithm, P 2 P search mechanism based on topic partition, is presented.
# 提出一种基于主题划分的P2P搜索算法———主题覆盖网络搜索算法 ( TONS ) .

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. while
# 2. enough
# 3. forth
# 4. tab
# 5. overlay
