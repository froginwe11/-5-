# %% [markdown]
# # Day46

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=47>

# %% [markdown]
# # variant
#
# 英\[ˈveəriənt\] 美\[ˈveriənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/variant)**
#
# n. （词等的）变体，（字音的）转讹; [生]变种，变异体; 变形，变量，转化; [统]变式
#
# adj. 变异的；不同的，相异的，不一致的；多样的；易变的，不定的
#
# **例句**：
#
# This property gets or sets a variant value for the range.
# 该属性获得或设置区域的值.
#
# Results Of all 24 lesions, the signal intensity was variant on T 1 WI an T 2 WI.
# 结果　病灶在T1WI和T2WI上信号多变.

# %% [markdown]
# # move
#
# 英\[muːv\] 美\[muːv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/move)**
#
# vt.& vi. 移动，搬动
#
# vi. 搬家; 行动; 进展; （机器等）开动
#
# vt. 提议; 使感动; 摇动; 变化
#
# n. 改变; 迁移
#
# **例句**：
#
# Move the handle to the left and the door will lock.
# 向左转动把手,门就会锁上.
#
# Firms are flocking after the government's offer of money to help them move to areas needing industry.
# 许多公司都想得到政府提供的旨在帮助他们迁向需要工业的地区的资助.

# %% [markdown]
# # direct
#
# 英\[dəˈrekt\] 美\[dəˈrekt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/direct)**
#
# adj. 直接的; 直的; 直系的; 率直的
#
# adv. 直接地; 径直地; 直截了当地; 正好
#
# vt. （用建议、指示、有益的情报等）指导; 导演（戏剧或电影）; 指示方向; 把…对准（某方向或某人）
#
# vt.& vi. 指导，导演，管理
#
# vi. 引路; 当向导; 领唱; 领奏
#
# **例句**：
#
# The army is now under the direct command of General Barton.
# 陆军现在由巴顿将军直接指挥.
#
# With no direct descendent, who will succeed to the title?
# 没有直系后裔, 谁来继承爵位 呢 ?

# %% [markdown]
# # searching
#
# 英\[ˈsɜ:tʃɪŋ\] 美\[ˈsɜrtʃɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/searching)**
#
# adj. 搜索的; 彻底的; 锐利的
#
# v. 找寻( search的现在分词 ); 搜查; 探查; [医学]（用仪器）探测（外伤）
#
# **例句**：
#
# He said he was searching for the truth.
# 他说他在找寻真理.
#
# He combed through the files searching for evidence of fraud.
# 他详查档案,寻找欺诈行为的证据.

# %% [markdown]
# # extremely
#
# 英\[ɪkˈstriːmli\] 美\[ɪkˈstriːmli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/extremely)**
#
# adv. 极端地; 非常，很; 去; 绝
#
# **例句**：
#
# The poor woman was extremely happy to be reunited with her two sons who had been carried off by a swindler.
# 这可怜的妇女为能跟他的两个被骗子拐走的儿子团聚一堂,感到喜出望外.
#
# The payment offered to the rank and file is extremely poor.
# 列兵的待遇极低.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. variant
# 2. move
# 3. direct
# 4. searching
# 5. extremely
