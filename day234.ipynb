# %% [markdown]
# # Day234

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=235>

# %% [markdown]
# # sound
#
# 英\[saʊnd\] 美\[saʊnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sound)**
#
# n. 声音，声响; 音调，声调; 声波; 嘈杂声
#
# vi. 响，发声; 听起来，好像; 回响; [音乐]乐器等被奏响
#
# vt. 使出声，使发声; 清楚地发出; 宣布，发表; 颂扬
#
# adj. 健全的; 合理的; 完好的，无损的; 明智的
#
# adv. 彻底地，充分地
#
# **例句**：
#
# Sound waves will not travel through a vacuum.
# 声波在真空里不能传播.
#
# Sound travels slower than light.
# 声音传播比光慢.

# %% [markdown]
# # slash
#
# 英\[slæʃ\] 美\[slæʃ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/slash)**
#
# vt. 挥砍; 鞭打; 严厉批评; 大幅削减
#
# vi. 严厉地批评; 猛砍
#
# n. 猛砍; 斜线; 刀痕，伤痕; 沼泽低地
#
# **例句**：
#
# You can rectify this fault if you insert a slash.
# 插人一条斜线便可以纠正此错误.
#
# Leigong lost justifications before revising the conditions for a slash at smb people.
# 雷公输了理,才修订了劈杀生灵的条件.

# %% [markdown]
# # retrieve
#
# 英\[rɪˈtriːv\] 美\[rɪˈtriːv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/retrieve)**
#
# vt. 取回; 恢复; [计]检索; 重新得到
#
# vi. 找回猎物
#
# **例句**：
#
# You retrieve a property's value by including the property name in an expression.
# 通过将属性名称包含在表达式中,可以检索属性的值.
#
# Within two minutes , can you retrieve any paper you need?
# 有一个测试可以用来检测你现在的归档系统是否运行良好.

# %% [markdown]
# # unpack
#
# 英\[ˌʌnˈpæk\] 美\[ʌnˈpæk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unpack)**
#
# vt.& vi. 从（包裹等）中取出（所装的东西），打开行李取出
#
# vt. 拆包; 解除…的负担; 吐露（心事等）; 卸下（车、马等）的负荷物
#
# **例句**：
#
# Carrying the bags upstairs is half the battle. Then we only have to unpack them.
# 把袋子搬上楼就做了一大半工作, 后面的事只需把袋子打开,取出里面的东西就行了.
#
# I'm just going to unpack my case.
# 我正要打开箱子取出里面的东西.

# %% [markdown]
# # browse
#
# 英\[braʊz\] 美\[braʊz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/browse)**
#
# vt.& vi. 浏览; 吃草; 随意翻阅
#
# **例句**：
#
# Show the top overlay and select Browse Guide from the navigation menu.
# 资料显示最常见覆盖,并选择浏览指南从导航菜单中.
#
# Select Browse Definition to view external components in the Object Browser.
# 选择“浏览定义”可在“对象浏览器”中查看外部组件.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. sound
# 2. slash
# 3. retrieve
# 4. unpack
# 5. browse
