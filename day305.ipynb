# %% [markdown]
# # Day305

# %% [markdown]
# # involve
#
# 英\[ɪnˈvɒlv\] 美\[ɪnˈvɑːlv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/involve)**
#
# vt. 包含; 使参与，牵涉; 围绕，缠绕; 使专心于
#
# **例句**：
#
# But what does it involve?
# 但是,它涉及什么事情?
#
# Giving advice at the right time has to involve a great deal of intelligence.
# 在适当的时间提建议需要人的睿智.

# %% [markdown]
# # just
#
# 英\[dʒʌst\] 美\[dʒʌst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/just)**
#
# adv. 刚才; 仅仅，只是; 正好; 刚要
#
# adj. 公正的，合理的; 恰当的; 合法的; 正确的
#
# **例句**：
#
# We can't get unwary just because nothing unusual has cropped up.
# 不能因为没发生什么问题就麻痹大意起来.
#
# They just handed the game to the other team on a plate.
# 他们让另一支球队轻易地赢得了这场比赛.

# %% [markdown]
# # normally
#
# 英\[ˈnɔːməli\] 美\[ˈnɔːrməli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/normally)**
#
# adv. 正常地; 通常地，一般地; 按说; 论理
#
# **例句**：
#
# Students will normally take three A2 subjects.
# 学生通常要选三门A2证书考试科目。
#
# I normally do all my shopping on Saturdays.
# 我通常在星期六买东西.

# %% [markdown]
# # paper
#
# 英\[ˈpeɪpə(r)\] 美\[ˈpeɪpər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/paper)**
#
# n. 纸; 文件; 论文; 文章
#
# adj. . 纸做的
#
# vt. 包装，用纸覆盖; 贴壁纸; 提供纸张; [俚语] 提供免费入场券
#
# vi. 贴糊墙纸; 发交通违章传票
#
# **例句**：
#
# Wad the space with paper, please.
# 请用报纸填塞空隙.
#
# We learned the matter from an American paper.
# 我们从一家美国报纸上获悉此事.

# %% [markdown]
# # array
#
# 英\[əˈreɪ\] 美\[əˈreɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/array)**
#
# n. 队列，阵列; 数组; 一大批; 衣服
#
# vt. 排列; 部署兵力; 打扮，装饰
#
# **例句**：
#
# Links to topics that explain how to enter array, Boolean, numeric, string, and object data.
# 指向特定主题的链接,这些主题解释如何输入数组 、 布尔值 、 数值 、 字符串和对象数据.
#
# Programmable logic, in particular field programmable gate array ( FPGA ) is such a solution.
# 可编程逻辑, 特别是现场可编程门阵列 ( FPGA ) 便是这样的解决方案.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. involve
# 2. just
# 3. normally
# 4. paper
# 5. array
