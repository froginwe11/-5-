# %% [markdown]
# # Day261

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=262>

# %% [markdown]
# # declaration
#
# 英\[ˌdekləˈreɪʃn\] 美\[ˌdekləˈreɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/declaration)**
#
# n. 宣言，布告，公告，声明; （纳税品在海关的）申报; [法]（原告的）申诉，（证人的）陈述，口供; [牌]摊牌，叫牌
#
# **例句**：
#
# Declaration of Corporate Income Tax.
# 公司所得税的申报.
#
# Completing the declarations of class Outer puts the declaration of the function handle in scope.
# 对Outer类声明的完成将函数handle的声明放在作用域中.

# %% [markdown]
# # possible
#
# 英\[ˈpɒsəbl\] 美\[ˈpɑːsəbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/possible)**
#
# adj. 可能的; 可接受的; 合理的，可以允许的; 不坏的
#
# n. 可能性，潜在性; 可能的人物，可能有的事; 最高分
#
# **例句**：
#
# It is possible to cure psoriasis.
# 牛皮癣是可以治好的.
#
# It is possible to go to the moon now.
# 现在有可能登上月球.

# %% [markdown]
# # hidden
#
# 英\[ˈhɪdn\] 美\[ˈhɪdn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hidden)**
#
# adj. 隐藏的; 神秘的; 秘密的
#
# v. 隐藏( hide的过去分词)
#
# **例句**：
#
# I have $100m hidden away where no one will ever find it.
# 我把1亿美元藏到了一个永远没人会找到的地方。
#
# Under all the innocent fun, there are hidden dangers, especially for children.
# 在所有简单无害的娱乐项目背后都隐藏着危险，特别是对儿童而言。

# %% [markdown]
# # segment
#
# 英\[ˈseɡmənt , seɡˈment\] 美\[ˈseɡmənt , seɡˈment\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/segment)**
#
# n. 部分，段落; 环节; [计算机]（字符等的）分段; [动物学]节片
#
# v. 分割；划分
#
# **例句**：
#
# A transcript and audio of the segment are available online.
# 网上提供节目的文字和声音.
#
# A rollback segment is only online until the instance is shut down.
# 直到实例关闭后,回滚段才联机.不明白什么意思.

# %% [markdown]
# # restrict
#
# 英\[rɪˈstrɪkt\] 美\[rɪˈstrɪkt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/restrict)**
#
# vt. 限制，限定; 约束，束缚
#
# **例句**：
#
# Record each user can restrict the IP number to prevent infinite growing database.
# 可以限制每个用户记录的IP数,防止数据库无限增大.
#
# This phenomenon restrict comment on full playing of function seriously.
# 这种“重论轻评”现象严重制约了评论功能的发挥.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. declaration
# 2. possible
# 3. hidden
# 4. segment
# 5. restrict
