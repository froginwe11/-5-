# %% [markdown]
# # Day90

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=91>

# %% [markdown]
# # reformat
#
# 英\[ri:ˈfɔ:mæt\] 美\[riˈfɔrmæt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reformat)**
#
# 重定格式
#
# **例句**：
#
# Could not reformat the document. The original format was restored.
# 未能重新格式化文档. 已还原为原始格式.
#
# Click to reformat the grid using current settings.
# 单击此处可使用当前设置重新设置网格格式.

# %% [markdown]
# # handle
#
# 英\[ˈhændl\] 美\[ˈhændl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/handle)**
#
# n. （织物、毛皮等的）手感; 手柄; 举动; 柄状物
#
# vi. 操作，操控; 容易搬运
#
# vt. 用双手触摸、举起或握住; 用手操作，操纵; 处理或负责，管理; 〈美〉买卖，经营
#
# **例句**：
#
# Move the handle to the left and the door will lock.
# 向左转动把手,门就会锁上.
#
# He felt about in the dark for the door handle.
# 他在黑暗中摸索着找门把手.

# %% [markdown]
# # block
#
# 英\[blɒk\] 美\[blɑːk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/block)**
#
# n. 块; 街区; <英>大楼，大厦; 障碍物，阻碍
#
# vt. 阻止; 阻塞; 限制
#
# **例句**：
#
# Tell me where you've been out so late, or I'll knock your block off.
# 告诉我你到哪儿去了,这么晚才回来, 不说我就揍死你.
#
# The students occupied the Administration Block.
# 学生占领行政大楼.

# %% [markdown]
# # tick
#
# 英\[tɪk\] 美\[tɪk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/tick)**
#
# n. 钩号; 标记; 一瞬间; 壁虱; 钟的嘀嗒声
#
# v. 给…做标记; 在（纸）上打钩; 做出…举动; 发出滴答声
#
# **例句**：
#
# Use to add a slider with adjustable tick style and slide button to an interface.
# 用于将带有可调刻度样式和滑动按钮的滑块添加到界面上.
#
# A tick is the smallest price fluctuation permitted in any market.
# 基点是市场允许的最小的变动单位.

# %% [markdown]
# # combo
#
# 英\[ˈkɒmbəʊ\] 美\[ˈkɑmboʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/combo)**
#
# n. 小型爵士乐队，小型伴舞乐队; <美口>套餐，如色拉、三明治、饮料等的组合食物; 组合; 套餐
#
# **例句**：
#
# Because a combo box contains an edit field, some combo box qualify as entry controls, too.
# 因为组合框包含一个编辑字段, 所以一些组合框的变体也能作为输入控件.
#
# Invalid message for a combo box because it does not have an edit control.
# 因为没有编辑控制,所以组合框的消息无效.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. reformat
# 2. handle
# 3. block
# 4. tick
# 5. combo
