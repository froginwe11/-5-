# %% [markdown]
# # Day157

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=158>

# %% [markdown]
# # independently
#
# 英\[ˌɪndɪ'pendəntlɪ\] 美\[ˌɪndɪˈpɛndəntlɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/independently)**
#
# adv. 独立地，自立地，无关地
#
# **例句**：
#
# Ceiling and wall lights can operate independently.
# 吊灯和壁灯可单独开关。
#
# The commission will operate independently of ministers.
# 委员会将独立运作，不受各部部长管辖。

# %% [markdown]
# # delay
#
# 英\[dɪˈleɪ\] 美\[dɪˈleɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/delay)**
#
# n. 延迟，拖延; 耽搁; 被耽搁或推迟的时间
#
# vt. 延期，推迟; 耽搁
#
# vi. 延缓，延期
#
# **例句**：
#
# His delay made the teacher angry.
# 他的迟到使老师生气了.
#
# The assembly voted to delay the legislation to allow further consultation to take place.
# 议会投票决定暂缓立法以便进一步磋商.

# %% [markdown]
# # mountain
#
# 英\[ˈmaʊntən\] 美\[ˈmaʊntn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/mountain)**
#
# n. 山，山岳; 山脉; 一大堆; 大量
#
# **例句**：
#
# Clouds involved the mountain top.
# 云雾笼罩山头.
#
# He fell behind when we were climbing the mountain.
# 我们爬山时,他掉队了.

# %% [markdown]
# # subscript
#
# 英\['sʌbskrɪpt\] 美\[ˈsʌbˌskrɪpt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/subscript)**
#
# adj. 下标的，写在下方的，脚注的
#
# n. 下标，脚注，下角数码
#
# **例句**：
#
# The subscript O and W identify the unweathered and weathered states.
# 下标O和W分别表示属于未风化和已风化的状态.
#
# In a single - species fluid, the subscript may be dropped.
# 对于 单组分 流体, 这个下标可以省略.

# %% [markdown]
# # basic
#
# 英\[ˈbeɪsɪk\] 美\[ˈbeɪsɪk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/basic)**
#
# adj. 基本的; [化学]碱性的; [地质学]基性的; 首要的
#
# **例句**：
#
# This law will deprive us of our most basic rights.
# 这条法律将剥夺我们最基本的权利.
#
# The adornments do not cohere with the basic design.
# 装饰物与设计的基调不协调.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. independently
# 2. delay
# 3. mountain
# 4. subscript
# 5. basic
