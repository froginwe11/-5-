# %% [markdown]
# # Day320

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=321>

# %% [markdown]
# # near
#
# 英\[nɪə(r)\] 美\[nɪr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/near)**
#
# adv. （空间）在近处; 在附近; （时间）临近; （程度）几乎
#
# prep. （表示程度）接近; （表示位置）靠近; （表示时间）将近; 接近于（某种状态）
#
# adj. 近的; 亲密的; 近似; （亲属关系）近亲
#
# **例句**：
#
# They were unaware that war was near.
# 他们不知道战争即将爆发.
#
# We had a few near misses in the first raid.
# 在第一次袭击中,有几次我们都差一点就命中目标.

# %% [markdown]
# # force
#
# 英\[fɔːs\] 美\[fɔːrs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/force)**
#
# n. 力; 武力; （社会）势力; 魄力
#
# vt. 强迫; 强行; 促使，推动; 强奸
#
# **例句**：
#
# We had to use force to get into the house.
# 我们不得不强行进屋.
#
# The agreement shall enter into force upon signature.
# 协定签字后立即生效.

# %% [markdown]
# # element
#
# 英\[ˈelɪmənt\] 美\[ˈelɪmənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/element)**
#
# n. [化]元素; 要素; 原理; [电]电阻丝
#
# **例句**：
#
# Thus, the role of alloying element depends mainly on its impact on the state diagram.
# 因此, 合金元素的作用主要取决于其对状态图的影响.
#
# The refrigerating machine set comprises a compressor, a condenser, a throttling element and an evaporator.
# 所述的制冷机组包括有压缩机, 冷凝器 、 节流元件和蒸发器.

# %% [markdown]
# # administrator
#
# 英\[ədˈmɪnɪstreɪtə(r)\] 美\[ədˈmɪnɪstreɪtər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/administrator)**
#
# n. 管理者; 有管理（或行政）才能的人; [法]（由遗嘱检验法庭指定的）遗产管理人; 地产管理人
#
# **例句**：
#
# If an administrator has no access to information, it's as if he was purblind and hard of hearing and had a stuffed nose.
# 做管理工作的人没有信息, 就是鼻子不通,耳目不灵.
#
# Only a system administrator can reassign tasks.
# 只有系统管理员才能重新指派任务.

# %% [markdown]
# # item
#
# 英\[ˈaɪtəm\] 美\[ˈaɪtəm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/item)**
#
# n. 条，条款; 项目; 一则; 一件商品（或物品）
#
# **例句**：
#
# Does this item go among the credits or the debits?
# 这笔账应记入贷方还是借方?
#
# This single item will suffice to typify all the rest.
# 即此一端,可概其余.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. near
# 2. force
# 3. element
# 4. administrator
# 5. item
