# %% [markdown]
# # Day76

# %% [markdown]
# # handler
#
# 英\[ˈhændlə(r)\] 美\[ˈhændlɚ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/handler)**
#
# n. 处理者，管理者; （动物）驯化者; [自]（信息）处理机; 拳击教练
#
# **例句**：
#
# When a user performs a specific action, the correct UI Handler is called.
# 当用户执行某个特定操作时, 系统会调用可用的用户交互处理器.
#
# Cannot register control callback handler for service { 0 }.
# 无法注册服务{0}的控件回调处理程序.

# %% [markdown]
# # masking
#
# 英\['mɑ:skɪŋ\] 美\['mɑskɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/masking)**
#
# n. 化装
#
# v. 用面具遮住，掩盖，掩饰( mask的现在分词 )
#
# **例句**：
#
# He is good at masking his real character behind an assumed manner.
# 他善于用伪装的举止来掩饰其真正的性格.
#
# He went to the masked ball without masking his face.
# 他去参加化装舞会而没戴假面具.

# %% [markdown]
# # declare
#
# 英\[dɪˈkleə(r)\] 美\[dɪˈkler\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/declare)**
#
# vt. 宣布; 声明，声称; 申报; [法]供述
#
# vi. 声明，发表宣言; 宣称
#
# **例句**：
#
# If any objection, I'll declare the meeting closed.
# 如果没人反对, 我就宣布会议结束.
#
# Customs Anything to declare?
# 海关官员:有什么要申报的 吗 ?

# %% [markdown]
# # sensitivity
#
# 英\[ˌsensəˈtɪvəti\] 美\[ˌsensəˈtɪvəti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sensitivity)**
#
# n. 敏感，感受性; 仪器等的)灵敏性; [摄]感光度
#
# **例句**：
#
# The results revealed mild lowering contrast sensitivity at high spatial frequency for our glaucoma patients.
# 然而特定轴度之闪光眩耀测试结果并未见明显差别.
#
# The manufacturing technology oxygen sensor is simple oxygensensoroxygen with high sensitivity and high selectivity.
# 该元件制作工艺简单,对O_ 2具有较高的灵敏度和很好的选择性.

# %% [markdown]
# # differentiate
#
# 英\[ˌdɪfəˈrenʃieɪt\] 美\[ˌdɪfəˈrenʃieɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/differentiate)**
#
# vt.& vi. 区分，区别，辨别
#
# vi. 区别对待
#
# vt. 表明…间的差别，构成…间差别的特征; [数学] 求…的微分：计算导数或（函数的）微分
#
# **例句**：
#
# Accordingly, economy of compendious market of differentiate and and intellectual economy, have important real sense undoubtedly.
# 因此, 简明地辨析市场经济和知识经济, 无疑具有重要的现实意义.
#
# Differentiate and explain the different adjustments in work schedules.
# 区分和解释调整工作时间的各种方法.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. handler
# 2. masking
# 3. declare
# 4. sensitivity
# 5. differentiate
