# %% [markdown]
# # Day214

# %% [markdown]
# # somewhat
#
# 英\[ˈsʌmwɒt\] 美\[ˈsʌmwʌt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/somewhat)**
#
# adv. 稍微; 有点; 达到某种程度
#
# **例句**：
#
# This embarassed me somewhat.
# 这使我有点困窘.
#
# His hearing is somewhat impaired.
# 他的听觉已受到一定程度的损害.

# %% [markdown]
# # form
#
# 英\[fɔːm\] 美\[fɔːrm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/form)**
#
# n. 形状，形式; 外形; 方式; 表格
#
# vt. 形成; 构成; 组织; 塑造
#
# vi. 形成，产生; 排队，整队
#
# **例句**：
#
# Canals and rivers form the inland waterways of a country.
# 运河和江河构成了一个国家的内河水路.
#
# Division is a form of computation.
# 除法是一种运算方法.

# %% [markdown]
# # process
#
# 英\[ˈprəʊses , prəˈses\] 美\[ˈprɑːses , prəˈses\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/process)**
#
# n. 过程; 工序; 做事方法; 工艺流程
#
# vt. 加工; 处理; 审阅; 审核
#
# vi. 列队行进
#
# **例句**：
#
# The process of adjustment to life in another country can be very difficult.
# 适应另一国家的生活可能会非常困难.
#
# There's still one more step in the process.
# 还差一道工序.

# %% [markdown]
# # transaction
#
# 英\[trænˈzækʃn\] 美\[trænˈzækʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/transaction)**
#
# n. 交易，业务，事务; 办理，处理; （一笔）交易，（一项）事务; （学会等的）会议记录，学报
#
# **例句**：
#
# Truth: Business in China is not be perceived as solely a transaction of money and time.
# 真理: 在中国,商业不能仅仅被看成是金钱和时间的交换.
#
# Transaction process is the necessary basis for constructing enterprise application.
# 事务处理是构建企业级应用的必要基础.

# %% [markdown]
# # hexadecimal
#
# 英\[ˌheksəˈdesɪml\] 美\[ˌhɛksəˈdɛsəməl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hexadecimal)**
#
# adj. 十六进制的
#
# **例句**：
#
# When a hexadecimal conversion is specified , hexadecimal characters are in upper case.
# 如果被转为16进制数字, 那么16进制字符将用大写表示.
#
# When a hexadecimal conversion is specified , hexadecimal characters are in lower case.
# 如果被转为16进制数字, 那么16进制字符将用小写表示.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. somewhat
# 2. form
# 3. process
# 4. transaction
# 5. hexadecimal
