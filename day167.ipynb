# %% [markdown]
# # Day167

# %% [markdown]
# # frequently
#
# 英\[ˈfriːkwəntli\] 美\[ˈfriːkwəntli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/frequently)**
#
# adv. 频繁地，屡次地; 往往; 动; 动辄
#
# **例句**：
#
# He was so engrossed in his work that he frequently stayed up until the small hours.
# 他全神贯注地工作,经常工作到下半夜.
#
# Host and guests frequently raised their glasses during the feast.
# 席间宾主频频举杯.

# %% [markdown]
# # means
#
# 英\[miːnz\] 美\[miːnz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/means)**
#
# n. 方法; 手段; 收入; 财富
#
# v. 意味着（ mean的第三人称单数）; 引起; 打算或注定要某人成为或做某事
#
# **例句**：
#
# It is by no means accidental.
# 事出有因.
#
# Courtesy costs little and means much.
# 礼节并不失去什么却获益甚多.

# %% [markdown]
# # maximum
#
# 英\[ˈmæksɪməm\] 美\[ˈmæksɪməm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/maximum)**
#
# adj. 最大值的，最大量的
#
# n. 最大的量、体积、强度等
#
# **例句**：
#
# The speed limit is 40 miles an hour. Don't exceed this maximum.
# 限速每小时四十英里, 不要超过这个极限.
#
# The journey was accomplished with a maximum of comfort and ease and a minimum of discomfort.
# 带着最大限度的舒适和轻松结束了这一旅程,很少有什么不舒适.

# %% [markdown]
# # thereafter
#
# 英\[ˌðeərˈɑːftə(r)\] 美\[ˌðerˈæftər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/thereafter)**
#
# adv. 此后，在那之后; 〈罕〉据此
#
# **例句**：
#
# But as to what happened thereafter , that will be disclosed in the ensuing chapter.
# 欲知后事如何, 且听下回分解.
#
# Yuan died shortly thereafter and his regime was overthrown.
# 不久袁世凯身死,洪宪帝制被废.

# %% [markdown]
# # terminology
#
# 英\[ˌtɜːmɪˈnɒlədʒi\] 美\[ˌtɜːrmɪˈnɑːlədʒi\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/terminology)**
#
# n. 专门名词; 术语，术语学; 用辞
#
# **例句**：
#
# That a midfield diamond in Mourinho terminology.
# 用老穆的话来讲,这是个菱形中场.
#
# Entity Framework language elements and terminology are explained in more detail in Entity Framework Terminology.
# 实体框架术语中更加详细地介绍了实体框架语言元素和术语.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. frequently
# 2. means
# 3. maximum
# 4. thereafter
# 5. terminology
