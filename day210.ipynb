# %% [markdown]
# # Day210

# %% [markdown]
# # identically
#
# 英\[aɪ'dentɪklɪ\] 美\[aɪ'dentɪklɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/identically)**
#
# adv. 同一地，相等地
#
# **例句**：
#
# The body must return identically to its original condition when the loads are released.
# 当去掉载荷时,物体必须恢复到与原来完全一样的状态.
#
# The motion is periodic, which means it occurs identically over and over again.
# 这个运动是周期的, 意即运动以同样的形式重复出现.

# %% [markdown]
# # programmable
#
# 英\[ˈprəʊgræməbl\] 美\[ˈproʊgræməbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/programmable)**
#
# adj. 可设计的，可编程的; 可编程序
#
# **例句**：
#
# Programmable logic, in particular field programmable gate array ( FPGA ) is such a solution.
# 可编程逻辑, 特别是现场可编程门阵列 ( FPGA ) 便是这样的解决方案.
#
# Let's at some of the specific programmable functions.
# 让我们来看一下具体的可编程功能.

# %% [markdown]
# # phone
#
# 英\[fəʊn\] 美\[foʊn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/phone)**
#
# n. 电话; 听筒; （发声或使用声音的）工具; 说某种语言的
#
# vt.& vi. 打电话（给某人）
#
# **例句**：
#
# Using a false accent over the phone is a sign of inferiority.
# 打电话时故意作出某种口音是自卑的表现.
#
# The police monitored all of Steve's phone calls.
# 警察监听史蒂夫的所有电话.

# %% [markdown]
# # debugger
#
# 英\[ˌdiːˈbʌɡə(r)\] 美\[ ˌdiːˈbʌɡər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/debugger)**
#
# n. 调试器
#
# **例句**：
#
# SmartARM in I 2 C package, has been run through the debugger.
# SmartARM中 的I2C软件包, 已经通过调试可以运行.
#
# Pattern recognition classifier design, the source for the LMS method, adopted by the debugger.
# 模式识别分类器的设计, 此为LMS法源码, 经调试通过.

# %% [markdown]
# # language
#
# 英\[ˈlæŋɡwɪdʒ\] 美\[ˈlæŋɡwɪdʒ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/language)**
#
# n. 语言，语言文字; 表达能力; 言语，语风，文风，文体; 专门用语，术语
#
# **例句**：
#
# A foreign language cannot be learned rapidly, it must be learned step by step.
# 外语并非在短时间内就能学会, 学外语是一个循序渐进的过程.
#
# She has mastered a foreign language by aid of a grammar and dictionary.
# 她借助语法书和词典掌握了一门外语.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. identically
# 2. programmable
# 3. phone
# 4. debugger
# 5. language
