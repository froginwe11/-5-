# %% [markdown]
# # Day19

# %% [markdown]
# # underscore
#
# 英\[ˌʌndəˈskɔ:(r)\] 美\[ˌʌndərˈskɔ(r)\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/underscore)**
#
# n. 下划线，底线
#
# v. 强调，突出; 在（字词、句子等）下画线
#
# **例句**：
#
# These results underscore the value of rescue medications in averting psychotic relapse.
# 这些结果显示了救护性治疗对避免精神病复发的价值.
#
# A word character is any letter, decimal digit, or punctuation connector such as the underscore.
# 单词字符是任何字母 、 十进制数字或标点连接符(如下划线).

# %% [markdown]
# # performance
#
# 英\[pəˈfɔːməns\] 美\[pərˈfɔːrməns\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/performance)**
#
# n. 表演; 演技; 表现; 执行
#
# **例句**：
#
# His performance at the concert last night proved that he is in the top flight of international pianists.
# 昨晚他在音乐会上的演奏证明他在国际钢琴家中居首位.
#
# The audience was fascinated by their superb performance.
# 他们的精彩表演使观众看得入了迷.

# %% [markdown]
# # rectangle
#
# 英\[ˈrektæŋɡl\] 美\[ˈrektæŋɡl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/rectangle)**
#
# n. [数]长方形，矩形
#
# **例句**：
#
# The spine of each section is printed with rectangle or short thick rule called collation mark.
# 在每帖的帖脊印上称为帖标的黑色方块或粗黑短线.
#
# A torus can be obtained from a rectangle by identifying opposite sides.
# 环面可由矩形把其两对对边分别重叠起来而得到.

# %% [markdown]
# # second
#
# 英\[ˈsekənd , sɪˈkɒnd\] 美\[ˈsekənd , sɪˈkɑːnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/second)**
#
# n. 秒; 瞬间; 次货; 第二份食物
#
# adv. 第二; 其次; 以第二位
#
# vt. 支持; 临时调派; 附议; 赞成提案
#
# **例句**：
#
# You will need a second pair of shoes.
# 你需要再准备一双鞋.
#
# The young German runner finished a creditable second.
# 这名年轻的德国赛跑运动员获得了当之无愧的第二名.

# %% [markdown]
# # reduce
#
# 英\[rɪˈdjuːs\] 美\[rɪˈduːs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reduce)**
#
# vt. 减少; 缩小; 使还原; 使变弱
#
# vi. 减少; 节食; 蒸发; （液体）浓缩变稠
#
# **例句**：
#
# We must carry on the patriotic public health campaign with a great fanfare, reduce disease and improve health conditions.
# 要大张旗鼓地开展爱国卫生运动, 减少疾病,提高健康水平.
#
# The government must make new policies to reduce unemployment.
# 政府必须制定减少失业的新政策.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. underscore
# 2. performance
# 3. rectangle
# 4. second
# 5. reduce
