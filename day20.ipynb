# %% [markdown]
# # Day20

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=21>

# %% [markdown]
# # string
#
# 英\[strɪŋ\] 美\[strɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/string)**
#
# n. 绳子，带子; 线丝，植物纤维; 串; [计算机科学]字符串
#
# vt. 上弦，调弦; 使排成一行或一系列; 绑，系或用线挂起; 延伸或扩展
#
# adj. 由弦乐器组成的；弦乐器的,线织的；线的
#
# **例句**：
#
# With a few pluck at the string of his banjo, everybody is singing along.
# 他拨了拨班卓琴的琴弦, 每个人就都跟著唱了起了.
#
# As both a novelist and a university lecturer, she has another string to her bow.
# 身兼小说家及大学讲师, 她有一个可替换的办法.

# %% [markdown]
# # width
#
# 英\[wɪdθ\] 美\[wɪdθ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/width)**
#
# n. 宽度; 广度
#
# **例句**：
#
#
# Measure the full width of the window
# 测量一下窗户的全宽。
#
# Wireless demand and usage have exploded across the width and breadth of Latin America.
# 整个拉丁美洲对无线通信的需求和使用已急速增加.

# %% [markdown]
# # else
#
# 英\[els\] 美\[els\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/else)**
#
# adv. 其他; 否则; 另外
#
# **例句**：
#
# Nobody else knows barring you and me.
# 除你我之外无人知道.
#
# In this matter we must place the common cause above all else.
# 在这件事情上,我们必须把共同事业放在高于一切的位置上.

# %% [markdown]
# # running
#
# 英\[ˈrʌnɪŋ\] 美\[ˈrʌnɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/running)**
#
# n. 跑步; 运转; 流出
#
# adj. 跑着的; 流动的; 连续的; 操作中的，运转着的
#
# v. 跑; 运转(run的ing形式)
#
# **例句**：
#
# My garden is running to weeds.
# 我的院子里长满了杂草.
#
# Running ten miles is no mean achievement.
# 跑十英里是了不起的成绩.

# %% [markdown]
# # length
#
# 英\[leŋθ\] 美\[leŋθ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/length)**
#
# n. 长度，长; 时间的长短; （语）音长; 一段，一节
#
# **例句**：
#
# The area can easily be worked out if you know the length and the breadth.
# 如果你知道长度与宽度,面积很容易计算出来.
#
# He skated the length of the rink without stopping.
# 他一下子滑过了整个溜冰场.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. string
# 2. width
# 3. else
# 4. running
# 5. length
