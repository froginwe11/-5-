# %% [markdown]
# # Day332

# %% [markdown]
# # separately
#
# 英\[ˈseprətli\] 美\[ˈsɛpərɪtlɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/separately)**
#
# adv. 分别地，另行; 分开，单独; 分离地; 个别地
#
# **例句**：
#
# Official publish retail price list for each model is available separately.
# 各款型号之公布零售价目表另行提供.
#
# Careful inspection showed that the statue's head had been cast separately and soldered in place.
# 仔细检查发现雕像的头部是铸好后再焊接上去的.

# %% [markdown]
# # cash
#
# 英\[kæʃ\] 美\[kæʃ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/cash)**
#
# n. 现金; 支付金额
#
# vt. 支付现款; 兑现
#
# **例句**：
#
# Cash on hand tallies with the figure in the accounts.
# 现款跟账上的数目没有出入.
#
# He's not easily parted from his cash.
# 叫他拿出现钱不大容易.

# %% [markdown]
# # selected
#
# 英\[sɪ'lektɪd\] 美\[sɪ'lektɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/selected)**
#
# adj. 经由选择的，挑选的
#
# v. 选择，挑选( select的过去式和过去分词 )
#
# **例句**：
#
# She selected a low gear and started down the track carefully.
# 她选了低速挡小心翼翼地沿小径下行。
#
# Price quotes on selected product categories will be sent on request.
# 所选产品类别的报价承索即寄。

# %% [markdown]
# # asterisk
#
# 英\[ˈæstərɪsk\] 美\[ˈæstəˌrɪsk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/asterisk)**
#
# n. 星号，星状物
#
# **例句**：
#
# The asterisk character is believed to be related to the understanding of ancient people on astrology.
# 星号符号据认为讲述是远古人类对占星术的理解.
#
# You can use the asterisk anywhere in a string.
# 可在字符串中的任意位置使用星号.

# %% [markdown]
# # create
#
# 英\[kriˈeɪt\] 美\[kriˈeɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/create)**
#
# vt. 创造，创作; 产生; 封爵，把…封为（贵族）
#
# vi. [英][俚]大发脾气，大发牢骚
#
# **例句**：
#
# You needn't create about it.
# 你不必为它大惊小怪.
#
# If anything, it could create a clampdown on democratic tendencies by regimes in neighbouring countries.
# 如果其主张会产生什么结果的话, 那就是会使周边国家的政府对民主潮流进行压制.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. separately
# 2. cash
# 3. selected
# 4. asterisk
# 5. create
