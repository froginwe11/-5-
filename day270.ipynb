# %% [markdown]
# # Day270

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=271>

# %% [markdown]
# # keypad
#
# 英\[ˈki:pæd\] 美\[ˈkiˌpæd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/keypad)**
#
# n. 键区
#
# **例句**：
#
# Use the numeric keypad on your remote to enter letters to rename the manual record.
# 使用遥控器上的数字小键盘输入字母以重命名手动录制.
#
# Do you want to use your numeric keypad instead of the mouse?
# 您想不用鼠标,而使用数字键盘 吗 ?

# %% [markdown]
# # environ
#
# 英\[ɪn'vaɪərən\] 美\[ɛnˈvaɪrən, -ˈvaɪən\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/environ)**
#
# vt. 包围，环绕，（敌意地或保护性的）围住
#
# **例句**：
#
# Il é tait environ onze heures.
# 这时大约十一点钟.
#
# Trees environ the yard.
# 树木环绕着那个院子.

# %% [markdown]
# # temporary
#
# 英\[ˈtemprəri\] 美\[ˈtempəreri\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/temporary)**
#
# adj. 临时的，暂时的; 短暂的
#
# **例句**：
#
# Opportunism consists of sacrificing fundamental interests in order to gain temporary, partial benefits.
# 机会主义就是牺牲根本的利益,贪图暂时的 、 局部的利益.
#
# In his defense he alleged temporary insanity.
# 他伪称一时精神错乱,为自己辩解.

# %% [markdown]
# # repeatedly
#
# 英\[rɪˈpiːtɪdli\] 美\[rɪˈpiːtɪdli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/repeatedly)**
#
# adv. 反复地，重复地; 再三地; 屡次地; 不停地
#
# **例句**：
#
# As we have repeatedly tested, the battery working hours for 20 hours.
# 经我们反复测试, 电池工作时间为20小时.
#
# Promises of reform have been made repeatedly before.
# 此前已经作过许多有关改革的承诺.

# %% [markdown]
# # empty
#
# 英\[ˈempti\] 美\[ˈempti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/empty)**
#
# adj. 空的，空虚的，空洞的; 空闲的，无效的，徒劳的; 无聊的，愚蠢的; 言语或行动空洞的
#
# vt. （使）成为空的， 把…弄空; 把…腾出来
#
# vi. 成为空的; 流空
#
# **例句**：
#
# His wordy and empty speech was a frost.
# 他的冗长空洞的讲话使人厌烦.
#
# Empty talk is no good.
# 空谈没有好处.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. keypad
# 2. environ
# 3. temporary
# 4. repeatedly
# 5. empty
