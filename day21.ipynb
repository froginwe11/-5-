# %% [markdown]
# # Day21

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=22>

# %% [markdown]
# # set
#
# 英\[set\] 美\[set\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/set)**
#
# vt. 放置，安置; 使处于某种状况; 设置; 摆放餐具
#
# vi. 落山; 出发; 凝结
#
# n. 一套，一副; 集合; 布景; 电视机
#
# adj. 固定的; 位于…的; 顽固的; 安排好的
#
# **例句**：
#
# They sought to set perpetual Zions there.
# 他们企图在那里建立永恒的乐园.
#
# Tazief was able to set up his camp very close to the volcano while it was erupting violently.
# 泰哲夫在火山猛烈爆发的时候,终于设法在离火山很近的地方搭起了帐蓬.

# %% [markdown]
# # respectively
#
# 英\[rɪˈspektɪvli\] 美\[rɪˈspektɪvli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/respectively)**
#
# adv. 各自地; 各个地; 分别地
#
# **例句**：
#
# The lean % of Landrace × Dahe , Duroc × Dahe made 52.32 % and 53.32 % respectively.
# 长×大、杜×大组合的瘦肉率分别达到52.32%和53.32%.
#
# In the middle stage, Dinggui and Furong powders were scattered on plasters respectively.
# 后期单用丁桂散或芙蓉粉直接撒在棉花上外敷.

# %% [markdown]
# # sector
#
# 英\[ˈsektə(r)\] 美\[ˈsektər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sector)**
#
# n. 部门; 领域; 防御地区; 扇形
#
# **例句**：
#
# The DOE first announced the project, a prototype for the private sector, in 2003.
# 2003年能源部首次公布了这个计划, 以私有部门为样板.
#
# The new salary deal for railway workers will be a bench mark for pay settlements in the public sector.
# 给铁路工人的新工资待遇将会成为公务部门工资问题的标准.

# %% [markdown]
# # effort
#
# 英\[ˈefət\] 美\[ˈefərt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/effort)**
#
# n. 努力，尝试; 工作; 成就; 杰作
#
# **例句**：
#
# He did the work without effort.
# 他很轻松地就把工作做好了.
#
# She made a feeble effort to get to school on time.
# 她努力想按时赶到学校,但未成功.

# %% [markdown]
# # sequence
#
# 英\[ˈsiːkwəns\] 美\[ˈsiːkwəns\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/sequence)**
#
# n. [数]数列，序列; 顺序; 连续; 片断插曲
#
# vt. 使按顺序排列，安排顺序; [生化]确定…的顺序，确定…的化学结构序列
#
# **例句**：
#
# For the same blending system, the penetration rates for acetic ether , absolute alcohol and gasoline sequence.
# 对同一体系, 对乙酸乙酯渗透率最小,无水乙醇次之, 汽油最大.
#
# Progressive develop in proper sequence is the Basic Law stipulates that Hong Kong's constitutional development model.
# 繁体字循序渐进是基本法规定香港政制发展的模式.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. set
# 2. respectively
# 3. sector
# 4. effort
# 5. sequence
