# %% [markdown]
# # Day220

# %% [markdown]
# # job
#
# 英\[dʒɒb\] 美\[dʒɑːb\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/job)**
#
# n. （一件）工作; 职责; 职业; （作为一个单元处理的）作业
#
# **例句**：
#
# We have the steel to get this job done.
# 我们有决心把这工作做完.
#
# He traded a job in New York City for the life of a cowboy.
# 他放弃了在纽约的工作,去过牛仔生活.

# %% [markdown]
# # guard
#
# 英\[ɡɑːd\] 美\[ɡɑːrd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/guard)**
#
# n. 警卫; 狱吏，看守; 护卫队; 防护装置
#
# vt. 保卫，守护; 看守; 加防护装置; 谨慎使用
#
# vi. 警惕; 警卫
#
# **例句**：
#
# I'll mount guard over the luggage while you get the ticket.
# 你去买票,我来看管行李.
#
# Guard the secret with your life, tell it to no one!
# 你要以生命来保守秘密, 不要告诉任何人.

# %% [markdown]
# # small
#
# 英\[smɔːl\] 美\[smɔːl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/small)**
#
# adj. 小的; 难为情的; 低级的，卑劣的; 细微的，微弱的
#
# adv. 小小地; 卑鄙地
#
# n. 细小部分，腰部; 琐碎东西; 身份低的人; 矮小的人
#
# **例句**：
#
# By frugality she managed to get along on her small salary.
# 凭着节俭,她设法以自己微薄的薪水生活.
#
# He failed, and small wonder.
# 他失败了, 这没什么奇怪.

# %% [markdown]
# # ship
#
# 英\[ʃɪp\] 美\[ʃɪp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/ship)**
#
# n. 船; <口>宇宙飞船; （舰船上的）全体船员; 运气
#
# vt.& vi. 运送
#
# vt. 把…装上船; 装好（船具）; 上市; 使乘船
#
# vi. 在船上工作; 乘船旅行; 当船员
#
# **例句**：
#
# The ship drifted helplessly for a time.
# 那艘船孤零无依地漂泊了一阵子.
#
# The captain ordered all sails lowered so the ship could ride out the storm.
# 船长命令把所有的帆放下以便船只安全渡过暴风雨.

# %% [markdown]
# # branch
#
# 英\[brɑːntʃ\] 美\[bræntʃ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/branch)**
#
# n. 树枝; 分支; 部门，分科; 支流
#
# vi. 分支形成; 分支扩张; 扩大某人的兴趣，业务或活动范围; [计]下分支的指令
#
# vt. 使分支; 使分叉; 用枝形叶脉刺绣花纹装饰
#
# **例句**：
#
# The two halves of the main branch have grown apart.
# 主枝的左右两边各向不同的方向生长.
#
# The branch bent but did not break.
# 那树枝弯曲,但没有折断.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. job
# 2. guard
# 3. small
# 4. ship
# 5. branch
