# %% [markdown]
# # Day142

# %% [markdown]
# # sub-directory
#
#
#
# **[释义](https://fanyi.baidu.com/#en/zh/sub-directory)**
#
# **例句**：

# %% [markdown]
# # quality
#
# 英\[ˈkwɒləti\] 美\[ˈkwɑːləti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/quality)**
#
# n. 质量，品质; 美质，优点; 才能，能力，技能，素养; 品种
#
# adj. 优质的，高质量的; 上流社会的
#
# **例句**：
#
# If the equipment is not up to the agreed specifications and quality, we will undertake to replace them.
# 如果设备达不到议定的规格质量, 我们将负责调换.
#
# Examination confirmed that the quality of the products was up to specification.
# 经检查,产品质量[品质]合格.

# %% [markdown]
# # door
#
# 英\[dɔː(r)\] 美\[dɔːr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/door)**
#
# n. 门，户; 出入口; 一家[户]; 通道
#
# **例句**：
#
# If you close that door, you can shut the noise in.
# 你要是关上那扇门, 就听不到吵闹声了.
#
# Braving the biting wind, she went out to beg from door to door.
# 她不顾寒风刺骨, 出去挨门乞讨.

# %% [markdown]
# # necessarily
#
# 英\[ˌnesəˈserəli\] 美\[ˌnesəˈserəli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/necessarily)**
#
# adv. 必要地; 必需地; 必定地; 必然地
#
# **例句**：
#
# The unemployment figures are not necessarily related to the rise in prices.
# 失业的数目同物价的上涨并没有必然的联系.
#
# The constitution of a primitive society is not necessarily simple.
# 原始社会的结构未必简单.

# %% [markdown]
# # system
#
# 英\[ˈsɪstəm\] 美\[ˈsɪstəm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/system)**
#
# n. 体系，系统; 制度; 身体; 方法
#
# **例句**：
#
# Since the new management system was put into effect, the production of this factory has increased tremendously.
# 自从实行新的管理制度以来,这个厂的生产有了很大发展.
#
# The railway system was modeled on the successful plan used in other countries.
# 这个铁路网是仿效他国行之有效的方案铺设的.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. sub-directory
# 2. quality
# 3. door
# 4. necessarily
# 5. system
