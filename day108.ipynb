# %% [markdown]
# # Day108

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=109>

# %% [markdown]
# # keep
#
# 英\[kiːp\] 美\[kiːp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/keep)**
#
# vt. 保持; 保留; 遵守; 阻止
#
# vi. （食品）保持新鲜; 保持健康
#
# n. 保持，保养; 供养，抚养; 生活，生计; 饲料；牧草
#
# **例句**：
#
# You don't know the facts, so keep your mouth shut!
# 你不了解情况, 别多嘴!
#
# Keep your nose clean, and don't get involved.
# 你要安分守己, 不要卷到那里头去.

# %% [markdown]
# # end
#
# 英\[end\] 美\[end\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/end)**
#
# n. <正>结果; 端; 终止; 最后部分
#
# vt.& vi. 结束，终止
#
# **例句**：
#
# That face called up in his mind the image of his end wife.
# 那张脸使他想起了他亡妻的形象.
#
# One way and another I'm going to finish this work before the end of the month.
# 无论如何,我打算在本月完成这项工作.

# %% [markdown]
# # icon
#
# 英\[ˈaɪkɒn\] 美\[ˈaɪkɑːn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/icon)**
#
# n. 偶像，崇拜对象; 图标，图符; [宗]圣像; 肖像
#
# **例句**：
#
# Fair trade and social workshop stores can use this Icon.
# 公平贸易和社会研讨会商店可以使用此图标.
#
# You should see the OpenOffice. org icon in the Applications folder.
# 您应该在应用程序文件夹里看到OpenOffice. org图标.

# %% [markdown]
# # ansi
#
# \['ænsi\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/ansi)**
#
# abbr. American National Standards Institute 美国国家标准学会
#
# 美国国家标准化组织
#
# **例句**：
#
# The first six chapters develop the foundations of object - oriented programming with ANSI - C .
# 前六章向大家展现ANSI -C 面向对象 编程的基本内容.
#
# Bonnet Joint ? joint design varies with ANSI class rating.
# 阀盖连接-ANSI压力等级不同,连接结构也有所不同.

# %% [markdown]
# # extend
#
# 英\[ɪkˈstend\] 美\[ɪkˈstend\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/extend)**
#
# vt.& vi. 延伸; 扩大; 推广
#
# vt. 伸展; 给予; 延长; 发出（邀请、欢迎等）
#
# vi. 伸出; 延伸; 增加
#
# **例句**：
#
# We request to extend the time limit for claim on the above shipment to July 5.
# 我们要求将上述货物的索赔时间期限延长到7月5号.
#
# Journal of local university must have its own feature column to enhance grade and extend influence.
# 地方高校学报要想提升档次,扩大影响,就必须有自己的特色栏目.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. keep
# 2. end
# 3. icon
# 4. ansi
# 5. extend
