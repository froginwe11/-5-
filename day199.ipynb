# %% [markdown]
# # Day199

# %% [markdown]
# # week
#
# 英\[wiːk\] 美\[wiːk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/week)**
#
# n. 一星期，周; 工作周（一个星期中的工作时间）
#
# **例句**：
#
# New students will come to our school sometime next week.
# 新学员将于下周某时来校.
#
# The firm signed on fifty more workers last week.
# 上星期该公司签约增雇50名工人.

# %% [markdown]
# # macros
#
# 英\['mækrɒs\] 美\['mækrɒs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/macros)**
#
# n. 麦克罗斯碱性耐火制品; 宏命令
#
# **例句**：
#
# All macros can be set to run when a hot key is pressed.
# 所有宏的运行都可以设定为热键操作。
#
# The computer can be preprogrammed ( hard - wired ) to draw macros.
# 计算机可按预编程序 ( “硬线化” ) 绘出宏指令表示的内容.

# %% [markdown]
# # even
#
# 英\[ˈiːvn\] 美\[ˈiːvn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/even)**
#
# adv. 甚至; 更加; 即使; 恰巧在…时候
#
# adj. 公平的; 平坦的; 偶数的; 平均的
#
# **例句**：
#
# Even a child knows all this.
# 这种事连小孩都知道.
#
# You seem mistrustful even of your friends.
# 看来你连自己的朋友都信不过了.

# %% [markdown]
# # snapshot
#
# 英\[ˈsnæpʃɒt\] 美\[ˈsnæpʃɑːt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/snapshot)**
#
# n. （快照）照片，独立的印象，简单印象; 简介; 急射，速射
#
# **例句**：
#
# An assessment is only a snapshot in time.
# 一份评估只是对不久将来的简短描述.
#
# Send or receiving a new snapshot overwrite the previous image.
# 发送或接收一幅新的快照会覆盖前面的图象.

# %% [markdown]
# # important
#
# 英\[ɪmˈpɔːtnt\] 美\[ɪmˈpɔːrtnt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/important)**
#
# adj. 重要的; 权威的; 有势力的; 有地位的
#
# **例句**：
#
# This is even more important.
# 这一点尤为重要.
#
# Exercise of the mental faculties is as important as bodily excercise.
# 智能的锻炼同身体的运动同样重要.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. week
# 2. macros
# 3. even
# 4. snapshot
# 5. important
