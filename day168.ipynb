# %% [markdown]
# # Day168

# %% [markdown]
# # detect
#
# 英\[dɪˈtekt\] 美\[dɪˈtekt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/detect)**
#
# vt. 查明，发现; 洞察; 侦察，侦查; [电子学]检波
#
# **例句**：
#
# In the paper, Hu's invariants are used to detect the pipe and it achieves high rate.
# 本文把Hu不变矩应用于类圆的检测中,提高了识别的准确性,速度也较快.
#
# This method can detect more Trojan horse's intrusions than general security detection software.
# 该方法可以检测出当前常规安全检测工具不能发现的系统恶意程序的入侵行为.

# %% [markdown]
# # subsequently
#
# 英\[ˈsʌbsɪkwəntli\] 美\[ˈsʌbsɪkwəntli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/subsequently)**
#
# adv. 其后，随后，接着; “subsequent”的派生; 嗣后; 尔后
#
# **例句**：
#
# Subsequently, the Securities and Futures Commission of Jilin Authority to investigate complaints.
# 随后, 证监会吉林监管局对投诉事项展开调查.
#
# Subsequently, other nations'lease accounting standards ( including IAS ) were based on the approach.
# 随后, 各国租赁会计准则 ( 包括国际会计准则 ) 基本沿用了这一理论依据.

# %% [markdown]
# # shell
#
# 英\[ʃel\] 美\[ʃel\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/shell)**
#
# n. （贝、卵、坚果等的）壳; 外壳; 炮弹; （人的）表面性格
#
# vt. 去壳，脱落; 炮击
#
# vi. 剥皮; 炮轰
#
# **例句**：
#
# A tortoise has a shell on his back.
# 乌龟背上有硬壳.
#
# The snail has rotted away in its shell.
# 这只蜗牛已经在壳里腐烂完了.

# %% [markdown]
# # enter
#
# 英\[ˈentə(r)\] 美\[ˈentər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/enter)**
#
# vt.& vi. 进入; 开始; 参加; 登记
#
# **例句**：
#
# You may need to enter this information manually.
# 你可能需要手工输入这条信息.
#
# The agreement shall enter into force upon signature.
# 协定签字后立即生效.

# %% [markdown]
# # american
#
# 英\[əˈmerɪkən\] 美\[əˈmerɪkən\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/american)**
#
# n. 美国人，美洲人; 美国英语
#
# adj. 美国的，美洲的; 地道美国式的
#
# **例句**：
#
# I think your South American youth has prejudiced you.
# 我认为你在南美度过的青少年时代让你产生了偏见。
#
# The American dollar finished the day up against foreign currencies.
# 美元汇率今日收盘时有所上涨。

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. detect
# 2. subsequently
# 3. shell
# 4. enter
# 5. american
