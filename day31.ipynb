# %% [markdown]
# # Day31

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=32>

# %% [markdown]
# # equipment
#
# 英\[ɪˈkwɪpmənt\] 美\[ɪˈkwɪpmənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/equipment)**
#
# n. 设备，装备; 器材，配件; （工作必需的）知识，素养
#
# **例句**：
#
# They loaded themselves with food, medical supplies, and oxygen equipment.
# 他们携带了食物 、 医疗器具和氧气设备.
#
# If the equipment is not up to the agreed specifications and quality, we will undertake to replace them.
# 如果设备达不到议定的规格质量, 我们将负责调换.

# %% [markdown]
# # shut
#
# 英\[ʃʌt\] 美\[ʃʌt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/shut)**
#
# vt.& vi. 关闭; 合上; 打烊; 闭上
#
# adj. 关闭; 停业; 合拢; 关门
#
# **例句**：
#
# You don't know the facts, so keep your mouth shut!
# 你不了解情况, 别多嘴!
#
# If you close that door, you can shut the noise in.
# 你要是关上那扇门, 就听不到吵闹声了.

# %% [markdown]
# # modify
#
# 英\[ˈmɒdɪfaɪ\] 美\[ˈmɑːdɪfaɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/modify)**
#
# vi. 被修饰; 修改
#
# vt. 改变; 减轻，减缓; [语]修饰，（用变音符号）改变
#
# **例句**：
#
# Memory modifications, you can modify the target process in a variables value.
# 内存修改器, 可以修改目标进程中某个变量的值.
#
# You do not have security permission to create or modify the contents of the Inbox folder.
# 您没有安全权限,无法创建或修改收件箱文件夹的内容.

# %% [markdown]
# # area
#
# 英\[ˈeəriə\] 美\[ˈeriə\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/area)**
#
# n. 地区; 区域，范围; 面积，平地; 领域
#
# **例句**：
#
# Houses in the area are built of sandstone.
# 这个地区的房屋都是用砂岩建的.
#
# This area is subject to earthquakes.
# 该地区常发生地震.

# %% [markdown]
# # considered
#
# 英\[kən'sɪdəd\] 美\[kənˈsɪdəd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/considered)**
#
# adj. 经过仔细考虑的; 经过深思熟虑的; 受尊敬的; 经过深思熟虑的看法
#
# v. 考虑( consider的过去式和过去分词); 想; 注意; 看重
#
# **例句**：
#
# The empirical evidence considered here is subject to many qualifications.
# 此处提及的实验证据有诸多限制条件。
#
# The landlord refused to serve him because he considered him too drunk.
# 酒吧老板觉得他已经喝多了，拒绝再给他添酒。

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. equipment
# 2. shut
# 3. modify
# 4. area
# 5. considered
