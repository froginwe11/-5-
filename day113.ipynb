# %% [markdown]
# # Day113

# %% [markdown]
# # organize
#
# 英\[ˈɔːɡənaɪz\] 美\[ˈɔːrɡənaɪz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/organize)**
#
# v. 组织; 安排; 规划; 建立组织
#
# **例句**：
#
# Organize travel arrangement and process expenses claims.
# 有效安排出差行程及处理费用报销.
#
# It'seems they all want to organize their time better.
# 他们似乎都希望能把自己的时间安排得更好.

# %% [markdown]
# # center
#
# 英\[ˈsentə(r)\] 美\[ˈsentər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/center)**
#
# n. 中心; （球队的） 中锋; 中心区; 中枢
#
# adj. 中央的，位于正中的; （在）中心的
#
# vt. 集中; 使聚集在一点; 定中心; 居中
#
# vi. 居中，有中心，被置于中心
#
# **例句**：
#
# The batter skied to the center fielder.
# 击球手打出一个高飞球到中外野手.
#
# The city has developed into a center of industry.
# 这座城市已经发展成为一个工业中心。

# %% [markdown]
# # course
#
# 英\[kɔːs\] 美\[kɔːrs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/course)**
#
# n. 课程; 航线; 行动方向; 一道菜
#
# vt. 快速地流动; 奔流; 跑过; 追逐
#
# vi. 沿…（方向）前进; 指引航线; 快跑; 迅速移动
#
# **例句**：
#
# In the course of time , this kind of lantern has become an exclusive of the Shens.
# 后来, 这种灯笼成了沈家的绝活.
#
# Of course it's absolutely impossible.
# 当然那是万万不可能的.

# %% [markdown]
# # spell
#
# 英\[spel\] 美\[spel\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/spell)**
#
# vt. 拼写; 导致，意味着; 组成（一个词）的字母是…
#
# vi. 轮替
#
# n. 符咒，咒语; 魅力; 一段时间; 轮班
#
# **例句**：
#
# It's not fair to hold me up to ridicule because I can't spell!
# 因为我拼不出来就讥笑我,这是不公平的.
#
# The dry spell is over.
# 旱象已经解除.

# %% [markdown]
# # roll
#
# 英\[rəʊl\] 美\[roʊl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/roll)**
#
# vt. 辗; 使（眼球等）左右转动; （使）原地转圈/打滚; （使）滚动，翻身; （马）仰卧蹬脚；使翻车；掷（骰子）；掷出（骰子数）；（转动）肩膀；行驶；推；摇车窗；（液体）滚落；（时间）流逝；稳定持续的；（产品）从（机器）产出；涌流；延绵起伏；运转；卷，卷起；展开；搓成；辗；发出隆隆声；把（衣服的边）卷起来；压平；覆盖；启动；用颤音发出（辅音，尤其是 r）
#
# vi. 左右摇晃; 翻滚; 开始移动，启动; 左右摇晃；蹒跚；
#
# n. 名册; 卷；柱形物；卷状食品；滚动，翻滚；翻筋斗；左右摇晃；隆隆声；小面包；总人数；名单；公文；延绵起伏；辊轧机；一管；掷骰子
#
# **例句**：
#
# Our dog loves a roll on the grass.
# 我们的狗喜爱在草地上打滚.
#
# Chariots rumble and roll ; horses whinny and neigh.
# 车辚辚, 马萧萧.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. organize
# 2. center
# 3. course
# 4. spell
# 5. roll
