# %% [markdown]
# # Day227

# %% [markdown]
# # decimal
#
# 英\[ˈdesɪml\] 美\[ˈdesɪml\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/decimal)**
#
# adj. 十进位的，小数的
#
# n. 小数
#
# **例句**：
#
# You do understand the Dewey decimal system, don't you ?
# 杜威图书十进制分类法您明白 吧 ?
#
# He knows the decimal rules.
# 他懂得十进制的用法.

# %% [markdown]
# # transfer
#
# 英\[trænsˈfɜː(r) , ˈtrænsfɜː(r)\] 美\[trænsˈfɜːr , ˈtrænsfɜːr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/transfer)**
#
# vt. 使转移; 使调动; 转让（权利等）; 让与
#
# vi. 转让; 转学; 转乘; 转会（尤指职业足球队）
#
# n. 转移; 调动; 换乘; （运动员）转会
#
# **例句**：
#
# At the same time, users of the data transfer, registration, changes will take time.
# 与此同时, 用户资料的交接 、 登记 、 变更需要一段时间.
#
# With your permission, I should like to put in for a transfer.
# 如果您允许, 我想申请转学.

# %% [markdown]
# # filter
#
# 英\[ˈfɪltə(r)\] 美\[ˈfɪltər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/filter)**
#
# n. 滤波器; 滤光器; 滤色镜; [化] 过滤器
#
# vi. 过滤; 透过; 渗透
#
# vt. 过滤; 滤除
#
# **例句**：
#
# Features a water pump , heating element, biomechanical filter, and an air diffuser . Works vertically and horizontally.
# 以水泵 、 发热设备 、 生物力学的过滤器和空气分散器为特色.
#
# Filter element micron ratings are available from. 1 to 300 micron depending on media type.
# 过滤元件微米收视率可从0.1至300微米取决于介质类型.

# %% [markdown]
# # background
#
# 英\[ˈbækɡraʊnd\] 美\[ˈbækɡraʊnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/background)**
#
# n. （画等的）背景; 底色; 背景资料; 配乐
#
# **例句**：
#
# She has a lot of power, but likes to remain in the background.
# 她掌握不少权力, 但喜欢退居幕后.
#
# He had learnt how to melt invisibly into the background.
# 他已经学会如何退居幕后.

# %% [markdown]
# # take
#
# 英\[teɪk\] 美\[teɪk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/take)**
#
# vt. 拿，取; 采取; 接受（礼物等）; 耗费（时间等）
#
# vi. 拿; 获得
#
# n. 镜头; 看法; 收入额; 场景
#
# **例句**：
#
# Take the letter to him [ her ; them ].
# 把信给 人家 送去.
#
# Take this book to her, please.
# 请把这本书捎给她.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. decimal
# 2. transfer
# 3. filter
# 4. background
# 5. take
