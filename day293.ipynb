# %% [markdown]
# # Day293

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=294>

# %% [markdown]
# # programmer
#
# 英\[ˈprəʊɡræmə(r)\] 美\[ˈproʊɡræmər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/programmer)**
#
# n. [计] 程序设计者; 程序设计器; 节目编排者; 订计划者
#
# **例句**：
#
# Thus the customer tests and programmer tests are a critical enabling factor.
# 因此客户测试和程序员测试都是有效的评价因素.
#
# A programmer hacked into the company's computer system and caused a lot of damages.
# 一个程序设计师非法侵入这家公司的电脑系统造成了很大的破坏.

# %% [markdown]
# # whole
#
# 英\[həʊl\] 美\[hoʊl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/whole)**
#
# adj. 全部的，所有的; 完整的
#
# n. 整体，整个; 全部
#
# **例句**：
#
# The whole incident was recorded on film.
# 整个事件都记录在胶片上了.
#
# We managed to record the whole of the concert from a live studio broadcast.
# 我们设法把现场直播音乐会的全部节目录了下来.

# %% [markdown]
# # twice
#
# 英\[twaɪs\] 美\[twaɪs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/twice)**
#
# adv. 两次; 两倍; 两遍
#
# **例句**：
#
# He was pinned against the fence by a boy twice his size; he could hardly breathe.
# 他被一个身材两倍于他的男孩按在篱笆上, 喘不过气来.
#
# The fields have been ploughed twice.
# 地已犁了两遍.

# %% [markdown]
# # parenthesis
#
# 英\[pəˈrenθəsɪs\] 美\[pəˈrɛnθɪsɪs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/parenthesis)**
#
# n. 插入语; 插入成分; 圆括号; 间歇
#
# **例句**：
#
# Items encapsulated in parenthesis are evaluated first and have the highest precedence.
# 先给包含在括号中的项目赋值,它拥有最高的优先权.
#
# Besides , conditional adverbial clauses ( phrases ) , parenthesis , and the different usages of voice own their respective styles.
# 条件状语或从句 、 插入语和不同语态的使用也有其自身风格.

# %% [markdown]
# # comment
#
# 英\[ˈkɒment\] 美\[ˈkɑːment\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/comment)**
#
# n. 评论; 解释; 批评; 指责
#
# v. 表达意见; 作出评论
#
# **例句**：
#
# As the author of the scheme I can't really comment.
# 我作为这一计划的创始人是不便置评的.
#
# It created wide comment in the press.
# 它引起了新闻界的广泛评论.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. programmer
# 2. whole
# 3. twice
# 4. parenthesis
# 5. comment
