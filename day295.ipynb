# %% [markdown]
# # Day295

# %% [markdown]
# # duplicate
#
# 英\[ˈdjuːplɪkeɪt , ˈdjuːplɪkət\] 美\[ˈduːplɪkeɪt , ˈduːplɪkət\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/duplicate)**
#
# v. 复制; 复印; 重复
#
# adj. 完全一样的；复制的；副本的
#
# n. 完全一样的东西；复制品；副本
#
# **例句**：
#
# An example of such an error is attempting to insert duplicate value in a primary key.
# 这种错误的一个实例:尝试在主键内插入同样的值.
#
# Her name is a duplicate of mine.
# 她与我重名.

# %% [markdown]
# # onto
#
# 英\[ˈɒntə\] 美\[ˈɑːntə\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/onto)**
#
# prep. 到…之上; 对…了解; [数]映射到…上; 向，朝；朝向，面向（某个方向）
#
# **例句**：
#
# Drop the dough onto a baking sheet with a teaspoon.
# 用茶匙把生面团舀到烤盘上。
#
# So, if we could just move onto something else?
# 那么我们可不可以干脆谈点别的？

# %% [markdown]
# # share
#
# 英\[ʃeə(r)\] 美\[ʃer\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/share)**
#
# n. 股; （参与、得到等的）份; （分享到的或贡献出的）一份; 市场占有率
#
# vt.& vi. 共有; 共用; 均摊
#
# vt. 分配; 分开; 共同承担
#
# vi. 分享，分担(in)
#
# **例句**：
#
# It always took a final reminder to get her to pay her share of the rent.
# 总是得发给她一份最后催缴通知,她才付应该交的房租.
#
# Sponging and taking more than one's share and extravagance and waste on the part of cadres must be banned.
# 杜绝干部多吃多占和铺张浪费.

# %% [markdown]
# # reading
#
# 英\[ˈriːdɪŋ\] 美\[ˈriːdɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/reading)**
#
# n. 阅读; 宣读; 读物; 读数
#
# v. 读( read的现在分词); 看懂; 理解; 显示，标明
#
# **例句**：
#
# Good reading elevates the mind.
# 阅读好书可使思想高尚.
#
# Much reading has impaired his vision.
# 大量读书损害了他的视力.

# %% [markdown]
# # otherwise
#
# 英\[ˈʌðəwaɪz\] 美\[ˈʌðərwaɪz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/otherwise)**
#
# adv. 否则; 另外; 别的方式
#
# adj. . 另外的; 其他方面的; 原本，本来
#
# conj. . 其他; 如果不; 然后
#
# **例句**：
#
# I suspect ( that ) you once thought otherwise.
# 我觉得你一度有过不同的想法.
#
# If he had done otherwise, I should have thought him a rascal.
# 如果他不这样做, 我就认为他是个恶棍.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. duplicate
# 2. onto
# 3. share
# 4. reading
# 5. otherwise
