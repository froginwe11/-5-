# %% [markdown]
# # Day77

# %% [markdown]
# # overwrite
#
# 英\[ˌəʊvəˈraɪt\] 美\[ˌoʊvərˈraɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/overwrite)**
#
# v. 写在…上面，写得过多
#
# **例句**：
#
# You can overwrite the defaults set in the database role.
# 您可以替代数据库角色中设置的默认值.
#
# Send or receiving a new snapshot overwrite the previous image.
# 发送或接收一幅新的快照会覆盖前面的图象.

# %% [markdown]
# # huge
#
# 英\[hjuːdʒ\] 美\[hjuːdʒ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/huge)**
#
# adj. 巨大的; 庞大的; 极大的
#
# **例句**：
#
# Four days after setting out , while the Titantic was sailing across the icy waters of the North Atlantic, a huge iceberg was suddenly spotted by a lookout.
# 启航四天后, 泰坦尼克号在穿过北大西洋多冰的海域时, 了望员突然发现了一个巨大的冰山.
#
# His acting raised a huge laugh.
# 他的表演引起一阵大笑.

# %% [markdown]
# # unlock
#
# 英\[ˌʌnˈlɒk\] 美\[ˌʌnˈlɑk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unlock)**
#
# vt. 开锁; 开启; 揭开; 表露
#
# vi. 解开; 被释放
#
# **例句**：
#
# Phones menu will popup with unlock code request.
# 电话菜单弹出解码请求.
#
# The decoration meant, " You unlock my heart! "
# 它代表着, “ 开启我的心! ”

# %% [markdown]
# # template
#
# 英\[ˈtempleɪt\] 美\[ˈtɛmplɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/template)**
#
# n. 样板; 模板; 型板
#
# **例句**：
#
# In the Add New Item dialog box, select Preprocessed Text Template.
# 在“添加新项”对话框中, 选择“预处理文本模板”.
#
# Click the plus sign to expand the list of templates, select a template, and click New.
# 单击加号展开模板列表, 选择一个模板, 然后单击“新建”.

# %% [markdown]
# # restricting
#
# 英\[rɪs'trɪktɪŋ\] 美\[rɪs'trɪktɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/restricting)**
#
# v. （以法规）限制( restrict的现在分词 ); 约束; 束缚
#
# **例句**：
#
# This was seen as a way of restricting women'sarticulation of grievances.
# 这被认为是一种限制妇女发牢骚的方式。
#
# She argued for import control , ie the restricting of imports.
# 她主张实行进口限制.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. overwrite
# 2. huge
# 3. unlock
# 4. template
# 5. restricting
