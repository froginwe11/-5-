# %% [markdown]
# # Day223

# %% [markdown]
# # log
#
# 英\[lɒɡ\] 美\[lɔːɡ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/log)**
#
# n. 记录; 日志; 原木
#
# v. 伐木; 把…载入正式记录; 行驶
#
# **例句**：
#
# If you already have an account. please log and try to access the account page again.
# 如果你已经拥有一个帐户. 请连接服务器.重新访问帐户页面.
#
# I reached for a floating log with my foot.
# 我用脚去钩取一段漂浮着的木头.

# %% [markdown]
# # capability
#
# 英\[ˌkeɪpəˈbɪləti\] 美\[ˌkeɪpəˈbɪləti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/capability)**
#
# n. 才能，能力; 容量; 性能; 生产率
#
# **例句**：
#
# Have strong organizational capability and activity planing ability, active and making contributions during the college time.
# 有较强的组织能力、活动策划能力, 大学期间经常为班级活动出谋划策.
#
# Processing capability as found in an intelligent terminal.
# 在智能终端上实现的处理能力.

# %% [markdown]
# # throughout
#
# 英\[θruːˈaʊt\] 美\[θruːˈaʊt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/throughout)**
#
# prep. （表示时间）自始至终; 在…期间; 遍及…地域; 遍及…场所
#
# **例句**：
#
# On the tops of very high mountains snow persists throughout the year.
# 高山顶上,积雪终年不化.
#
# Our product enjoys popularity throughout the world.
# 我们的产品饮誉全球.

# %% [markdown]
# # echo
#
# 英\[ˈekəʊ\] 美\[ˈekoʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/echo)**
#
# n. 回声，共鸣; （言语、作风、思想等的）重复; 重复者; [无线电]回波
#
# vt. 重复，效仿; 随声附和; 类似; 发射（声音等）
#
# vi. 被重复; 产生回响; 充满回声
#
# **例句**：
#
# A new echo signal simulation method based data matrix of point object is put forward.
# 回波信号模拟是合成孔径雷达模拟技术的基础.
#
# She shouted on the mountaintop and listened for the echo.
# 她在山顶上大声喊着,然后聆听着回声.

# %% [markdown]
# # hello
#
# 英\[həˈləʊ\] 美\[həˈloʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hello)**
#
# int. 哈喽，喂; 你好，您好; 表示问候; 打招呼
#
# n. “喂”的招呼声或问候声
#
# **例句**：
#
# Hello! This is little Li speaking.
# 喂, 我是小李.
#
# Hello, Brooks! How are you?
# 喂, 布鲁克斯! 你好 吗 ?

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. log
# 2. capability
# 3. throughout
# 4. echo
# 5. hello
