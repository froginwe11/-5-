# %% [markdown]
# # Day158

# %% [markdown]
# # until
#
# 英\[ənˈtɪl\] 美\[ənˈtɪl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/until)**
#
# prep. 到…为止; 在…以前
#
# conj. 到…为止，在…以前; 直到…才
#
# **例句**：
#
# I withheld payment until they had fulfilled the contract.
# 他们履行合同后,我才付款.
#
# He did not agree until I had talked to him for a long time.
# 我劝说了半天,他才肯了.

# %% [markdown]
# # semicolon
#
# 英\[ˌsemiˈkəʊlən\] 美\[ˈsemikoʊlən\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/semicolon)**
#
# n. 分号
#
# **例句**：
#
# The following characters are reserved and cannot be used for this property: semicolon, comma.
# 以下字符是保留的并且不能用于此属性:分 号 、 逗号.
#
# Specify the source file column delimiter type. Specify comma, tab, semicolon, or another character.
# 指定源文件列分隔符类型. 指定逗号 、 制表符 、 分号或其它字符.

# %% [markdown]
# # setup
#
# 英\['setʌp\] 美\[ˈsɛtˌʌp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/setup)**
#
# n. 计划; <口>组织; 姿势; <口>故意安排使一方易胜的比赛
#
# **例句**：
#
# I gradually got rather disillusioned with the whole setup of the university.
# 渐渐地，我对大学的整个体制感到相当失望。
#
# These food markets have more or less the same setup.
# 几个菜市场的格局差不多.

# %% [markdown]
# # highest
#
# 英\[haɪɪst\] 美\[haɪɪst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/highest)**
#
# adj. 最高的; 高的( high的最高级 ); 高尚的; 高地的; 高级的
#
# **例句**：
#
# At the highest executive levels earnings and performance aren't always correlated.
# 在最高管理层，收入与工作表现并不总是相关的。
#
# The highest Order of Knighthood is the Order of the Garter.
# 最高骑士勋位是嘉德勋位。

# %% [markdown]
# # mach
#
# 英 美
#
# **[释义](https://fanyi.baidu.com/#en/zh/mach)**
#
# abbr. machine 机器; machinery 机器; machinist 机械师; machined 机械加工的
#
# **例句**：
#
# The hot air permitted higher speeds before the critical Mach number was exceeded.
# 热空气可使之在超过临界马赫数之前达到更快的速度。
#
# The aim is to fly at about Mach 2, twice the speed of sound.
# 目标是以大约2马赫的速度飞行，也就是音速的两倍。

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. until
# 2. semicolon
# 3. setup
# 4. highest
# 5. mach
