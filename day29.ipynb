# %% [markdown]
# # Day29

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=30>

# %% [markdown]
# # procedural
#
# 英\[prə'si:dʒərəl\] 美\[prəˈsidʒərəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/procedural)**
#
# adj. 程序的; 有关程序的
#
# **例句**：
#
# The Paris talks will mainly be about procedural matters.
# 巴黎会谈将主要围绕程序上的事宜。
#
# No doubt someone had pulled a fast one on her over a procedural matter.
# 无疑有人在程序性问题上骗了她。

# %% [markdown]
# # higher
#
# 英\[ˈhaɪə(r)\] 美\[ˈhaɪər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/higher)**
#
# adj. 高高的; 高级的; 上级的; 高等的; 高的( high的比较级 ); 高尚的; 高地的; 高级的
#
# **例句**：
#
# He is disposed to accept the new job, for the pay is higher.
# 他倾向于接受这个新的工作, 因为工资高一些.
#
# We have to offer higher rates.
# 我们不得不付更高的价钱.

# %% [markdown]
# # encounter
#
# 英\[ɪnˈkaʊntə(r)\] 美\[ɪnˈkaʊntər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/encounter)**
#
# vt. 不期而遇; 遭遇; 对抗
#
# n. 相遇，碰见; 遭遇战; 对决，冲突
#
# vi. 碰见，尤指不期而遇
#
# **例句**：
#
# There was heavy bloodshed in their first encounter at sea.
# 第一次海上冲突,他们双方都伤亡惨重.
#
# It was a bloody encounter between the two armies.
# 这是那两军之间的一次激烈的遭遇战.

# %% [markdown]
# # document
#
# 英\[ˈdɒkjumənt , ˈdɒkjument\] 美\[ˈdɑːkjumənt , ˈdɑːkjument\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/document)**
#
# n. （计算机）文档，证件; 公文
#
# vt. 证明; 记录; 为…提供证明
#
# **例句**：
#
# He asked me to make ten copies of the document.
# 他叫我把这份文件复印十份.
#
# The document is being circulated among the committee members.
# 文件正在委员中传阅.

# %% [markdown]
# # convention
#
# 英\[kənˈvenʃn\] 美\[kənˈvenʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/convention)**
#
# n. 会议; 全体与会者; 国际公约; 惯例，习俗，规矩
#
# **例句**：
#
# He was delegated to the convention.
# 他被委派为代表参加会议.
#
# Japan has signed a convention of peace with a neighbouring country.
# 日本已与邻国签署一项和平协定.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. procedural
# 2. higher
# 3. encounter
# 4. document
# 5. convention
