# %% [markdown]
# # Day267

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=268>

# %% [markdown]
# # subgroup
#
# 英\[ˈsʌbɡruːp\] 美\[ˈsʌbɡruːp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/subgroup)**
#
# n. 小群，隶属的小组织，子群
#
# **例句**：
#
# There are difference in conditions which subgroup cooperate and swarm cooperate depending on.
# 小群体合作与大群体合作所依存的条件是有差异的.
#
# A subgroup of patients underwent ambulatory BP monitoring.
# 另一个亚组采用动态血压监测.

# %% [markdown]
# # under
#
# 英\[ˈʌndə(r)\] 美\[ˈʌndər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/under)**
#
# prep. 在…下面，在表面之下; 在…的假定表面或掩饰下; 少于，小于; 在…情况下
#
# adv. 在下面; 少于; 在水下; 在昏迷中
#
# adj. 较低的，下面的
#
# **例句**：
#
# Many questions are under discussion.
# 许多问题正在讨论.
#
# The powerful lords were guilty of grinding the villagers under their heels.
# 那些大领主的罪过是以权势欺压村民.

# %% [markdown]
# # jump
#
# 英\[dʒʌmp\] 美\[dʒʌmp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/jump)**
#
# vt. 跳; 跳过; 快速移动; （因吃惊、害怕或激动而）猛地一动
#
# vi. 暴涨; 跳跃; 猛增
#
# n. 猛长，暴涨; （需要跳越的）障碍; 跳伞
#
# **例句**：
#
# Meteorologist believe this pressure jump is the mechanism responsible for storm and tornado.
# 气象学家认为这一气压的突然升高是暴风雨和飓风形成的物理机制.
#
# They defied him to jump off the bridge.
# 他们激他跳下桥去.

# %% [markdown]
# # manifest
#
# 英\[ˈmænɪfest\] 美\[ˈmænɪfest\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/manifest)**
#
# vt. 显示，表明; 证明; 使显现
#
# adj. 明白的，明显的
#
# n. 货单，旅客名单
#
# **例句**：
#
# Does your factory check arriving cargo against advance information on the cargo manifest?
# 做你的工厂检查到达货物反对进步关于货物的资讯载货单?
#
# In our semantic analysis, EBC is shown to manifest a perfect match between syntax and semantics.
# 删除的过程受黄(1991b)中提到“方向性制约”的约束,在我们的语义分析中, 可以看出,“显性比字句”表现出句法和语义完美搭配.

# %% [markdown]
# # transportable
#
# 英\[trænˈspɔ:təbl\] 美\[trænˈspɔrtəbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/transportable)**
#
# adj. 可运输的
#
# **例句**：
#
# Here we distinguish azimuthal and equatorial mountings as well as fixed and transportable instruments.
# 比如说有地平式和赤道式装置,有固定式和移动式的等等.
#
# They are ultra - light and easily transportable, even in a van.
# 超轻设计,易于运输, 甚至可以用于小型面包车装运.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. subgroup
# 2. under
# 3. jump
# 4. manifest
# 5. transportable
