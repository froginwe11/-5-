# %% [markdown]
# # Day43

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=44>

# %% [markdown]
# # complete
#
# 英\[kəmˈpliːt\] 美\[kəmˈpliːt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/complete)**
#
# adj. （用以强调）完全的; 完成的; 达到结尾的; 完整的
#
# vt. 完成，使完满; 完成或结束; 填写（表格）
#
# **例句**：
#
# The word has passed into complete disuse.
# 这个词已经完全不用了.
#
# The work is already complete inmanuscript.
# 著作已经脱稿.

# %% [markdown]
# # number
#
# 英\[ˈnʌmbə(r)\] 美\[ˈnʌmbər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/number)**
#
# n. 数字; 数量; 号码; 编号
#
# v. 标号; 总计; 把…算作
#
# **例句**：
#
# The king was attended upon [ on ] by a number of servants.
# 国王有好多奴仆侍候.
#
# He consulted a number of relevant books and periodicals.
# 他参看了不少有关书刊.

# %% [markdown]
# # agree
#
# 英\[əˈɡriː\] 美\[əˈɡriː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/agree)**
#
# vt.& vi. 同意，赞同
#
# vi. [语]一致，符合; 商定，约定; 意见相合; （气候、食物等）适宜
#
# vt. 同意，承认; 使和谐一致; 认为正确无误
#
# **例句**：
#
# We all agree in adopting the new teaching method.
# 我们一致同意采取新的教学方法.
#
# He did not agree until I had talked to him for a long time.
# 我劝说了半天,他才肯了.

# %% [markdown]
# # run
#
# 英\[rʌn\] 美\[rʌn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/run)**
#
# vt.& vi. 跑; 移动; （使）流动
#
# n. 奔跑; 行程; 放映期; 一系列; 趋向，态势
#
# vi. （工作等）进行; 延续; 逃跑; 行驶
#
# vt. 使奔跑; 使…快速移动; 运行，经营; 划
#
# **例句**：
#
# I will run you in if the bus isn't going into the town because of the snow today.
# 如果今天公共汽车因为下雪不送你进城的话,我会开车送你去的.
#
# Smith has run away from home, but his family are putting a good face on it.
# 史密斯已经离家出走, 但他的家人却装作若无其事.

# %% [markdown]
# # progress
#
# 英\[ˈprəʊɡres , prəˈɡres\] 美\[ˈprɑːɡres , prəˈɡres\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/progress)**
#
# n. 进步; 前进; [生物学]进化; （向更高方向）增长
#
# v. （使）进步，（使）进行; 发展; 促进
#
# vi. 发展; （向更高方向）增进
#
# **例句**：
#
# The old ideas are a drag on progress.
# 旧观念是进步的障碍.
#
# It is always futile to try to hold back the progress of history.
# 要想阻止历史潮流是徒劳的.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. complete
# 2. number
# 3. agree
# 4. run
# 5. progress
