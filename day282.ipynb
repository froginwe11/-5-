# %% [markdown]
# # Day282

# %% [markdown]
# # assistance
#
# 英\[əˈsɪstəns\] 美\[əˈsɪstəns\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/assistance)**
#
# n. 帮助，援助; 〈古〉出席，出席者; 辅助设备
#
# **例句**：
#
# We are going to render them economic assistance.
# 我们打算向他们提供经济援助.
#
# He will get the great possible assistance.
# 他将获得尽可能大的帮助.

# %% [markdown]
# # confidential
#
# 英\[ˌkɒnfɪˈdenʃl\] 美\[ˌkɑːnfɪˈdenʃl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/confidential)**
#
# adj. 秘密的; 机密的; 表示信任的; 亲密的
#
# **例句**：
#
# Bt DTU, Jamey convinces Jack to shut Nina off from confidential access.
# 在反恐组, 杰米说服了杰克,不让尼娜问鼎秘要的文件.
#
# The secret behind your unpaid fund. [ Strictly confidential ].
# 这个秘密在你无偿基金. [ 严格保密的 ].

# %% [markdown]
# # traditional
#
# 英\[trəˈdɪʃənl\] 美\[trəˈdɪʃənl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/traditional)**
#
# adj. 传统的; 口传的; 惯例的; 因袭的
#
# **例句**：
#
# With her precise use of language and intimidating aspect, she was a typical traditional schoolmistress.
# 她说话咬文嚼字,样子咄咄逼人, 真是一个典型的传统式的女教师.
#
# I can see that they are not ready to depart from traditional practice.
# 我想他们不是真的背离传统习惯.

# %% [markdown]
# # initial
#
# 英\[ɪˈnɪʃl\] 美\[ɪˈnɪʃl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/initial)**
#
# adj. 最初的; 开始的; 首字母的
#
# n. 首字母; [语音学]声母; 特大的大写字母
#
# vt. 用姓名的首字母签名
#
# **例句**：
#
# Hesitation posisons your bravery, will and initial velocity.
# 踌躇将拖慢勇气 、 意志、初速.
#
# Being due to initial data errors, the result accuracy from the popular adjustment will decrease.
# 因起算数据误差的存在, 导致了用普通的平差方法求得的结果精度降低.

# %% [markdown]
# # understand
#
# 英\[ˌʌndəˈstænd\] 美\[ˌʌndərˈstænd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/understand)**
#
# vt.& vi. 懂，理解
#
# vt. 了解; 默认; 听说; 领会
#
# **例句**：
#
# Most of the students understand English well.
# 这些学生中大多数通晓英语.
#
# Then he spoke slowly, but I could not understand him.
# 后来,他说话说得慢了, 但是我还是听不懂他的话.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. assistance
# 2. confidential
# 3. traditional
# 4. initial
# 5. understand
