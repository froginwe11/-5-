# %% [markdown]
# # Day111

# %% [markdown]
# # vary
#
# 英\[ˈveəri\] 美\[ˈveri\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/vary)**
#
# vi. 变化; 不同，偏离; [生]变异
#
# vt. 使不同; 使多样化; [音乐]变奏
#
# **例句**：
#
# The doses used for surgical anaesthesia vary between 2 and 10 mg / kg.
# 外科手术麻醉药的用量从每公斤2毫克到10毫克不等.
#
# Old people don't like to vary their habits.
# 老年人不喜欢改变他们的习惯.

# %% [markdown]
# # idea
#
# 英\[aɪˈdɪə\] 美\[ aɪˈdiːə\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/idea)**
#
# n. 主意，想法; [哲]理念，观念; [乐]乐句; 模糊想法
#
# **例句**：
#
# This idea never occurred to me.
# 我万万没有想到.
#
# Then an idea suggested itself to her.
# 这时她脑中浮现出一个想法.

# %% [markdown]
# # transform
#
# 英\[trænsˈfɔːm\] 美\[trænsˈfɔːrm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/transform)**
#
# vt. 改变; 改观; 变换
#
# vi. 改变
#
# **例句**：
#
# But what exactly is this new development and how will it transform our lives?
# 但这一新发明到底是什么,它将如何改变我们的生活?
#
# We transform, as if by magic, from wives and mothers into horrid society murdering beasts.
# 我们变了, 像变戏法似的, 从妻子、母亲的角色变成了恐怖的为害社会的畜牲.

# %% [markdown]
# # cursor
#
# 英\[ˈkɜ:sə(r)\] 美\[ˈkɜrsə(r)\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/cursor)**
#
# n. 光标
#
# **例句**：
#
# To pause the slideshow, place your mouse cursor over the picture.
# 暂停幻灯片, 把你的鼠标光标放在图画上.
#
# What is used for moving the cursor around the screen?
# 用什么来移动屏幕上的光标?

# %% [markdown]
# # able
#
# 英\[ˈeɪbl\] 美\[ˈeɪbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/able)**
#
# adj. 能够的; 有能力的; 有才干的; 干练的
#
# **例句**：
#
# We won't be able to tell what skills the man has until we try him out.
# 要等试用一个时期以后,我们才能知道这人有什么专长.
#
# They are able to master the situation.
# 他们能够控制局势.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. vary
# 2. idea
# 3. transform
# 4. cursor
# 5. able
