# %% [markdown]
# # Day252

# %% [markdown]
# # password
#
# 英\[ˈpɑːswɜːd\] 美\[ˈpæswɜːrd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/password)**
#
# n. （进入房间、建筑或某个地区的）口令; <计>（使用计算机操作系统的）密码
#
# **例句**：
#
# Password protected remote maintenance of your index including.
# 密码保护远程维护你的指数,其中包括.
#
# Listening LAN password, docking received packet further analysis, the layer protocol analysis, access to the password.
# 侦听局域网内的密码, 对接收到的封包进一步分析, 解析出应用层协议, 获得密码.

# %% [markdown]
# # far
#
# 英\[fɑː(r)\] 美\[fɑːr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/far)**
#
# adv. 久远地; （问到或谈及距离时说）有多远; 到很远距离; 到很大程度，非常
#
# adj. 远的; 遥远的; （某方向的）最远的; 远端的
#
# **例句**：
#
# We still fall far short of what the Party expects of us.
# 我们离党的要求还差得远.
#
# This arrangement is quite satisfactory, so far as I am concerned.
# 就我来说, 这样的安排很好.

# %% [markdown]
# # squeeze
#
# 英\[skwiːz\] 美\[skwiːz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/squeeze)**
#
# vt.& vi. 挤，榨，捏; 压迫，压榨
#
# vt. 榨取，汲取; 轻轻地捏; 向…勒索（或榨取）
#
# vi. 在强压下屈服; 施加压力; 挤过去
#
# n. 挤压，压榨; 抱紧，拥挤; 拥挤的人群; <口>压力
#
# **例句**：
#
# But he had never imagined she was so poor and he couldn't squeeze anything out of her.
# 可是他没有料到她竟会那么穷,榨不出一点油水.
#
# Give the tube of toothpaste a squeeze.
# 把牙膏挤一挤.

# %% [markdown]
# # board
#
# 英\[bɔːd\] 美\[bɔːrd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/board)**
#
# n. 板; 董事会; 甲板; 膳食
#
# vt. 上（船、车或飞机）; 收费供…膳宿; 使搭伙，使寄宿; 强行登（船）
#
# vi. （火车、轮船、飞机等）接受乘客; 搭伙，寄宿
#
# **例句**：
#
# The board has so misconducted the company that it's deep in debt.
# 由于董事会对公司管理不善,公司负债累累.
#
# Please show your ticket to the stewardess when you board the plane.
# 登机时请向空中小姐出示机票.

# %% [markdown]
# # character
#
# 英\[ˈkærəktə(r)\] 美\[ˈkærəktər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/character)**
#
# n. 性格; 特点; 字母; 角色，人物
#
# **例句**：
#
# He's an odd character and no mistake!
# 他的确是个怪人!
#
# He is a queer character.
# 他是个可疑的人.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. password
# 2. far
# 3. squeeze
# 4. board
# 5. character
