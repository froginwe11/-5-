# %% [markdown]
# # Day131

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=132>

# %% [markdown]
# # original
#
# 英\[əˈrɪdʒənl\] 美\[əˈrɪdʒənl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/original)**
#
# adj. 原始的; 独创的; 最初的; 新颖的
#
# n. 原文; 原型; 原件; 怪人
#
# **例句**：
#
# The new version of the program comes with a much better user interface than original.
# 新版程序的用户界面比原来程序的好得多.
#
# The translation does not quite correspond to the original.
# 译文不切原意.

# %% [markdown]
# # cancel
#
# 英\[ˈkænsl\] 美\[ˈkænsl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/cancel)**
#
# vt. 取消，注销; 抵消，偿还; 〈数〉约去
#
# vi. 抵消，中和
#
# **例句**：
#
# It is vitally important to cancel the order immediately.
# 马上取消这批订货是至关重要的.
#
# Would you like to postpone or cancel your call?
# 您随后打电话,还是不打了?

# %% [markdown]
# # among
#
# 英\[əˈmʌŋ\] 美\[əˈmʌŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/among)**
#
# prep. （表示牵涉）经过; （表示位置）处在…中; （表示范围）在…之内; （表示所属）为…所特有
#
# **例句**：
#
# These difficulties are general among people of his age.
# 这些困难在他那个年龄的人中普遍存在.
#
# Shakespeare is a giant among writers.
# 莎士比亚是作家中的巨擘.

# %% [markdown]
# # last
#
# 英\[lɑːst\] 美\[læst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/last)**
#
# n. 末尾; 最后; 上个; 鞋楦（做鞋的模型）
#
# vt. 经受住; 到…之后; 够用; 足够维持（尤指某段时间）
#
# vi. 持续
#
# adv. 上一次，最近一次; 最后
#
# det. 最后的；最末的；末尾的,最近的；上一个的,仅剩下的；最终的,（强调）最不可能的，最不适当的
#
# **例句**：
#
# His performance at the concert last night proved that he is in the top flight of international pianists.
# 昨晚他在音乐会上的演奏证明他在国际钢琴家中居首位.
#
# May the friendship between the peoples of ( our ) two countries last forever.
# 祝两国人民的友谊万古长青.

# %% [markdown]
# # modification
#
# 英\[ˌmɒdɪfɪˈkeɪʃn\] 美\[ˌmɑːdɪfɪˈkeɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/modification)**
#
# n. 修改，修正，变更，改良，改进，缓和，减轻，限制; [语]修饰，（用变音符号的）母音改变; [生]诱发变异，变态，变体，变型
#
# **例句**：
#
# This also reduces chances for errors in modification, if the code needs to be changed.
# 如果代码需要更改,可以减少修改中出错的几率.
#
# The surface modification of ultrafine calcium carbonate was made by using aluminium zirconium coupling agent.
# 用铝锆酸酯偶联剂对超微碳酸钙粉体进行表面改性.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. original
# 2. cancel
# 3. among
# 4. last
# 5. modification
