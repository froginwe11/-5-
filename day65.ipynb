# %% [markdown]
# # Day65

# %% [markdown]
# # assembler
#
# 英\[əˈsemblə(r)\] 美\[əˈsɛmblɚ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/assembler)**
#
# n. 装配工; 汇编程序; 低级编码; 汇编语言
#
# **例句**：
#
# The design of traffic lights with assembler language feel pretty good!
# 交通灯的设计用汇编语言自己觉得挺不错的!
#
# The filesize is very large for a virus written in pure Assembler language.
# 对完全采用汇编编写的病毒来说,这个长度是有些臃肿了.

# %% [markdown]
# # turn
#
# 英\[tɜːn\] 美\[tɜːrn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/turn)**
#
# v. 使转动; 旋转; 转身; 翻转
#
# n. 转动; 转向; 转弯处; 转变; （依次轮到的）机会
#
# **例句**：
#
# If you turn the envelope upside down, the key will fall out.
# 你如果把信封倒过来, 钥匙就会掉出.
#
# If a writer does not go deep among the masses, he cannot expect to turn out good works.
# 当作家而不深入群众, 就不会写出好作品来.

# %% [markdown]
# # stuff
#
# 英\[stʌf\] 美\[stʌf\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/stuff)**
#
# n. 材料，原料，资料; 〈俚〉钱，现金; 填充物; 素材资料
#
# vt. 塞满; 填塞; 让吃饱
#
# vi. 吃得过多
#
# **例句**：
#
# This is the stuff most stadard TV sitcoms are made of.
# 这是大多数标注的电视幽默剧所采用的题材.
#
# I'll sit on the stuff for a few days.
# 我将看守几天东西.

# %% [markdown]
# # difficulty
#
# 英\[ˈdɪfɪkəlti\] 美\[ˈdɪfɪkəlti\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/difficulty)**
#
# n. 困难，麻烦，难事; 难度; 异议，争论，纠葛; 财政困难，（经济）拮据
#
# **例句**：
#
# Do you apprehend any difficulty?
# 你担心会有困难 吗 ?
#
# They always helped us on in times of difficulty.
# 在我们遇到困难时,他们总是鼓励我们.

# %% [markdown]
# # contain
#
# 英\[kənˈteɪn\] 美\[kənˈteɪn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/contain)**
#
# vt. 包含，容纳; 克制，遏制; 牵制; 包括或由…构成
#
# **例句**：
#
# It'says on the packet that these crisps contain no additives.
# 包装上说这些炸薯片不含添加剂.
#
# Our observations may contain a grain of truth for you to refer to.
# 我们的意见也许会有千虑一得之处,供你参考.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. assembler
# 2. turn
# 3. stuff
# 4. difficulty
# 5. contain
