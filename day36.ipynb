# %% [markdown]
# # Day36

# %% [markdown]
# # average
#
# 英\[ˈævərɪdʒ\] 美\[ˈævərɪdʒ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/average)**
#
# adj. 平常的; 平均的; 典型的; （价值、比率等的）平均数的
#
# n. 平均水平; （速度等的）平均率; 平均估价
#
# vt. [数学] 计算…的平均值; 调和，拉平; 分摊; 按比例（或平均）分配（利润等）
#
# vi. 平均：作为或达到一个中间值; 维持（有利的）平均价格
#
# **例句**：
#
# To put It'simply, the new proposals mean that the average worker will be about 10 % better paid.
# 简单地说, 新建议意味着一个普通工人的工资将增加10%.
#
# There was nothing special about the meal ; it was average.
# 饭菜没什么特别, 挺平常的.

# %% [markdown]
# # manipulating
#
# 英\[mə'nɪpjə,let\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/manipulating)**
#
# v. 熟练控制[操作]( manipulate的现在分词 ); （暗中）控制，操纵，影响; 正骨; 治疗脱臼
#
# **例句**：
#
# He was a past-master at manipulating the media for his own ends.
# 他是操纵媒体为自己服务的老手。
#
# Using binary notation is in fact just manipulating ones and noughts.
# 使用二进制标号法实际上只运用1和0两个数.

# %% [markdown]
# # aware
#
# 英\[əˈweə(r)\] 美\[əˈwer\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/aware)**
#
# adj. 意识到的; 知道的; 觉察到的
#
# **例句**：
#
# They were acutely aware of the difficulties.
# 他们强烈地感到种种困难.
#
# He was aware of sharp disappointment and betrayal.
# 他意识到绝望和被出卖.

# %% [markdown]
# # support
#
# 英\[səˈpɔːt\] 美\[səˈpɔːrt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/support)**
#
# vt. 支持; 帮助; 支撑; 维持
#
# n. 支撑; 支持者; [数学]支集; 支撑物
#
# **例句**：
#
# Her encouragement and support strengthened our resolve.
# 她的鼓励和支持加强了我们的决心.
#
# They support each other in their work.
# 他们在工作中互相支持.

# %% [markdown]
# # counter
#
# 英\[ˈkaʊntə(r)\] 美\[ˈkaʊntər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/counter)**
#
# n. 柜台; 对立面; 计数器; （某些棋盘游戏的）筹码
#
# vt. 反击，还击; 反向移动，对着干; 反驳，回答
#
# vi. 逆向移动，对着干; 反驳
#
# adv. 反方向地; 背道而驰地
#
# **例句**：
#
# Jewelry is displayed on a sales counter.
# 珠宝陈列在柜台里.
#
# A large crowd of customers swarmed before the counter.
# 柜台前挤满了一大群顾客.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. average
# 2. manipulating
# 3. aware
# 4. support
# 5. counter
