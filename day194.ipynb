# %% [markdown]
# # Day194

# %% [markdown]
# # profile
#
# 英\[ˈprəʊfaɪl\] 美\[ˈproʊfaɪl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/profile)**
#
# n. 侧面，半面; 外形，轮廓; [航]翼型; 人物简介
#
# vt. 描…的轮廓; 给…画侧面图; 为（某人）写传略; [机]铣出…的轮廓
#
# **例句**：
#
# Dani has a lovely profile.
# 丹尼从侧面看真漂亮.
#
# Ability to know whoes profile is verified from search results.
# 搜索结果可以看出谁的的简历已经经过了确认.

# %% [markdown]
# # destination
#
# 英\[ˌdestɪˈneɪʃn\] 美\[ˌdestɪˈneɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/destination)**
#
# n. 目的，目标; 目的地，终点; [罕用语]预定，指定
#
# adj. 作为目的地的（旅馆、商店、饭店等）
#
# **例句**：
#
# Does providing my realm preference guarantee my destination?
# 我选择了新的服务器后,保证就能转到那个新的去?
#
# We are at last at our destination.
# 我们终于到达目的地.

# %% [markdown]
# # slowly
#
# 英\[ˈsləʊli\] 美\[ˈsloʊli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/slowly)**
#
# adv. 缓慢地，慢吞吞地，慢腾腾地; 慢条斯理地，不慌不忙地，袅袅; 迟钝，痴痴呆呆地; 逐步
#
# **例句**：
#
# The funeral made its way slowly through the silent streets.
# 送葬的队伍缓缓地穿过肃静的街道.
#
# Then he spoke slowly, but I could not understand him.
# 后来,他说话说得慢了, 但是我还是听不懂他的话.

# %% [markdown]
# # boundary
#
# 英\[ˈbaʊndri\] 美\[ˈbaʊndri\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/boundary)**
#
# n. 分界线; 范围; （球场）边线
#
# **例句**：
#
# A river forms the boundary between the two countries.
# 一条河流成了两国的分界线.
#
# Scientists have called the boundary area around the hole the event horizon.
# 科学家们把这个洞的边缘区域称为“事界”.

# %% [markdown]
# # specific
#
# 英\[spəˈsɪfɪk\] 美\[spəˈsɪfɪk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/specific)**
#
# adj. 明确的; 特种的; 具体的; [免疫学]特效的
#
# **例句**：
#
# We should make a concrete analysis of each specific question.
# 对于每个具体问题要进行具体分析.
#
# What's the specific time of his arrival?
# 他确切的到达时间是几点钟?

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. profile
# 2. destination
# 3. slowly
# 4. boundary
# 5. specific
