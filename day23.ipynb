# %% [markdown]
# # Day23

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=24>

# %% [markdown]
# # repeating
#
# 英\[rɪ'pi:tɪŋ\] 美\[rɪ'pitɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/repeating)**
#
# adj. 反复的，重复的
#
# v. 重做( repeat的现在分词 ); 复述; 重说; 重复发生
#
# **例句**：
#
# You are a bad boy for repeating what I told you.
# 重复我对你说的话，你真是个捣蛋鬼。
#
# Then he started rambling and repeating himself.
# 他接下来就开始不着边际、说话来回重复了。

# %% [markdown]
# # slide
#
# 英\[slaɪd\] 美\[slaɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/slide)**
#
# vi. 滑落; 下跌; 打滑; [棒球]滑垒
#
# vt. 衰落（成）; 逐渐降低; 使悄悄转动; （使）快捷而悄声地移动
#
# n. 幻灯片; 降低; 滑梯
#
# **例句**：
#
# Chao Shi Shuang Xiang clear, plastic food Braised sweet slide.
# 炒食清脆香爽,焖食胶滑甘甜.
#
# Push the trimmer slide key upwards until it is fixed , then run the shaver.
# 把修剪的滑面刀片按键推上, 待安装固定后开始剃须.

# %% [markdown]
# # shortcut
#
# 英\[ˈʃɔːtkʌt\] 美\[ˈʃɔːrtkʌt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/shortcut)**
#
# n. 捷径，近路; 被切短的东西
#
# **例句**：
#
# In the shortcut menu that appears next to the glyph, select the Add Column item.
# 在标志符号旁显示的快捷菜单上选择“添加列”项.
#
# There used to be a shortcut behind the hotel.
# 宾馆后面过去有一条近路.

# %% [markdown]
# # indexing
#
# 英\['ɪndeksɪŋ\] 美\['ɪndeksɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/indexing)**
#
# n. 标定指数; 变址; 标引; 索引
#
# **例句**：
#
# Observeing the symptoms, sings and the variety of the laboratory indexing.
# 治疗后观察症状 、 体征及实验室指标的变化.
#
# I had the job of indexing everything published in the physical sciences.
# 我的工作是给自然科学的所有出版物编索引.

# %% [markdown]
# # navigation
#
# 英\[ˌnævɪˈɡeɪʃn\] 美\[ˌnævɪˈɡeɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/navigation)**
#
# n. 航行（学）; 航海（术）; 海上交通
#
# **例句**：
#
# Show the top overlay and select Browse Guide from the navigation menu.
# 资料显示最常见覆盖,并选择浏览指南从导航菜单中.
#
# The top of Fig. 5 shows the clearance values during navigation.
# 图5的顶部表示(机器人)导航时的间隙值.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. repeating
# 2. slide
# 3. shortcut
# 4. indexing
# 5. navigation
