# %% [markdown]
# # Day236

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=237>

# %% [markdown]
# # whereas
#
# 英\[ˌweərˈæz\] 美\[ˌwerˈæz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/whereas)**
#
# conj. 鉴于; 然而; 反之
#
# n. “鉴于…”：正式文件的介绍性陈述，开场白; 条件性陈述
#
# **例句**：
#
# You told me it was so, whereas as a matter of fact it is not so.
# 你告诉我情况是那样, 而事实上情况并非那样.
#
# In partial moles, some villi ( as seen atlower left ) appear normal, whereas others are swollen.
# 在部分胎块中, 一些绒毛 ( 左下所示 ) 表现正常, 然而它处绒毛肿胀.

# %% [markdown]
# # either
#
# 英\[ˈaɪðə(r)\] 美\[ˈiː.ðər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/either)**
#
# pron. （两者之中）任何一个
#
# adv. （否定句中）也; [用于否定句或否定词组后]也（不…），亦，而且; [口语] [用于否定句或否定词组后以加强语气]根本; 当然
#
# conj. [通常用于“either…or…”结构中]或者，要么[在“either…or…”结构中，动词的人称和数一般与离得最近的主动响应，但有时用第三人称单数，在口语中也有把两个主语合在一起用作复数的]
#
# **例句**：
#
# In either event you will benefit.
# 无论怎样你都会得到好处的.
#
# A buxom widow must be either married , buried or shut up in a convent.
# 寡妇门前是非多.

# %% [markdown]
# # except
#
# 英\[ɪkˈsept\] 美\[ɪkˈsept\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/except)**
#
# vt. 把…除外; 不计
#
# prep. 除…外
#
# conj. [口语]要不是; 除非; 除…以外
#
# vi. 反对，表示异议（与 to 或 against连用）
#
# **例句**：
#
# He could do little except write.
# 他除了会写之外,其他什么都不行.
#
# He works every day except Sunday.
# 除星期天外,他每天都工作.

# %% [markdown]
# # memory
#
# 英\[ˈmeməri\] 美\[ˈmeməri\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/memory)**
#
# n. 记忆，记忆力; 回忆，往事; [计]存储器，内存
#
# **例句**：
#
# This story had lodged in his memory.
# 这个故事已深植在他记忆中.
#
# His memory is a blank.
# 他什么也记不起来.

# %% [markdown]
# # mirror
#
# 英\[ˈmɪrə(r)\] 美\[ˈmɪrər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/mirror)**
#
# n. 镜子，反光镜; 真实的写照; 反映，借鉴; 榜样
#
# vt. 反映; 反射
#
# **例句**：
#
# The mirror dropped and broke with a crash.
# 啪嚓一声,镜子掉在地上摔碎了.
#
# The surface of the water is as smooth as a mirror.
# 水平如镜.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. whereas
# 2. either
# 3. except
# 4. memory
# 5. mirror
