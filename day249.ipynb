# %% [markdown]
# # Day249

# %% [markdown]
# # total
#
# 英\[ˈtəʊtl\] 美\[ˈtoʊtl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/total)**
#
# adj. 总计的（金额等）; 全部的; 完全的; 绝对的
#
# n. 总计，总数; 全体数量
#
# vt.& vi. 总计达，计算…的总数
#
# **例句**：
#
# The king's escort total 50 men.
# 国王的警卫队总数达50人.
#
# I intend to amortize the total cost of the car over three years.
# 我打算用三年时间分期偿还汽车的所有费用.

# %% [markdown]
# # method
#
# 英\[ˈmeθəd\] 美\[ˈmeθəd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/method)**
#
# n. 方法; 条理
#
# **例句**：
#
# We all agree in adopting the new teaching method.
# 我们一致同意采取新的教学方法.
#
# A new method of fuel injection was developed during the war.
# 一种新的注油方法在战争期间发展起来.

# %% [markdown]
# # digital
#
# 英\[ˈdɪdʒɪtl\] 美\[ˈdɪdʒɪtl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/digital)**
#
# adj. 数字的; 数据的; 手指的; 指状的
#
# n. 手指; （钢琴等的）琴键; 数字
#
# **例句**：
#
# With Digital Universe, Emmart and Hayden Planetarium can take viewers deep into space on interstellar missions.
# 随着数字宇宙, 埃马尔特和海登天文馆可以考虑到星际空间飞行任务观众深.
#
# There's a digital watch on the table.
# 桌子上有一块数字式手表.

# %% [markdown]
# # keyboard
#
# 英\[ˈkiːbɔːd\] 美\[ˈkiːbɔːrd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/keyboard)**
#
# n. 键盘; 琴键; 电子琴
#
# vt. 用键盘输入; 用键盘式排字机排字
#
# vi. 用键盘进行操作; 作键盘式排字机排字
#
# **例句**：
#
# When off, the screen is completely transparent and the keyboard goes opaque.
# 当后, 屏幕上是完全透明和键盘不用不透明.
#
# Learn more about using the keyboard.
# 学习和使用更多的键盘快捷键.

# %% [markdown]
# # natural
#
# 英\[ˈnætʃrəl\] 美\[ˈnætʃrəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/natural)**
#
# adj. 自然的; 物质的; 天生的; 不做作的
#
# n. 自然的事情; （生来的）白痴; [乐]（风琴等的）白键
#
# **例句**：
#
# Iceland is full of hot springs, beautifully coloured rocks, and other natural wonders.
# 冰岛遍布温泉 、 美丽的五彩岩石和其他自然奇观.
#
# It's natural for children to grow away from their family.
# 孩子们长大以后离开家庭是很自然的事.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. total
# 2. method
# 3. digital
# 4. keyboard
# 5. natural
