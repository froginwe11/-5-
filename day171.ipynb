# %% [markdown]
# # Day171

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=172>

# %% [markdown]
# # let
#
# 英\[let\] 美\[let\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/let)**
#
# 允许，任由; 让，随; 假设; 出租
#
# **例句**：
#
# Let us finalize tonight.
# 让我们今天晚上干完.
#
# When he was with her, his nerve never let up.
# 和她在一起, 他总是感到很激动.

# %% [markdown]
# # double
#
# 英\[ˈdʌbl\] 美\[ˈdʌbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/double)**
#
# adj. 双的; 两倍的; 两面派的; 双人用的
#
# vt. 使加倍; 把…对折; 重复
#
# vi. 加倍，加倍努力; 快步走
#
# adv. 两倍地; 双重地
#
# n. 两倍; 双精度型
#
# det. 两倍的；双倍的
#
# **例句**：
#
# This machine serves a double purpose.
# 这部机器有双重用途.
#
# Double over the map so that we can read it more easily.
# 把地图对折起来,这样看起来更容易.

# %% [markdown]
# # home
#
# 英\[həʊm\] 美\[hoʊm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/home)**
#
# n. 家; 家庭; 家庭生活; 终点
#
# adj. 家庭的; 家用的; 本地的; 本部的
#
# adv. 在家; 在家乡; 深深地; 深入地
#
# **例句**：
#
# In a pinch, you could get home on foot.
# 在万不得已时, 你可以步行回家.
#
# My mother makes a fuss of me every time I come home.
# 我每次回家,母亲总对我体贴备至.

# %% [markdown]
# # away
#
# 英\[əˈweɪ\] 美\[əˈweɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/away)**
#
# adv. 离开，远离; 在远处; 消失
#
# **例句**：
#
# She has a fortune stashed away in various bank accounts.
# 她在不同的银行账户上秘密储存了一大笔钱.
#
# He was carried away by his enthusiasm.
# 热情使他的头脑不够冷静.

# %% [markdown]
# # refer
#
# 英\[rɪˈfɜː(r)\] 美\[rɪˈfɜːr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/refer)**
#
# vi. 提到; 针对; 关系到; 请教
#
# vt. 归因于…; 使求助于; 送交; 认为…起源于
#
# vt.& vi. 参考，查阅
#
# **例句**：
#
# Our observations may contain a grain of truth for you to refer to.
# 我们的意见也许会有千虑一得之处,供你参考.
#
# Don't refer to the matter again.
# 不要再提这件事了.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. let
# 2. double
# 3. home
# 4. away
# 5. refer
