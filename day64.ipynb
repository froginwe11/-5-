# %% [markdown]
# # Day64

# %% [markdown]
# # index
#
# 英\[ˈɪndeks\] 美\[ˈɪndeks\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/index)**
#
# n. 索引; <数>指数; 指示; 标志
#
# vt. 给…编索引; 把…编入索引; [经济学]按生活指数调整（工资、价格等）
#
# vi. [机械学]转位
#
# **例句**：
#
# The average recovery of the added index was 99.16 %.
# 结果:简便准确,专属性强,其方法的平均加样回收率为99.
#
# Price total index rises somewhat, fundamental product value rises situation hasten delay.
# 价格总指数略有上升, 基础产品价格涨势趋缓.

# %% [markdown]
# # ascii
#
#
#
# **[释义](https://fanyi.baidu.com/#en/zh/ascii)**
#
# 美国信息交换标准代码
#
# **例句**：
#
# Files can be exported in ASCII or PCX formats.
# 文件可以以ASCII或者PCX格式导出。
#
# For the Username, do not use spaces, and do use ASCII characters.
# 对于用户名, 不要用空格, 一定要使用ASCII字符.

# %% [markdown]
# # backup
#
# 英\[ˈbækʌp\] 美\[ˈbækʌp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/backup)**
#
# n. 支持，后援; 阻塞; <计>备份文件; [乐]伴奏
#
# **例句**：
#
# We had no computer backup and had to rely on old paper files to reconstruct the records.
# 我们没有计算机备份,只得靠落后的纸档案重做记录.
#
# Our troops cut the enemy's backup supplies from behind their back.
# 我军从后方斩断了敌人的后勤供给线.

# %% [markdown]
# # previously
#
# 英\[ˈpriːviəsli\] 美\[ˈpriːviəsli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/previously)**
#
# adv. 事先; 以前; 仓促; “previous”的派生
#
# **例句**：
#
# The device had been used operationally some months previously.
# 该设备几个月之前曾投入运行。
#
# He may suddenly take a dislike to foods that he's previously enjoyed.
# 对以前爱吃的食物，他兴许突然就没了胃口。

# %% [markdown]
# # unsuccessful
#
# 英\[ˌʌnsəkˈsesfl\] 美\[ˌʌnsəkˈsɛsfəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/unsuccessful)**
#
# adj. 不成功的，失败的; 碌碌无为
#
# **例句**：
#
# It becomes necessary to cannibalize unsuccessful projects to fund those which can proceed ( Daily Report for Executives )
# 当务之急是将不成功项目中的资金抽调出来以支持那些可行项目 ( 管理者每日报告 )
#
# The satellite launch was unsuccessful.
# 卫星发射失败了.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. index
# 2. ascii
# 3. backup
# 4. previously
# 5. unsuccessful
