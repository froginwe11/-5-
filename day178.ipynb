# %% [markdown]
# # Day178

# %% [markdown]
# # compose
#
# 英\[kəmˈpəʊz\] 美\[kəmˈpoʊz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/compose)**
#
# vt. 组成，构成; 调解; [印刷]排（字）; 使安定
#
# vt.& vi. 创作（乐曲、诗歌等）; 为…谱曲
#
# vi. 构图，构成
#
# **例句**：
#
# This raw, dirty town seemed naturally to compose itself into stirring artistic pictures.
# 这个新辟的污秽城市仿佛天然自成一幅幅动人的优美图画.
#
# When I am in the humour I can compose grand symphonies, and paint magnificent pictures.
# 如果我有兴致的话,我可以谱写出宏伟的交响乐, 描绘出壮丽的画卷.

# %% [markdown]
# # congratulation
#
# 英\[kənˌɡrætʃuˈleɪʃn\] 美\[kənˌɡrætʃuˈleɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/congratulation)**
#
# n. 祝贺，恭喜; 贺词
#
# **例句**：
#
# Congratulation! You are an registered user.
# 祝贺! 你是注册用户了.
#
# He has received many letters in congratulation of his birthday.
# 他收到许多祝贺他生日的信件.

# %% [markdown]
# # accept
#
# 英\[əkˈsept\] 美\[əkˈsept\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/accept)**
#
# vi. 承认; 同意; 承兑
#
# vt. 接受; 承认; 承担; 承兑
#
# **例句**：
#
# Please accept my condolences.
# 请接受我的慰问.
#
# He is disposed to accept the new job, for the pay is higher.
# 他倾向于接受这个新的工作, 因为工资高一些.

# %% [markdown]
# # editor
#
# 英\[ˈedɪtə(r)\] 美\[ˈedɪtər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/editor)**
#
# n. 编辑，编者; 校订者; [计]编辑软件，编辑程序
#
# **例句**：
#
# The editor of the magazine was hard up for material.
# 那家杂志的编辑缺少材料.
#
# When a manuscript has been accepted for publication, it is passed to an editor for detailed scrutiny.
# 当原稿被采用出版时, 便将它交与一名编辑进行仔细校阅.

# %% [markdown]
# # truncate
#
# 英\[trʌŋˈkeɪt\] 美\[ˈtrʌŋkeɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/truncate)**
#
# vt. 缩短
#
# **例句**：
#
# MEI is an effective numerical method to truncate finite difference mesh.
# 方法是一种有效的用于边界截断的数值计算方法.
#
# Sorry, the text is too long to edit. Truncate it to 255 characters?
# 对不起, 文本太长了,无法进行编辑. 将其截断到255个字符 吗 ?

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. compose
# 2. congratulation
# 3. accept
# 4. editor
# 5. truncate
