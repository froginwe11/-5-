# %% [markdown]
# # Day22

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=23>

# %% [markdown]
# # mean
#
# 英\[miːn\] 美\[miːn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/mean)**
#
# v. 表示…的意思; 意思是; 打算; 产生…结果
#
# adj. 吝啬的; 刻薄的; 破旧的; 残忍的
#
# n. 平均数; 中间; 几何平均; 等比中数
#
# **例句**：
#
# I mean that it is impossible.
# 我的意思是说那不可能.
#
# A silent movie doesn't mean it is motionless.
# 无声电影并非没有动作.

# %% [markdown]
# # kilobyte
#
# 英\[ 'kɪləʊ.baɪt\] 美\[ 'kɪlə.baɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/kilobyte)**
#
# 千字节，1024字节
#
# **例句**：

# %% [markdown]
# # application
#
# 英\[ˌæplɪˈkeɪʃn\] 美\[ˌæplɪˈkeɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/application)**
#
# n. 适用，应用，运用; 申请，请求，申请表格; 勤勉，用功; 敷用，敷用药
#
# **例句**：
#
# They filed an application to have their case heard early.
# 他们申请早日审理他们的案子.
#
# Her application was turned down.
# 她的申请被驳回了.

# %% [markdown]
# # assortment
#
# 英\[əˈsɔːtmənt\] 美\[əˈsɔːrtmənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/assortment)**
#
# n. 分类; 搭配; 花色品种; 混合物
#
# **例句**：
#
# We have a large assortment of them.
# 这些我们有许多花色品种.
#
# You will please to notice that this consignment will consist of an assortment of fancy goods.
# 本次寄售品,系各种花色货,请查收.

# %% [markdown]
# # desirable
#
# 英\[dɪˈzaɪərəbl\] 美\[dɪˈzaɪərəbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/desirable)**
#
# adj. 令人满意的; 值得拥有的; 可取的; 性感的
#
# **例句**：
#
# You've looked more desirable.
# 你的模样真迷人.
#
# We think a regulatory approach is not desirable, as it may suppress benign investment.
# 我们认为规定性的方法不可取, 因为它可能会压制善意的投资.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. mean
# 2. kilobyte
# 3. application
# 4. assortment
# 5. desirable
