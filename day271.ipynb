# %% [markdown]
# # Day271

# %% [markdown]
# # give
#
# 英\[ɡɪv\] 美\[ɡɪv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/give)**
#
# vt.& vi. 给予; 赠送; 作出
#
# vt. 供给; 产生; 举办; （为购买某物或做某事而）支付
#
# vi. （物体）塌下; 让步
#
# n. 伸展性，弹性
#
# **例句**：
#
# Please give me a lift onto the saddle.
# 请扶我上马鞍.
#
# I shall have to read up on this subject if I am to give a talk about it.
# 如果我准备做一次关于这课题的讲座,我就必须把它彻底研究一番.

# %% [markdown]
# # abbreviate
#
# 英\[əˈbri:vieɪt\] 美\[əˈbriviˌet\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/abbreviate)**
#
# vt. 使简短; 缩简; 缩略; 使用缩写词
#
# **例句**：
#
# If delete, do not weigh, undertake abbreviate to this article.
# 把不重要是删除, 对该文章进行缩写.
#
# I like to abbreviate my title since it's easier for human to remember.
# 我喜爱简写我的姓名,因该那样大部分人更简易记住.

# %% [markdown]
# # invalid
#
# 英\[ɪnˈvælɪd , ˈɪnvəlɪd\] 美\[ɪnˈvælɪd , ˈɪnvəlɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/invalid)**
#
# adj. 无效的; 不能成立的; 有病的; 病人用的
#
# vt. 使伤残; 使退役; 失去健康
#
# n. 病人，病号; 残废者; 伤病军人
#
# vi. 变得病弱; 因病而奉命退役
#
# **例句**：
#
# It is possible for any anti - corrosion action to become invalid, corrosion can not be avoided.
# 任何防腐措施都存在失效的可能, 腐蚀是不可避免的.
#
# Invalid message for a combo box because it does not have an edit control.
# 因为没有编辑控制,所以组合框的消息无效.

# %% [markdown]
# # confirm
#
# 英\[kənˈfɜːm\] 美\[kənˈfɜːrm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/confirm)**
#
# vt. [法]确认，批准; 证实; 使有效; 使巩固
#
# **例句**：
#
# Confirm with Group Leader and SPE Engineer the concept design and detail execution of his work.
# 和主管以及SPE工程师一起确认方案及其详细施工.
#
# I'll confirm the dress code for the party tomorrow. I don't want to be underdressed.
# 我明天会确认派对的服装规定;我可不想穿著不得体.

# %% [markdown]
# # according
#
# 英\[ə'kɔːdɪŋ\] 美\[ ə'kɔrdɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/according)**
#
# v. 给予(权力、地位、某种待遇); (与…)一致，符合（accord的现在分词）
#
# **例句**：
#
# According to the assessor's statement, the fire damage was not severe.
# 根据估价员的估计, 火灾损失并不严重.
#
# We wanted to buy a bigger house than this but we had to cut our coat according to our cloth.
# 我们原想买比这个大些的房子,但是得量力而为呀.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. give
# 2. abbreviate
# 3. invalid
# 4. confirm
# 5. according
