# %% [markdown]
# # Day306

# %% [markdown]
# # deal
#
# 英\[diːl\] 美\[diːl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/deal)**
#
# vt. [牌戏]分; 分配; 经营; 施予
#
# n. （一笔）交易; 许多; 待遇; 发牌
#
# vi. 论述; （有效地或成功地）处理; 惩处; 交易
#
# **例句**：
#
# It takes a great deal of courage to face the situation bravely.
# 大胆地正视这一局面需要很大的勇气.
#
# There is a great deal of difference between the two.
# 两者相差甚远.

# %% [markdown]
# # alphabetical
#
# 英\[ˌælfəˈbetɪkl\] 美\[ˌælfəˈbetɪkl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/alphabetical)**
#
# adj. 按字母（表）顺序的
#
# **例句**：
#
# All the catalogues are in alphabetical order by author, title, and subject.
# 所有目录都是以作者姓名 、 书名及主题按字母顺序编制的.
#
# Please organize the books on the shelf in alphabetical order.
# 请把书架上的书按照字母顺序摆好.

# %% [markdown]
# # host
#
# 英\[həʊst\] 美\[hoʊst\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/host)**
#
# n. [计算机]主机; 主人，东道主; 节目主持人; 酒店业主
#
# vt. 当主人; 主办宴会，主持节目; 款待，做东
#
# vi. 做主人，做东道主
#
# **例句**：
#
# That would be reversal of the order of host and guest.
# 这就主客颠倒了.
#
# The harbor is busy night and day, within a year playing host to freighters from more than 30 countries and regions.
# 这港口日夜繁忙, 一年内接待了来自30多个国家和地区的货轮.

# %% [markdown]
# # leave
#
# 英\[liːv\] 美\[liːv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/leave)**
#
# vt. 离开; 遗弃; 忘了带; 交托
#
# vt.& vi. 离去; 出发; 舍弃; 留下
#
# n. 准假; 假期; 辞别; 许可
#
# **例句**：
#
# Don't leave me behind.
# 不要把我忘了.
#
# Why do you leave all the hard work up to your mother?
# 你为什么把所有难做的事都留给你母亲?

# %% [markdown]
# # remove
#
# 英\[rɪˈmuːv\] 美\[rɪˈmuːv\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/remove)**
#
# vt. 开除; 去除; 脱掉，拿下; 迁移
#
# vi. 迁移，移居; 离开
#
# n. 距离，差距; 移动
#
# **例句**：
#
# Ladies remove their hats in a concert.
# 女士们在音乐会上脱下帽子.
#
# It is a custom among the Japanese to remove their footwear before entering a house.
# 脱鞋进屋是日本人的习惯.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. deal
# 2. alphabetical
# 3. host
# 4. leave
# 5. remove
