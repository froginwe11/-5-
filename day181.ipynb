# %% [markdown]
# # Day181

# %% [markdown]
# # variable
#
# 英\[ˈveəriəbl\] 美\[ˈveriəbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/variable)**
#
# adj. 变化的，可变的; [数]变量的; [生]变异的
#
# n. 可变因素，变量; 易变的东西
#
# **例句**：
#
# Modifications js method name and global variable names to avoid naming conflicts.
# 修改部分js方法名称及全局变量名称,避免命名冲突.
#
# Variable speed control of a governor.
# 变量更调速控制速度.

# %% [markdown]
# # around
#
# 英\[əˈraʊnd\] 美\[əˈraʊnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/around)**
#
# adv. 大约; 旋转; 到处，四处; 在周围
#
# prep. 围绕; 在附近; 前后，左右; 在…周围
#
# **例句**：
#
# You shouldn't fool around with dangerous chemicals.
# 你不应该玩弄危险的化学品.
#
# The driveway makes a hook around an old tree.
# 车道绕过一棵老树来了个急转弯.

# %% [markdown]
# # probable
#
# 英\[ˈprɒbəbl\] 美\[ˈprɑːbəbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/probable)**
#
# adj. 可能的; 大概的
#
# n. 很可能的事; 可能入选者
#
# **例句**：
#
# It is hardly probable that he will succeed.
# 他不会成功.
#
# Now the future is probable.
# 未来是可能的.

# %% [markdown]
# # safe
#
# 英\[seɪf\] 美\[seɪf\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/safe)**
#
# adj. 安全的; 保险的，肯定的; 无损的; 提供保护的
#
# n. 保险箱，保险柜; 冷藏箱; 〈俚〉避孕套
#
# **例句**：
#
# Mary kept her valuables in a safe.
# 玛丽把她的贵重东西藏在保险箱里.
#
# When the river dike is completed , the crops will be safe against floods.
# 修好河堤, 庄稼就不怕淹了.

# %% [markdown]
# # opinion
#
# 英\[əˈpɪnjən\] 美\[əˈpɪnjən\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/opinion)**
#
# n. 意见，主张; 评价; 鉴定，判定
#
# **例句**：
#
# Public opinion at last became vocal.
# 终于舆论哗然.
#
# She invited our opinion of her story.
# 她征求我们对她的故事的意见.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. variable
# 2. around
# 3. probable
# 4. safe
# 5. opinion
