# %% [markdown]
# # Day152

# %% [markdown]
# # logged
#
# 英\[lɔ:gd\] 美\[lɔgd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/logged)**
#
# adj. 笨拙的，（树）劈成木材的
#
# **例句**：
#
# Details of the crime are then logged in the computer.
# 随后会将罪案的详细情况录入到计算机里。
#
# We have logged up a remarkable series of gains in technical innovation.
# 我们已在技术革新方面取得一系列可观的成就.

# %% [markdown]
# # replaceable
#
# 英\[rɪˈpleɪsəbl\] 美\[rɪˈpleɪsəbl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/replaceable)**
#
# adj. 可代替的
#
# **例句**：
#
# He would see I was not so easily replaceable.
# 他会看到我不是那么容易被替代的。
#
# A person, unlike a machine, is not replaceable.
# 人和机器不同, 是不可替代的.

# %% [markdown]
# # format
#
# 英\[ˈfɔːmæt\] 美\[ˈfɔːrmæt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/format)**
#
# n. （出版物的）版式; [自]（数据安排的）形式; 电视节目的总安排（或计划）
#
# vt. 使格式化; 安排…的格局; 设计…的版面
#
# vi. 设计一个版式
#
# **例句**：
#
# Fujian against commercial housing sales contract format, the piling design process.
# 针对福建省商品房销售合同格式, 设计的套打程序.
#
# The string resource identifier that contains the format - control string.
# 包含格式控制字符串的字符串资源标记.

# %% [markdown]
# # piece
#
# 英\[piːs\] 美\[piːs\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/piece)**
#
# n. 块，片，段; 部分，部件; 文章，音乐作品
#
# vt. 修补; 接合，结合; 凑合
#
# **例句**：
#
# I've got some 〔 a piece of 〕 grit in my shoe.
# 我的鞋里进了些〔一粒〕沙子.
#
# This piece of material may be cut up to make a pair of trousers.
# 这块布料可以裁一条裤子.

# %% [markdown]
# # delimit
#
# 英\[diˈlɪmɪt\] 美\[dɪˈlɪmɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/delimit)**
#
# vt. 限制，定…的界
#
# **例句**：
#
# How does ability delimit affection cent is clear about.
# 怎么才能把情感划分清楚.
#
# In there, you may swim, delimit the ship, seize the fish, the drift, jump the level.
# 在那里, 你可以游泳 、 划船 、 捉鱼 、 漂流 、 蹦级.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. logged
# 2. replaceable
# 3. format
# 4. piece
# 5. delimit
