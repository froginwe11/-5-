# %% [markdown]
# # Day262

# %% [markdown]
# # placement
#
# 英\[ˈpleɪsmənt\] 美\[ˈpleɪsmənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/placement)**
#
# n. 安置，放置; 实习工作，实习课; 定位，[足]定位球
#
# **例句**：
#
# There are also basic indicators built in and commands of order placement and control.
# 系统中还包含了基本的内建指示器(指标)和用来购置以及控制定单的命令.
#
# The placement of each knob visually suggests which burner it will turn on.
# 每个旋钮的位置都在视觉上清晰地显示出其控制的火眼.

# %% [markdown]
# # consume
#
# 英\[kənˈsjuːm\] 美\[kənˈsuːm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/consume)**
#
# vt. 消耗，消费; 耗尽，毁灭; 吃光，喝光; 烧毁
#
# **例句**：
#
# Professor Guldan is concerned that a large proportion of urban Asian children consume an unbalanced diet.
# 使古尔丹教授忧虑的是很大一部分亚洲城市里的孩子饮食不平衡.
#
# Compared with developing countries, developed countries consume more energy.
# 8与发展中国家相比, 发达国家消耗更多能源.

# %% [markdown]
# # play
#
# 英\[pleɪ\] 美\[pleɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/play)**
#
# n. 比赛; 游戏; 戏剧; 赌博
#
# vt.& vi. 玩; 演奏; 演出; 参加比赛
#
# vt. 扮演; 担任，充当…的角色; 演出; 装扮
#
# vi. 玩耍，游戏; [游戏] 参加游戏; 赌博; 闹着玩
#
# **例句**：
#
# He disillusioned his fans by his sloppy play.
# 他草率的表演使他的崇拜者大失所望.
#
# She seems to have camped up at the third act of the play.
# 她在第三幕中表演得似乎过火了.

# %% [markdown]
# # clause
#
# 英\[klɔːz\] 美\[klɔːz\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/clause)**
#
# n. 从句，分句; 条款，款项
#
# **例句**：
#
# A try statement may have more than one except clause, to specify handlers for different exceptions.
# 一个try语句可能包含多个except子句, 分别指定处理不同的异常.
#
# What clause do you require in the contract?
# 你要求在合同中订上什么条款?

# %% [markdown]
# # amount
#
# 英\[əˈmaʊnt\] 美\[əˈmaʊnt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/amount)**
#
# n. 量，数量; 总额; 本利之和; 全部效果，全部含义
#
# **例句**：
#
# There is a lot of concern over the amount of herbicides and pesticides used in farming.
# 人们对农业上灭草剂和杀虫剂的用量非常担忧.
#
# There's no stipulation as to the amount you can invest.
# 没有关于投资额的规定.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. placement
# 2. consume
# 3. play
# 4. clause
# 5. amount
