# %% [markdown]
# # Day161

# %% [markdown]
# # flush
#
# 英\[flʌʃ\] 美\[flʌʃ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/flush)**
#
# vi. 脸红; 呈红色; 奔流; 冲刷
#
# adj. 满面红光的; 富足的，丰富的; 盈满的，没过的; 水平的，同高的
#
# n. 奔流，涌出; 脸红或发亮; 发热; 强烈情感的冲动
#
# vt. 发红或发亮; 使兴奋或得意; （以水）冲刷，冲洗; 冲掉，除掉
#
# **例句**：
#
# The truth is, some health care can probably be safely off until you're feeling more flush.
# 事实是这样一些医疗保健可能可安全的推迟进行,直到你觉得更富裕时.
#
# But all the bloomy flush of life is fled.
# 而整个精力旺盛的青春已经一去不复返了.

# %% [markdown]
# # hold
#
# 英\[həʊld\] 美\[hoʊld\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hold)**
#
# vt. 拿住，握住; 保留，保存; 扣留，拘押; 容纳; 举行
#
# vi. 拿住，握住; 同意，赞成; 保持不变; 有效
#
# n. 握住; 保留; 控制
#
# **例句**：
#
# Hold to my hand while we cross the street.
# 我们过马路时,你要抓住我的手.
#
# The caller is on hold.
# 那个打电话的人正等着通话.

# %% [markdown]
# # standard
#
# 英\[ˈstændəd\] 美\[ˈstændərd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/standard)**
#
# n. 标准，规格; 旗，军旗; 度量衡标准; 直立支柱
#
# adj. 标准的，合格的; 普遍的，一般的; 公认为优秀的
#
# **例句**：
#
# The quality of this product is up to standard.
# 这项产品的质量已经过关.
#
# I try to live up to the high standard of the school.
# 我力求达到这所学校的高标准要求.

# %% [markdown]
# # mark
#
# 英\[mɑːk\] 美\[mɑːrk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/mark)**
#
# n. 斑点; 记号; 成绩; 标准
#
# vt. 作记号; 表示; 给…打分; 在…留下痕迹
#
# vi. 评分; 注意; （比赛中）记分
#
# **例句**：
#
# You don't study hard, thence no good mark.
# 你不努力学习, 因而没有好分数.
#
# Mark boosted his cousin into a better job.
# 马克吹捧自己的堂兄,使他得到较好的工作.

# %% [markdown]
# # software
#
# 英\[ˈsɒftweə(r)\] 美\[ˈsɔːftwer\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/software)**
#
# n. 软件; 软体; 软设备
#
# **例句**：
#
# He bought a new software package.
# 他买了一个新的软件包.
#
# All the statistical computations were performed by the new software system.
# 所有的统计计算均由新的软件系统完成。

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. flush
# 2. hold
# 3. standard
# 4. mark
# 5. software
