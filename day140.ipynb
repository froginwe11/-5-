# %% [markdown]
# # Day140

# %% [markdown]
# # backward
#
# 英\[ˈbækwəd\] 美\[ˈbækwərd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/backward)**
#
# adj. 向后的; 反向的; 怯生生的; 落后的
#
# **例句**：
#
# Take a frequent backward look at yesterday, you will value today and look forward to tomorrow.
# 经常的回顾昨天, 你会珍惜今天并向往明天.
#
# It has the magic to turn a backward town into a wonderland of prosperity.
# 旅游被赋予了某种魔力,能够把一个落后的小镇变成一个令人神往的胜地.

# %% [markdown]
# # configuration
#
# 英\[kənˌfɪɡəˈreɪʃn\] 美\[kənˌfɪɡjəˈreɪʃn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/configuration)**
#
# n. 布局，构造; 配置; [化]（分子中原子的）组态，排列; [物]位形，组态
#
# **例句**：
#
# Traditionally templet an important part in machining accessory and configuration with its easy and intuitionistic measure.
# 在传统零件加工和装配过程中样板充当重要的角色,它测量简单直观.
#
# The configuration of complementary judgement matrix and methods of solving it were studied.
# 研究互补型判断矩阵的构成及求解方法.

# %% [markdown]
# # limit
#
# 英\[ˈlɪmɪt\] 美\[ˈlɪmɪt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/limit)**
#
# n. 限制; 限量，限度; 界限
#
# vt. 限制，限定
#
# **例句**：
#
# There isn't a limit to everything.
# 对每件事情没有什么限制.
#
# There is a limit to one's life, but no limit to serving the people.
# 人的生命是有限的, 但为人民服务是无限的.

# %% [markdown]
# # select
#
# 英\[sɪˈlekt\] 美\[sɪˈlekt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/select)**
#
# vt. 选择; 挑选; 选拔
#
# adj. 精选的; 挑选出来的; 苛择的; 〈口〉爱挑三拣四的，挑剔的
#
# **例句**：
#
# Therefore need to select one of the best reverberation time.
# 因此需要选择一个最佳混响时间.
#
# Show the top overlay and select Browse Guide from the navigation menu.
# 资料显示最常见覆盖,并选择浏览指南从导航菜单中.

# %% [markdown]
# # object
#
# 英\[ˈɒbdʒɪkt\] 美\[ ˈɑːbdʒekt,ˈɑːbdʒɪkt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/object)**
#
# n. 物体; 目标; 宾语; 客体，对象
#
# v. 不同意；不赞成；反对,提出…作为反对的理由；抗辩说
#
# vi. 不赞成，反对; 抱反感
#
# vt. 提出…作反对的理由
#
# **例句**：
#
# I don't object to a glass of hot water.
# 我想喝杯开水.
#
# The rapid movement of an object towards the eye triggers the blink reflex.
# 快速朝眼前移动物体,就会引起眨眼反应.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. backward
# 2. configuration
# 3. limit
# 4. select
# 5. object
