# %% [markdown]
# # Day150

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=151>

# %% [markdown]
# # alignment
#
# 英\[əˈlaɪnmənt\] 美\[əˈlaɪnmənt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/alignment)**
#
# n. 队列，排成直线; 结盟; 校直，调整; [工]准线
#
# **例句**：
#
# The tables are in alignment.
# 桌子摆得很整齐.
#
# However the trick we have added is that Alignment influences which faction you can join.
# 每个国家会看自己和每个阵营的关系.

# %% [markdown]
# # result
#
# 英\[rɪˈzʌlt\] 美\[rɪˈzʌlt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/result)**
#
# n. 结果; （尤指足球比赛的）胜利; [体]比分; 成功实现的事
#
# vi. 发生，产生; 归结为，导致; 后果，终结; 由…而造成[产生]
#
# **例句**：
#
# Excessive dosage of this drug can result in injury to the liver.
# 这种药使用过量会损害肝脏.
#
# A minimal error or deviation may result in wide divergence.
# 失之毫厘,谬以千里.

# %% [markdown]
# # volume
#
# 英\[ˈvɒljuːm\] 美\[ˈvɑːljuːm\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/volume)**
#
# n. 量，大量; 体积; 音量; 卷
#
# **例句**：
#
# The companion volume will soon be published.
# 这卷书的姊妹篇即将问世.
#
# Up to now, I've read as far as the fifth chapter, the second volume of " The War and Peace ".
# 到今天, 我已经读到 《 战争与和平 》 的第2卷第5章了.

# %% [markdown]
# # grant
#
# 英\[ɡrɑːnt\] 美\[ɡrænt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/grant)**
#
# vt. 承认; 同意; 准许; 授予
#
# n. 拨款; 补助金; 授给物（如财产、授地、专有权、补助、拨款等）
#
# vi. 同意
#
# **例句**：
#
# Stop grant depends on the length of the actual reform process of the two groups.
# 停批时间长短实际取决于两大集团的整改进程.
#
# No. 15 years'protection is the minimum protection any other country will grant its patentees.
# 不是的.其他任何国家都对专利人给予最低15年的专利保护.

# %% [markdown]
# # required
#
# 英\[rɪ'kwaɪəd\] 美\[rɪ'kwaɪəd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/required)**
#
# adj. 必须的，<美>（学科）必修的
#
# v. 要求( require的过去式和过去分词 ); 需要; 想要; 命令
#
# **例句**：
#
# The demand generated by one factory required the construction of another.
# 一家工厂产生的需求使得必须再建造一家工厂。
#
# Interest is paid monthly. Three months' notice is required for withdrawals.
# 利息按月支付。提款须提前3个月通知银行。

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. alignment
# 2. result
# 3. volume
# 4. grant
# 5. required
