# %% [markdown]
# # Day17

# %% [markdown]
# # describe
#
# 英\[dɪˈskraɪb\] 美\[dɪˈskraɪb\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/describe)**
#
# vt. 描写，形容; 叙述; 描绘，作图; （行星等）周转
#
# **例句**：
#
# Who'd like to describe what happened just now?
# 谁来描述一下刚才所发生的情形?
#
# Words can hardly describe how excited we were.
# 我们激动的心情难以用笔墨来形容.

# %% [markdown]
# # static
#
# 英\[ˈstætɪk\] 美\[ˈstætɪk\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/static)**
#
# adj. 静止的; 不变的; 静电的; [物]静力的
#
# n. 静电; [物]静电（干扰）; 静力学; 争吵
#
# **例句**：
#
# We can build special customer specifications for the product, providing static control technical services.
# 本公司可以为客户订做特殊规格的产品, 提供静电控制技术服务.
#
# Pulse is photoelectric isolation static idle contact form output.
# 脉冲是光电隔离的静态空接点形式输出.

# %% [markdown]
# # lightning
#
# 英\[ˈlaɪtnɪŋ\] 美\[ˈlaɪtnɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/lightning)**
#
# adj. 闪电般的，快速的
#
# n. 闪电，雷电
#
# **例句**：
#
# Lightning streaks from cloud to cloud.
# 闪电划过朵朵乌云.
#
# Lightning zigzagged across the sky.
# 闪电曲折地在天空划过.

# %% [markdown]
# # manually
#
# 英\[ˈmænjʊəli\] 美\[ˈmænjuəli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/manually)**
#
# adv. 用手地，手工地
#
# **例句**：
#
# Add code manually to handle UI events.
# 手工加代码处理UI事件.
#
# If you want to pass private key information, you will have to manually send that data.
# 如果希望传递私钥信息, 则必须手动发送该数据.

# %% [markdown]
# # commercial
#
# 英\[kəˈmɜːʃl\] 美\[kəˈmɜːrʃl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/commercial)**
#
# adj. 商业的; 贸易的; 营利的; 靠广告收入的
#
# n. （电台或电视播放的）广告
#
# **例句**：
#
# The right to demand payment from the endorser of a commercial paper when the first party liable fails to pay.
# 追索权当有支付义务的第一方不能支付时,可以向商业票据的背书人要求支付的权力.
#
# Our correspondence is limited to a few commercial letters.
# 我们之间的通信只限于几封商业函件.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. describe
# 2. static
# 3. lightning
# 4. manually
# 5. commercial
