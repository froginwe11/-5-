# %% [markdown]
# # Day251

# %% [markdown]
# <https://www.bilibili.com/video/BV1ht4y1D7H9?p=252>

# %% [markdown]
# # surrounding
#
# 英\[səˈraʊndɪŋ\] 美\[səˈraʊndɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/surrounding)**
#
# adj. 周围的，附近的
#
# v. 包围( surround的现在分词 ); 与…紧密相关; 围绕; 喜欢结交（某类人）
#
# **例句**：
#
# Foxes started coming in from the surrounding countryside.
# 狐狸开始从附近的乡下跑进来.
#
# New housing is starting to encroach upon the surrounding fields.
# 新住宅开始延伸到周围的田地.

# %% [markdown]
# # bell
#
# 英\[bel\] 美\[bel\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/bell)**
#
# n. 钟，铃; 钟声，铃声; 钟状物; [建]圆屋顶
#
# **例句**：
#
# As soon as the bell rang, the captain gave orders to cast off, and the voyage began.
# 铃一响, 船长下令解缆绳, 航行就开始了.
#
# " Well, anyhow, I rang the bell. ”
# “ 好吧, 不管好歹, 反正我按铃了. ”

# %% [markdown]
# # key
#
# 英\[kiː\] 美\[kiː\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/key)**
#
# n. 钥匙; （打字机等的）键; 关键，线索，秘诀; （音乐的）调
#
# vt. 键入; 锁上; 调节…的音调; 提供线索
#
# vi. 使用钥匙
#
# adj. 关键的; 主要的
#
# **例句**：
#
# He dived his hand into his pocket in an attempt to find the key.
# 他把手伸到口袋里摸,试图找到那把钥匙.
#
# If you turn the envelope upside down, the key will fall out.
# 你如果把信封倒过来, 钥匙就会掉出.

# %% [markdown]
# # cad
#
# 英\[kæd\] 美\[kæd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/cad)**
#
# n. （尤指对女性）卑鄙的男人； 无赖，下流人；下流男子
#
# **例句**：
#
# The center also will offer solution quotations, CAD drawings and panel designs.
# 中心也将提供解决方案报价单 、 电脑辅助设计绘图及展板设计.
#
# Automatic vectorization of the engineering drawing is one of the key technologies in CAD field.
# 工程图扫描输入及自动矢量化是CAD等领域中的关键技术之一.

# %% [markdown]
# # neither
#
# 英\[ˈnaɪðə(r)\] 美\[ˈnaɪðər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/neither)**
#
# adj. （两者）都不的
#
# pron. 两者都不
#
# adv. 两个都不; 既不…也不
#
# conj. 也不; 既不
#
# **例句**：
#
# Neither pen nor pencil can express.
# 并非笔墨所能形容.
#
# I left my watch on the table, but when I returned I could find neither hide nor hair.
# 我把手表忘在桌上了; 可当我回来找时,什么都没有了.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. surrounding
# 2. bell
# 3. key
# 4. cad
# 5. neither
