# %% [markdown]
# # Day309

# %% [markdown]
# # heap
#
# 英\[hiːp\] 美\[hiːp\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/heap)**
#
# n. 堆，堆积; <口>许多，大量; <俚>破车
#
# vt. 扔成一堆; 完全填满，灌满; 大量或奢侈的赠予
#
# **例句**：
#
# Can you tell how many jin of apples there are in this heap?
# 你估一估这堆苹果有几斤.
#
# Displays error information in the IDE title bar if errors are found in the heap.
# 在堆中发现错误后,在IDE的标题栏上显示错误信息.

# %% [markdown]
# # pseudo
#
# 英\['sju:dəʊ\] 美\['sudoʊ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/pseudo)**
#
# adj. 假的，虚伪的
#
# n. [口]假冒的人，伪君子
#
# **例句**：
#
# What a load of pompous, pseudo-intellectual rot.
# 真是自命不凡的伪知识分子的一派胡言！
#
# Her care for the poor is completely pseudo.
# 她对穷人的关心完全是假的.

# %% [markdown]
# # return
#
# 英\[rɪˈtɜːn\] 美\[rɪˈtɜːrn\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/return)**
#
# v. 回来; 退还; 重现; 回报
#
# n. 回来; 归还; 恢复; 利润
#
# **例句**：
#
# An interval of a year elapsed before we were able to return.
# 隔了一年我们才得以返回.
#
# Taiwan will return to the embrace of the motherland; the whole country must be united. This is the general trend of development and the common aspiration of the people.
# 台湾要回到祖国的怀抱, 全国一定要统一.这是大势所趋,人心所向.

# %% [markdown]
# # recall
#
# 英\[rɪˈkɔːl\] 美\[rɪˈkɔːl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/recall)**
#
# vt. 叫回，召回; 使想起，回想; 取消; 调回工厂
#
# n. 召回，唤回; 记忆力，回想; 罢免; 收回通告
#
# **例句**：
#
# He seemed to have a very selective recall of past events.
# 他好像对过去的事情有选择地回忆.
#
# He made a decision beyond recall.
# 他做了一个不可挽回的决定.

# %% [markdown]
# # undesirable
#
# 英\[ˌʌndɪˈzaɪərəbl\] 美\[ˌʌndɪˈzaɪrəbəl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/undesirable)**
#
# adj. 不受欢迎的，讨厌的; 不合需要的; 不方便的; 不良的
#
# n. 不受欢迎的人; 不良分子
#
# **例句**：
#
# The whole business of making a fuss is seen as socially undesirable.
# 吵吵闹闹、小题大作压根儿是失礼的.
#
# When he was young, he used to run with some very undesirable types.
# 他在年轻时常同一些极不受欢迎的人往来.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. heap
# 2. pseudo
# 3. return
# 4. recall
# 5. undesirable
