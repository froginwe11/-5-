# %% [markdown]
# # Day268

# %% [markdown]
# # model
#
# 英\[ˈmɒdl\] 美\[ˈmɑːdl\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/model)**
#
# n. 模型; 模特儿; 模式; 典型
#
# vt.& vi. 做模特儿
#
# vt. 模仿; 制作模型，塑造; 将…做成模型
#
# **例句**：
#
# The artist posed the model carefully.
# 那个画家细心地使模特儿摆好姿势.
#
# She was posturing a model.
# 她正在摆模特儿的姿势.

# %% [markdown]
# # hardware
#
# 英\[ˈhɑːdweə(r)\] 美\[ˈhɑːrdwer\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hardware)**
#
# n. 五金器具; 计算机硬件; 武器装备
#
# **例句**：
#
# Preparation and maintenance the components need in hardware development.
# 准备和维护硬件研发中所需元器件.
#
# Continuous computer check achieved by duplication of hardware and comparison of results.
# 用两套硬件(例如两个运算器)同时产生的结果进行连续的比较而实现的校验.

# %% [markdown]
# # record
#
# 英\[ˈrekɔːd , rɪˈkɔːd\] 美\[ˈrekərd , rɪˈkɔːrd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/record)**
#
# n. 记录，记载; 档案，履历; 唱片; 最高纪录
#
# vt.& vi. 记录，记载; 标明; 录音
#
# **例句**：
#
# We managed to record the whole of the concert from a live studio broadcast.
# 我们设法把现场直播音乐会的全部节目录了下来.
#
# Production in this factory topped the highest record in history.
# 该厂生产超过了历史上最高记录.

# %% [markdown]
# # foreground
#
# 英\[ˈfɔːɡraʊnd\] 美\[ˈfɔːrɡraʊnd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/foreground)**
#
# n. 前景; 突出的地方， 最显著的位置
#
# v. 强调；突出
#
# **例句**：
#
# The market foreground of TARSM telephone is very widely.
# 固话短信市场前景非常广阔.
#
# The development and foreground f application for the YAG optical function ceramics were analyzed.
# 与过去的YAG单晶陶瓷作了对比,并对其发展及应用前景进行了分析.

# %% [markdown]
# # toward
#
# 英\[tə'wɔ:d\] 美\[təˈwɒrd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/toward)**
#
# prep. 对于; 向; 为了; 接近
#
# adj. 即将来到的; 进行中的
#
# **例句**：
#
# McKay walked slowly toward this screen, feeling a growing tenseness.
# 麦凯缓缓地朝这个屏幕走来，每走一步心情都更加紧张。
#
# Breathe out and ease your knees in toward your chest.
# 呼气，膝部放松向胸部靠拢。

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. model
# 2. hardware
# 3. record
# 4. foreground
# 5. toward
