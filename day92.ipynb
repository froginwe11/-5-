# %% [markdown]
# # Day92

# %% [markdown]
# # separated
#
# 英\[ˈsepəreɪtɪd\] 美\['sepəreɪtɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/separated)**
#
# adj. 分开的
#
# v. 分开(separate的过去式和过去分词)
#
# **例句**：
#
# The pity is that their happy days were soon over. A few weeks later the war broke out and they separated again.
# 可惜的是好景不常, 几个星期以后战争爆发,他们又分手了.
#
# The war separated many families.
# 战争使许多家庭离散.

# %% [markdown]
# # store
#
# 英\[stɔː(r)\] 美\[stɔːr\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/store)**
#
# n. 商店; 贮存物; 仓库; 大量
#
# v. 贮存; （在计算机里）存储
#
# **例句**：
#
# He volunteered to serve as the manager of our department store.
# 他自荐当我们商场的经理.
#
# They are trading at a store.
# 他们正在商店买东西.

# %% [markdown]
# # experience
#
# 英\[ɪkˈspɪəriəns\] 美\[ɪkˈspɪriəns\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/experience)**
#
# n. 经验，体验; 经历，阅历
#
# vt. 亲身参与，亲身经历; 感受; 发现
#
# **例句**：
#
# Television allows viewers to experience an event without any loss of immediacy.
# 电视让观众可以即时经历某一事件.
#
# Experience is the mother of wisdom.
# 经验为智慧之母.

# %% [markdown]
# # font
#
# 英\[fɒnt\] 美\[fɑnt\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/font)**
#
# n. 字体; 字形; 圣洗池（设于教堂中，常为石造）; （同样字体和字号的）一副铅字
#
# **例句**：
#
# Specifies a new font, size, and color to be used for rendering the enclosed text.
# 用于说明所包含文本的新字体 、 大小和颜色.
#
# Font viewer view sample text in all available fonts.
# 字体查看器样文在所有可用的字体.

# %% [markdown]
# # whatever
#
# 英\[wɒtˈevə(r)\] 美\[wətˈevər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/whatever)**
#
# pron. 无论什么; 任何（事物）; 诸如此类; （表示不在乎，什么都可接受）什么都可以
#
# adv. 一点儿都（不）；丝毫（不）；什么都（没有）,不管发生什么
#
# **例句**：
#
# Now that I have passed my exams, I feel as free as the air and can do whatever I like.
# 我考试及格了, 可以自由自在,爱做什么就做什么了.
#
# We will defer to whatever the committee decides.
# 我们遵从委员会作出的任何决定.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. separated
# 2. store
# 3. experience
# 4. font
# 5. whatever
