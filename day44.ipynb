# %% [markdown]
# # Day44

# %% [markdown]
# # related
#
# 英\[rɪˈleɪtɪd\] 美\[rɪˈleɪtɪd\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/related)**
#
# adj. 有关系的; 叙述的
#
# vt. 叙述(relate过去式和过去分词)
#
# **例句**：
#
# All the bees in the colony are genetically related.
# 同一群体的蜜蜂都有亲缘关系.
#
# The unemployment figures are not necessarily related to the rise in prices.
# 失业的数目同物价的上涨并没有必然的联系.

# %% [markdown]
# # hardly
#
# 英\[ˈhɑːdli\] 美\[ˈhɑːrdli\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/hardly)**
#
# adv. 几乎不; 简直不; 刚刚; 严厉地，粗鲁地
#
# **例句**：
#
# He was pinned against the fence by a boy twice his size; he could hardly breathe.
# 他被一个身材两倍于他的男孩按在篱笆上, 喘不过气来.
#
# The words hardly permit doubt.
# 这些话不容置疑.

# %% [markdown]
# # positioning
#
# 英\[pə'zɪʃnɪŋ\] 美\[pə'zɪʃnɪŋ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/positioning)**
#
# n. 配置，布置; 定位
#
# **例句**：
#
# The accurate positioning of an entity relative to a reference.
# 相对于参考基准把某个实体精确定位.
#
# Their segregated positioning subtly and silently indicates that caution should be taken in their use.
# 它们相对分离的位置微妙而无声地提示着用户,即使用它们时应该小心.

# %% [markdown]
# # say
#
# 英\[seɪ\] 美\[seɪ\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/say)**
#
# vi. 说， 讲; 表明，宣称; 假设; 约莫
#
# vt. 表明; 念; 说明; 比方说
#
# n. 发言权; 说话; 要说的话; 发言权
#
# **例句**：
#
# I asked him several times, but he didn't say anything.
# 我问过他几遍, 他都没吱声.
#
# I'd like to say a few more words.
# 我还有几句话要说.

# %% [markdown]
# # cover
#
# 英\[ˈkʌvə(r)\] 美\[ˈkʌvər\]
#
# **[释义](https://fanyi.baidu.com/#en/zh/cover)**
#
# v. 遮盖; 掩蔽; 涉及; 洒上
#
# n. 覆盖物; 避难所; 掩护; 封面
#
# **例句**：
#
# Go on and take your coffee break. I'll cover for you until you return.
# 你去喝咖啡吧, 你回来前我会代替你.
#
# Everybody took cover when the bombs began to fall on the town.
# 轰炸时,镇上的每个人都藏了起来.

# %% [markdown]
# # 回顾
#
# **暂停5秒，回想一下我们今天所学的单词**

# %% [markdown]
# **准备好了吗?**

# %% [markdown]
# 1. related
# 2. hardly
# 3. positioning
# 4. say
# 5. cover
